# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
data_path = "resultat_anomalies.csv"
data = pd.read_csv(data_path)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3955 entries, 0 to 3954
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   uId                  3955 non-null   object
#  1   pmcId                3955 non-null   int64
#  2   licenseType          3955 non-null   object
#  3   articleDate          3955 non-null   object
#  4   articleType          3955 non-null   object
#  5   publisher            3955 non-null   object
#  6   specialty            3955 non-null   object
#  7   language             3955 non-null   object
#  8   abstract_COMPARISON  3333 non-null   object
#  9   abstract_INDICATION  3865 non-null   object
#  10  abstract_FINDINGS    3425 non-null   object
#  11  abstract_IMPRESSION  3921 non-null   object
#  12  authors              3955 non-null   object
#  13  mesh_major           3955 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 432.7+ KB

# %%
columns_to_remove = [ "pmcId","licenseType","articleDate","articleType","publisher","language","authors",]
data = data.drop(columns=columns_to_remove)
print("Données après suppression des colonnes :")
data.info()
# Out:
# Données après suppression des colonnes :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3955 entries, 0 to 3954
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   uId                  3955 non-null   object
#  1   specialty            3955 non-null   object
#  2   abstract_COMPARISON  3333 non-null   object
#  3   abstract_INDICATION  3865 non-null   object
#  4   abstract_FINDINGS    3425 non-null   object
#  5   abstract_IMPRESSION  3921 non-null   object
#  6   mesh_major           3955 non-null   object
# dtypes: object(7)
# memory usage: 216.4+ KB

# %%
final_data_path = "final_dataset.csv"
data.to_csv(final_data_path,index=False)

# %%
data.shape
# Out:
# (3955, 7)

# %%
data.head()
# Out:
#        uId           specialty                    abstract_COMPARISON  \
# 0     CXR1  pulmonary diseases                                  None.
# 1    CXR10  pulmonary diseases                Chest radiographs XXXX.
# 2   CXR100  pulmonary diseases                                  None.
# 3  CXR1000  pulmonary diseases  XXXX PA and lateral chest radiographs
# 4  CXR1001  pulmonary diseases                                   None
#
#                                  abstract_INDICATION  \
# 0                                   Positive TB test
# 1                    XXXX-year-old male, chest pain.
# 2                                                NaN
# 3                          XXXX-year-old male, XXXX.
# 4  dyspnea, subjective fevers, arthritis, immigra...
#
#                                    abstract_FINDINGS  \
# 0  The cardiac silhouette and mediastinum size ar...
# 1  The cardiomediastinal silhouette is within nor...
# 2  Both lungs are clear and expanded. Heart and m...
# 3  There is XXXX increased opacity within the rig...
# 4  Interstitial markings are diffusely prominent ...
#
#                                  abstract_IMPRESSION  \
# 0                               Normal chest x-XXXX.
# 1                  No acute cardiopulmonary process.
# 2                                 No active disease.
# 3  1. Increased opacity in the right upper lobe w...
# 4  Diffuse fibrosis. No visible focal acute disease.
#
#                                           mesh_major
# 0                                             normal
# 1          Calcified Granuloma/lung/upper lobe/right
# 2                                             normal
# 3  Opacity/lung/upper lobe/right, Pulmonary Atele...
# 4  Markings/lung/bilateral/interstitial/diffuse/p...

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# uId                      0
# specialty                0
# abstract_COMPARISON    622
# abstract_INDICATION     90
# abstract_FINDINGS      530
# abstract_IMPRESSION     34
# mesh_major               0
# dtype: int64

# %%
print("\n ** Nombre de doublons avant supppression **:",data.duplicated().sum())
# Out:
#  ** Nombre de doublons avant supppression **: 0

# %%
data = data.drop_duplicates()
print("**Nombre de doublons après suppression**:", data.duplicated().sum())
# Out:
# **Nombre de doublons après suppression**: 0

# %%
data.shape
# Out:
# (3955, 7)

# %%
data.dtypes
# Out:
# uId                    object
# specialty              object
# abstract_COMPARISON    object
# abstract_INDICATION    object
# abstract_FINDINGS      object
# abstract_IMPRESSION    object
# mesh_major             object
# dtype: object

# %%
data.abstract_COMPARISON.describe()
# Out:
# count      3333
# unique      401
# top       None.
# freq        826
# Name: abstract_COMPARISON, dtype: object

# %%
data.abstract_INDICATION.describe()
# Out:
# count           3865
# unique          2522
# top       Chest pain
# freq             129
# Name: abstract_INDICATION, dtype: object

# %%
data.abstract_FINDINGS.describe()
# Out:
# count                                                  3337
# unique                                                 2553
# top       The heart is normal in size. The mediastinum i...
# freq                                                     51
# Name: abstract_FINDINGS, dtype: object

# %%
data.abstract_IMPRESSION.describe()
# Out:
# count                                      3820
# unique                                     1770
# top       No acute cardiopulmonary abnormality.
# freq                                        301
# Name: abstract_IMPRESSION, dtype: object

# %%
data.mesh_major.describe()
# Out:
# count       3851
# unique      1900
# top       normal
# freq        1379
# Name: mesh_major, dtype: object

# %%
data.uId.describe()
# Out:
# count       3851
# unique      3851
# top       CXR999
# freq           1
# Name: uId, dtype: object

# %%
data.

# %%
def generate_wordcloud(column_name, title="Nuage de mots"):
    if column_name not in data.columns:
        print(f"La colonne '{column_name}' n'existe pas dans le DataFrame.")
        return
    text = " ".join(data[column_name].dropna())
    if not text.strip():
        print(f"La colonne '{column_name}' ne contient pas de texte non vide.")
        return
    wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text)
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"{title} - {column_name}\n")
    plt.show()

generate_wordcloud('abstract_COMPARISON')

# %%
generate_wordcloud('abstract_INDICATION')

# %%
generate_wordcloud('mesh_major')

# %%
generate_wordcloud('uId')

# %%
generate_wordcloud('abstract_IMPRESSION')

# %%
generate_wordcloud('abstract_FINDINGS')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
