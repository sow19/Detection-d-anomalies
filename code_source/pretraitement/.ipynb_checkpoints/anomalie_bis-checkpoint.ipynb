# %%
import gensim.downloader as api
import pandas as pd
import numpy as np
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.decomposition import PCA
# from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import StandardScaler
# Out:
# 2025-03-24 16:14:59.921612: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-24 16:14:59.924479: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-24 16:14:59.980893: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-24 16:14:59.982072: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-24 16:15:01.918063: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
csv = "../../data/cleaned/final_clean_data1.csv"
df = pd.read_csv(csv)

# %%
heart_keywords = [
    'heart', 'cardiac', 'cardiomegaly', 'cardiothoracic', 'cardiovascular',
    'cardiopulmonary', 'vascular', 'aorta', 'aortic', 'ventricle', 'ventricular',
    'atrium', 'atrial', 'pericardial', 'pericardium', 'enlargement', 'heart_size',
    'mediastinum', 'mediastinal', 'silhouette', 'congestive', 'congestion',
    'vascularity', 'vascular_congestion', 'cardiac_border', 'cardiomegalia',
    'cardiac_enlargement'
]
lung_keywords = [
    'lung', 'lungs', 'pulmonary', 'pleural', 'pleura', 'pneumothorax',
    'infiltrate', 'infiltration', 'opacity', 'opacities', 'consolidation',
    'emphysema', 'hyperinflation', 'interstitial', 'atelectasis', 'edema',
    'bronchial', 'bronchi', 'airspace', 'alveolar', 'fibrosis', 'pneumonia',
    'trachea', 'hilar', 'effusion', 'hemithorax', 'costophrenic', 'parenchymal',
    'bilateral', 'unilateral', 'lobar', 'lobes', 'upper_lobe', 'lower_lobe'
]

def assign_subject_code(text):
    heart_score = sum(1 for word in heart_keywords if word in text)
    lung_score = sum(1 for word in lung_keywords if word in text)
    
    if lung_score > heart_score:
        return 1  # Poumon
    elif heart_score > lung_score:
        return 2  # Cœur
    else:
        return 0  # Inconnu

df['sujet'] = df['combined_text'].apply(assign_subject_code)

# %%
# Séparer les datasets
df_lung = df[df['sujet'] == 1].reset_index(drop=True)
df_heart = df[df['sujet'] == 2].reset_index(drop=True)

# (Optionnel) Afficher les tailles
print(f" Poumon : {len(df_lung)} lignes")
print(f" Cœur : {len(df_heart)} lignes")
# Out:
#  Poumon : 2815 lignes
#  Cœur : 604 lignes

# %%
df_lung
# Out:
#                                           combined_text  sujet
# 0     cardiac silhouette mediastinum size within nor...      1
# 1     cardiomediastinal silhouette within normal lim...      1
# 2     increased_opacity within right_upper_lobe poss...      1
# 3     interstitial marking diffusely prominent throu...      1
# 4     heart size pulmonary vascularity appear within...      1
# ...                                                 ...    ...
# 2810  heart size normal lung clear normal pneumonia ...      1
# 2811  lung clear cardiomediastinal silhouette within...      1
# 2812  sternotomy suture bypass graft placed interval...      1
# 2813  calcified mediastinal focal area consolidation...      1
# 2814  lung clear bilaterally focal consolidation ple...      1
#
# [2815 rows x 2 columns]

# %%
def key_words(column, top_n=20):
    """
    En utilisant la métrique tf-dif, la fonction retourne les top_n premiers mots-clés dans le dataset.
    """
    vectorizer = TfidfVectorizer()
    x = vectorizer.fit_transform(column)
    feature_names = vectorizer.get_feature_names_out()
    
    kw_per_text = []
    for doc_idx in range(x.shape[0]):
        # récupérer les scores tf-dif pour le texte courant
        tfidf_scores = x[doc_idx].toarray()[0]

        # associer chaque mot avec son score tf-dif
        word_scores = [(feature_names[i], tfidf_scores[i]) for i in range(len(feature_names))]

        # trier les mots par score décroissant
        sorted_words = sorted(word_scores, key=lambda x: x[1], reverse=True)

        # récupérer les top_n mots-clés
        keywords = [word for word, score in sorted_words[:top_n]]
        kw_per_text.append(keywords)

    return kw_per_text

# %%
key_words(df_lung['combined_text'])
# Out:
# [['edema',
#   'cardiac',
#   'mediastinum',
#   'chest',
#   'evidence',
#   'normal',
#   'silhouette',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['inflated',
#   'normally',
#   'bone',
#   'within',
#   'upper',
#   'granuloma',
#   'process',
#   'calcified',
#   'lung',
#   'stable',
#   'acute',
#   'without',
#   'right',
#   'evidence',
#   'cardiomediastinal',
#   'airspace',
#   'contour',
#   'silhouette',
#   'disease',
#   'abnormality'],
#  ['increased_opacity',
#   'left_5th_rib_may',
#   'represent_focal_airspace_disease',
#   'focal_consolidation',
#   'right_upper_lobe',
#   'associated',
#   'atelectasis',
#   'overlying',
#   'mass',
#   'may_represent',
#   'possible',
#   'lesion',
#   'recommend',
#   'opacity',
#   'midlung',
#   'tomography',
#   'computed',
#   'evaluation',
#   'bone',
#   'posterior'],
#  ['diffusely',
#   'fibrosis',
#   'throughout',
#   'diffuse',
#   'marking',
#   'prominent',
#   'visible',
#   'interstitial',
#   'normal',
#   'disease',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['appearance_suggests',
#   'retrocardiac_soft_tissue_density',
#   'bandlike_opacity',
#   'hiatal_hernia',
#   'base',
#   'present',
#   'atelectasis',
#   'development',
#   'osteopenia',
#   'seen',
#   'left',
#   'represents',
#   'could',
#   'interval',
#   'appears',
#   'suggest',
#   'represent',
#   'vascular',
#   'calcification',
#   'may'],
#  ['degenerative_change',
#   'inferior',
#   'acromioclavicular',
#   'ectatic',
#   'joint',
#   'cava',
#   'vena',
#   'suggest',
#   'tortuous',
#   'pneumonia',
#   'aorta',
#   'air',
#   'identified',
#   'space',
#   'mediastinum',
#   'spine',
#   'opacity',
#   'disease',
#   'limit',
#   'within'],
#  ['suggest',
#   'clear',
#   'pneumonia',
#   'space',
#   'appear',
#   'opacity',
#   'normal',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'disease',
#   'pulmonary',
#   'cardiopulmonary',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'pleural',
#   '02010'],
#  ['reveals',
#   'trachea',
#   'show',
#   'midline',
#   'acute',
#   'abnormality',
#   'view',
#   'lateral',
#   'infiltrate',
#   'visualized',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'bony',
#   'structure',
#   'without',
#   'spine',
#   'evidence',
#   'change',
#   'cardiomediastinal'],
#  ['consolidative',
#   'radiographic',
#   'appearance',
#   'visualized',
#   'intact',
#   'appear',
#   'osseous',
#   'structure',
#   'evidence',
#   'opacity',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal'],
#  ['area',
#   'vasculature',
#   'cardiomediastinal',
#   'silhouette',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'focal',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['elevated_left_hemidiaphragm',
#   'degenerative_change',
#   'shoulder',
#   'mildly',
#   'subluationdislocation',
#   'bilateral',
#   'chronic',
#   'atelectasis',
#   'humerus',
#   'dislocation',
#   'accentuated',
#   'somewhat',
#   'etensive',
#   'correlate',
#   'rotated',
#   'congestion',
#   'correlation',
#   'clinical',
#   'probable',
#   'stable'],
#  ['bibasilar',
#   'traverse',
#   'bilateral',
#   'entire',
#   'shunt',
#   'tubing',
#   'top',
#   'image',
#   'fluid',
#   'blunting',
#   'costophrenic',
#   'low',
#   'present',
#   'volume',
#   'normal',
#   'airspace',
#   'disease',
#   'consolidation',
#   'pulmonary',
#   'size'],
#  ['stable_mild_cardiomegaly',
#   'anchor',
#   'head',
#   'humeral',
#   'bone',
#   'intact',
#   'bony',
#   'structure',
#   'without',
#   'right',
#   'airspace',
#   'disease',
#   'abnormality',
#   'cardiopulmonary',
#   'focal',
#   'acute',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['bibasilar_opacity',
#   'triangular',
#   'feature',
#   'combination',
#   'considering',
#   'difference',
#   'projected',
#   'technical',
#   'factor',
#   'greater',
#   'streaky',
#   'patchy',
#   'typical',
#   'density',
#   'suggest',
#   'definite',
#   'view',
#   'lateral',
#   'edema',
#   'atelectasis'],
#  ['present',
#   'lingula',
#   'epanded',
#   'basilar',
#   'infiltrates',
#   'hilar',
#   'active',
#   'atelectasis',
#   'calcified',
#   'right',
#   'disease',
#   'clear',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'normal',
#   '02010',
#   '09',
#   '10'],
#  ['small',
#   'area',
#   'lateral',
#   'granuloma',
#   'vasculature',
#   'calcified',
#   'right',
#   'cardiomediastinal',
#   'silhouette',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal'],
#  ['blunting_right',
#   'costophrenic_sulcus_could_secondary',
#   'effusion_versus_scarring_focal',
#   'airspace_consolidation',
#   'small',
#   'lateral',
#   'appear',
#   'bony',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'limit',
#   'within',
#   'size',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   '02010',
#   '09'],
#  ['pectus',
#   'substernal',
#   'hyperaerated',
#   'related',
#   'deformity',
#   'density',
#   'may',
#   'abnormality',
#   'clear',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09'],
#  ['hypoinflation',
#   'visible',
#   'infiltrates',
#   'low',
#   'volume',
#   'active',
#   'disease',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'normal',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13'],
#  ['evidence',
#   'edema',
#   'cardiac',
#   'mediastinum',
#   'large',
#   'silhouette',
#   'disease',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['pneumothoraces',
#   'hilar',
#   'normal',
#   'air',
#   'space',
#   'vascularity',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'clear',
#   'consolidation',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['base',
#   'negative',
#   'granuloma',
#   'calcified',
#   'large',
#   'right',
#   'normal',
#   'cardiomediastinal',
#   'contour',
#   'silhouette',
#   'abnormality',
#   'consolidation',
#   'size',
#   'focal',
#   'acute',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09'],
#  ['appear',
#   'clear',
#   'space',
#   'normal',
#   'mediastinal',
#   'contour',
#   'disease',
#   'pulmonary',
#   'cardiopulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'pleural',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13'],
#  ['limited',
#   'eamination',
#   'demonstration',
#   'obscuration',
#   'somewhat',
#   'sulcus',
#   'intrathoracic',
#   'secondary',
#   'radiograph',
#   'costophrenic',
#   'appears',
#   'posterior',
#   'bilateral',
#   'area',
#   'view',
#   'appearance',
#   'lateral',
#   'intact',
#   'thoracic',
#   'large'],
#  ['ascending_aorta_mediastinal_lymphadenopathy',
#   'computed_tomography_chest_contrast',
#   'may_helpful_evaluation',
#   'prominence_mediastinal_contour_near',
#   'right_hilum',
#   'representing',
#   'possibly',
#   'evidence',
#   'compared',
#   'eam',
#   'represent',
#   'may',
#   'prior',
#   'cardiac',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'large',
#   'without',
#   'spine'],
#  ['radiographic',
#   'mild',
#   'seen',
#   'degenerative',
#   'large',
#   'bony',
#   'acute',
#   'spine',
#   'evidence',
#   'change',
#   'cardiomediastinal',
#   'silhouette',
#   'disease',
#   'abnormality',
#   'consolidation',
#   'cardiopulmonary',
#   'focal',
#   'pneumothora',
#   'normal',
#   'pleural'],
#  ['prior',
#   'projecting',
#   'tspine',
#   'sequela',
#   'midlung',
#   'osteophyte',
#   'granulomatous',
#   'calcification',
#   'small',
#   'unchanged',
#   'area',
#   'vasculature',
#   'left',
#   'cardiomediastinal',
#   'silhouette',
#   'disease',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within'],
#  ['lung_zone',
#   'perihilar_opacity',
#   'nodular_opacity',
#   'may_represent',
#   'vague',
#   'prominent',
#   'mucous',
#   'right',
#   'peribronchial',
#   'present',
#   'bronchiectasis',
#   'bronchus',
#   'filled',
#   'dilated',
#   'slightly',
#   'possibly',
#   'due',
#   'previous',
#   'study',
#   'small'],
#  ['unremarkable',
#   'emphysema',
#   'hyperepanded',
#   'tortuous',
#   'consistent',
#   'present',
#   'aorta',
#   'calcified',
#   'mediastinum',
#   'thoracic',
#   'airspace',
#   'disease',
#   'abnormality',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora'],
#  ['bilaterally',
#   'cardiac',
#   'contour',
#   'abnormality',
#   'clear',
#   'cardiopulmonary',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm'],
#  ['minimal_left_basilar',
#   'subsegmental_atelectasis_scarring',
#   'splenic',
#   'overlies',
#   'calcified',
#   'ventricle',
#   'defibrillator',
#   'also',
#   'multiple',
#   'atherosclerotic',
#   'aortic',
#   'lymph',
#   'appears',
#   'minimal',
#   'suggest',
#   'granulomatous',
#   'consistent',
#   'vascular',
#   'calcification',
#   'hilar'],
#  ['posterior_rib',
#   'cross',
#   '10th',
#   'portion',
#   'tenderness',
#   'correlate',
#   'question',
#   'lucency',
#   'fracture',
#   'visualized',
#   'thoracic',
#   'large',
#   'unremarkable',
#   'left',
#   'spine',
#   'mediastinal',
#   'contour',
#   'clear',
#   'lung',
#   'pneumothora'],
#  ['interval_improvement',
#   'pleural_effusion',
#   'lung_base',
#   'aeration',
#   'small',
#   'left',
#   'atelectatic',
#   'questionable',
#   'residual',
#   'improved',
#   'right',
#   'bilateral',
#   'base',
#   'volume',
#   'bilaterally',
#   'visualized',
#   'chest',
#   'change',
#   'normal',
#   'cardiomediastinal'],
#  ['lung_appear',
#   'consistent_emphysema',
#   'hyperepanded',
#   'clearing',
#   'base',
#   'vascularity',
#   'appear',
#   'seen',
#   'left',
#   'evidence',
#   'opacity',
#   'airspace',
#   'disease',
#   'clear',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'heart',
#   'lung'],
#  ['posterolateral',
#   '7th',
#   'injury',
#   'appearing',
#   'finding',
#   'suggestive',
#   'old',
#   'deformity',
#   'alveolar',
#   'contour',
#   'rib',
#   'chronic',
#   'hilar',
#   'edema',
#   'noted',
#   'stable',
#   'right',
#   'mediastinal',
#   'consolidation',
#   'limit'],
#  ['negative',
#   'mediastinum',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['cardio',
#   'specifically',
#   'abnormality',
#   'thora',
#   'bilaterally',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'acute',
#   'structure',
#   'without',
#   'evidence',
#   'mediastinal',
#   'silhouette',
#   'clear',
#   'consolidation',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'pneumothora'],
#  ['acromioclavicular',
#   'joint',
#   'suspicious',
#   'bilateral',
#   'pulmonary',
#   'noted',
#   'identified',
#   'visualized',
#   'intact',
#   'vascularity',
#   'appear',
#   'osseous',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'large',
#   'structure',
#   'spine',
#   'change',
#   'opacity'],
#  ['subclavian',
#   'position',
#   'venous',
#   'catheter',
#   'blunting',
#   'costophrenic',
#   'central',
#   'bilateral',
#   'bilaterally',
#   'mild',
#   'stable',
#   'left',
#   'airspace',
#   'disease',
#   'limit',
#   'within',
#   'size',
#   'focal',
#   'heart',
#   'pneumothora'],
#  ['bronchopulmonary',
#   'ray',
#   'repeat',
#   'technically',
#   'nonspecific',
#   'concern',
#   'decreased',
#   'associated',
#   'consider',
#   'secondary',
#   'prominence',
#   'limited',
#   'crowding',
#   'study',
#   'patient',
#   'suspicious',
#   'vascular',
#   'volume',
#   'identified',
#   'process'],
#  ['dislocation',
#   'reveal',
#   'overlying',
#   'cardio',
#   'sternotomy',
#   'trachea',
#   'midline',
#   'fracture',
#   'infiltrate',
#   'visualized',
#   'bony',
#   'acute',
#   'structure',
#   'without',
#   'mediastinal',
#   'contour',
#   'silhouette',
#   'abnormality',
#   'clear',
#   'lung'],
#  ['subsegmental_atelectasis_decreased_prior',
#   'stable_mild_cardiomegaly',
#   'scattered',
#   'radiograph',
#   'postoperative',
#   'coronary',
#   'bypass',
#   'graft',
#   'change',
#   'artery',
#   'sternotomy',
#   'minimal',
#   'bilateral',
#   'degenerative',
#   'chest',
#   'spine',
#   'airspace',
#   'consolidation',
#   'focal',
#   'pneumothora'],
#  ['suspicious',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'stable',
#   'spine',
#   'change',
#   'opacity',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora'],
#  ['infiltrate',
#   'without',
#   'evidence',
#   'contour',
#   'disease',
#   'clear',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['emphysematous_lung_change',
#   'levoscoliosis',
#   'flattened',
#   'stable',
#   'thoracolumbar',
#   'hyperinflated',
#   'diaphragm',
#   'tortuous',
#   'granulomatous',
#   'consistent',
#   'suspicious',
#   'prior',
#   'aorta',
#   'air',
#   'space',
#   'seen',
#   'spine',
#   'opacity',
#   'disease',
#   'abnormality'],
#  ['discrete',
#   'adenopathy',
#   'disease',
#   'free',
#   'active',
#   'nodule',
#   'identified',
#   'vascularity',
#   'appear',
#   'seen',
#   'evidence',
#   'airspace',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'pneumothora'],
#  ['innumerable_bilateral',
#   'lung_nodule',
#   'present',
#   'diffusely',
#   'continued',
#   'seen',
#   'superimposed',
#   'scoliosis',
#   'throughout',
#   'small',
#   'identified',
#   'vascularity',
#   'appear',
#   'change',
#   'airspace',
#   'disease',
#   'limit',
#   'within',
#   'pulmonary',
#   'size'],
#  ['stable_retrocardiac_airspace_opacity',
#   'tortuous',
#   'granulomatous',
#   'prior',
#   'aorta',
#   'stable',
#   'cardiomediastinal',
#   'silhouette',
#   'disease',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm'],
#  ['slight',
#   'wedge',
#   'vertebral',
#   'comparison',
#   'body',
#   'mid',
#   'deformity',
#   'study',
#   'suggest',
#   'unchanged',
#   'lower',
#   'pneumonia',
#   'air',
#   'space',
#   'mediastinum',
#   'thoracic',
#   'opacity',
#   'disease',
#   'limit',
#   'within'],
#  ['atelectasis_lung_otherwise_clear',
#   'base',
#   'left',
#   'representing',
#   'minimal',
#   'opacity',
#   'size',
#   'heart',
#   'lung',
#   'pneumothora',
#   'normal',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm',
#   '15'],
#  ['increased_right_basilar_airspace',
#   'right_hemidiaphragm_questionable',
#   'diseaseatelectasis',
#   'subtle',
#   'correlate',
#   'stable',
#   'clinically',
#   'elevated',
#   'elevation',
#   'unremarkable',
#   'left',
#   'opacity',
#   'clear',
#   'size',
#   'heart',
#   'lung',
#   'normal',
#   '02010',
#   '09',
#   '10'],
#  ['cerclage',
#   'peripheral',
#   'disc',
#   'thoracic',
#   'coronary',
#   'bypass',
#   'graft',
#   'artery',
#   'sternotomy',
#   'interval',
#   'atherosclerotic',
#   'vascular',
#   'disease',
#   'calcification',
#   'otherwise',
#   'appearance',
#   'aorta',
#   'air',
#   'space',
#   'visualized'],
#  ['suspicious',
#   'soft',
#   'radiographic',
#   'tissue',
#   'mass',
#   'thora',
#   'grossly',
#   'nodule',
#   'unremarkable',
#   'bony',
#   'without',
#   'evidence',
#   'abnormality',
#   'clear',
#   'consolidation',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart'],
#  ['active',
#   'infiltrate',
#   'identified',
#   'vascularity',
#   'disease',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11'],
#  ['hyperepansion',
#   'flattening',
#   'bronchovascular',
#   'crowding',
#   'compatible',
#   'emphysema',
#   'diaphragm',
#   'base',
#   'negative',
#   'mild',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute'],
#  ['cardio',
#   'specifically',
#   'abnormality',
#   'thora',
#   'bilaterally',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'acute',
#   'structure',
#   'without',
#   'evidence',
#   'mediastinal',
#   'silhouette',
#   'clear',
#   'consolidation',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'pneumothora'],
#  ['abnormal_separation_right',
#   'pain',
#   'cardia',
#   'corticated',
#   'cortical',
#   'partial',
#   'dedicated',
#   'obscuration',
#   'remote',
#   'ageindeterminate',
#   'aspect',
#   'pattern',
#   'indicated',
#   'retrosternal',
#   'correlate',
#   'injury',
#   'shoulder',
#   'question',
#   'reflect',
#   'film'],
#  ['acute_displaced_fracture',
#   'rotated',
#   'patient',
#   'mildly',
#   'appearance',
#   'vascularity',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'spine',
#   'change',
#   'normal',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal'],
#  ['interval_development_left_lower',
#   'lobe_airspace_disease',
#   'there',
#   'since',
#   'due',
#   'compatible',
#   'study',
#   'atherosclerotic',
#   'tortuous',
#   'may',
#   'prior',
#   'aorta',
#   'infiltrate',
#   'atelectasis',
#   'calcified',
#   'stable',
#   'right',
#   'mediastinal',
#   'contour',
#   'disease'],
#  ['thoracic',
#   'flattened',
#   'change',
#   'tortuosity',
#   'emphysema',
#   'hyperepanded',
#   'eam',
#   'diaphragm',
#   'consistent',
#   'chronic',
#   'prior',
#   'aorta',
#   'mild',
#   'degenerative',
#   'large',
#   'stable',
#   'spine',
#   'cardiomediastinal',
#   'silhouette',
#   'abnormality'],
#  ['lung_volume',
#   'suggest',
#   'low',
#   'remain',
#   'line',
#   'blunting',
#   'costophrenic',
#   'large',
#   'bony',
#   'finding',
#   'stable',
#   'structure',
#   'pleural',
#   'cardiomediastinal',
#   'silhouette',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'acute',
#   'pneumothora'],
#  ['available',
#   'coronal_sagittal',
#   'irregular_pleuralparenchymal',
#   'opacity_left_upper_lobe',
#   'outside_study',
#   'severe_emphysema',
#   'outside',
#   'scarring',
#   'image',
#   'recommend',
#   'confidently',
#   'longterm',
#   'reformats',
#   'reformatted',
#   'shortterm',
#   'generalized',
#   'institution',
#   'month',
#   'none',
#   'may'],
#  ['heart_size_mild_central',
#   'left_lower_lobe',
#   'pleural_effusion',
#   'vascular',
#   'congestive',
#   'probably',
#   'aspect',
#   'question',
#   'andor',
#   'borderline',
#   'represents',
#   'prominence',
#   'also',
#   'multiple',
#   'old',
#   'deformity',
#   'posterior',
#   'small',
#   'bilateral',
#   'rib'],
#  ['skeletal',
#   'mediastinum',
#   'structure',
#   'normal',
#   'disease',
#   'clear',
#   'pulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13'],
#  ['right_basilar_atelectasis',
#   'low_lung_volume',
#   'demonstrates',
#   'amount',
#   'congestion',
#   'eam',
#   'minimal',
#   'vascular',
#   'small',
#   'appearance',
#   'upper',
#   'intact',
#   'appear',
#   'mediastinum',
#   'osseous',
#   'large',
#   'structure',
#   'pneumothora',
#   'consolidation',
#   'pulmonary'],
#  ['history_bronchitis_acute_infiltrate',
#   'related',
#   'perihilar',
#   'marking',
#   'particularly',
#   'increase',
#   'hypoinflated',
#   'region',
#   'increased',
#   'patient',
#   'lung',
#   'low',
#   'volume',
#   'mediastinum',
#   'mild',
#   'seen',
#   'left',
#   'normal',
#   'limit',
#   'within'],
#  ['emphysematous',
#   'change',
#   'hyperepanded',
#   'mass',
#   'process',
#   'seen',
#   'thoracic',
#   'lung',
#   'degenerative',
#   'stable',
#   'spine',
#   'opacity',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'normal',
#   '02010',
#   '09'],
#  ['stable_cardiomegaly',
#   'tortuosity',
#   'aorta',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'stable',
#   'spine',
#   'change',
#   'opacity',
#   'airspace',
#   'clear',
#   'focal',
#   'lung',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10'],
#  ['epigastric',
#   'gastroesophageal',
#   'cardiac',
#   'aeration',
#   'postsurgical',
#   'junction',
#   'airway',
#   'configuration',
#   'show',
#   'frontal',
#   'central',
#   'view',
#   'pulmonary',
#   'active',
#   'lateral',
#   'vasculature',
#   'chest',
#   'change',
#   'normal',
#   'mediastinal'],
#  ['without_acute',
#   'low_lung_volume',
#   'atelectatic',
#   'demonstrate',
#   'projection',
#   'scar',
#   'streaky',
#   'cardio',
#   'specifically',
#   'frontal',
#   'abnormality',
#   'thora',
#   'lobe',
#   'upper',
#   'bilaterally',
#   'visualized',
#   'osseous',
#   'mild',
#   'unremarkable',
#   'left'],
#  ['rib',
#   'corticated',
#   'gross',
#   '5th',
#   'irregularity',
#   'finding',
#   'secondary',
#   'old',
#   'posterior',
#   'fracture',
#   'vasculature',
#   'bony',
#   'acute',
#   'right',
#   'cardiomediastinal',
#   'airspace',
#   'silhouette',
#   'disease',
#   'clear',
#   'limit'],
#  ['believed',
#   'senescent',
#   'calcified',
#   'left',
#   'old',
#   'skeletal',
#   'show',
#   'lymph',
#   'granulomatous',
#   'disease',
#   'otherwise',
#   'hilar',
#   'lobe',
#   'upper',
#   'granuloma',
#   'structure',
#   'change',
#   'mediastinal',
#   'clear',
#   'pulmonary'],
#  ['streaky_opacity_lateral_right',
#   'atelectasis_versus_scarring',
#   'subsegmental',
#   'small',
#   'negative',
#   'mild',
#   'lung',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'focal',
#   'heart',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10'],
#  ['left_hemidiaphragm',
#   'elevated',
#   'descending',
#   'venous',
#   'remains',
#   'catheter',
#   'tortuous',
#   'central',
#   'disease',
#   'free',
#   'active',
#   'aorta',
#   'noted',
#   'vascularity',
#   'appear',
#   'seen',
#   'thoracic',
#   'evidence',
#   'airspace',
#   'limit'],
#  ['disease',
#   'free',
#   'active',
#   'vascularity',
#   'appear',
#   'seen',
#   'evidence',
#   'airspace',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['appearing',
#   'representing',
#   'density',
#   'soft',
#   'tissue',
#   'lower',
#   'hilar',
#   'consolidation',
#   'area',
#   'lobe',
#   'atelectasis',
#   'focal',
#   'osseous',
#   'left',
#   'normal',
#   'cardiomediastinal',
#   'contour',
#   'silhouette',
#   'abnormality',
#   'limit'],
#  ['displaced',
#   'rib',
#   'fracture',
#   'air',
#   'space',
#   'finding',
#   'opacity',
#   'limit',
#   'within',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10'],
#  ['anterior_wedging',
#   't11_level',
#   'indeterminate',
#   'mild',
#   'congestion',
#   'approimately',
#   'age',
#   'sequela',
#   'vertebral',
#   'infection',
#   'diffuse',
#   'body',
#   'visible',
#   'granulomatous',
#   'vascular',
#   'bilateral',
#   'lower',
#   'prior',
#   'edema',
#   'calcified'],
#  ['emphysema',
#   'coarse',
#   'pleuralparenchymal',
#   'lobar',
#   'hyperinflated',
#   'obstructive',
#   'compatible',
#   'marking',
#   'interstitial',
#   'scarring',
#   'chronic',
#   'base',
#   'seen',
#   'lung',
#   'disease',
#   'consolidation',
#   'within',
#   'pulmonary',
#   'size',
#   'heart'],
#  ['coronary',
#   'bypass',
#   'graft',
#   'artery',
#   'sternotomy',
#   'bony',
#   'finding',
#   'acute',
#   'change',
#   'airspace',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'pneumothora',
#   'normal'],
#  ['finding',
#   'vasculature',
#   'osseous',
#   'acute',
#   'cardiomediastinal',
#   'silhouette',
#   'clear',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['interstitial',
#   'bilateral',
#   'congestive',
#   'engorged',
#   'failure',
#   'fluid',
#   'blunting',
#   'bibasilar',
#   'basilar',
#   'costophrenic',
#   'infiltrates',
#   'present',
#   'pulmonary',
#   'edema',
#   'heart',
#   'large',
#   'pleural',
#   '02010',
#   '09',
#   '10'],
#  ['suggest',
#   'pneumonia',
#   'air',
#   'space',
#   'mediastinum',
#   'degenerative',
#   'spine',
#   'change',
#   'opacity',
#   'disease',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural'],
#  ['vascular_congestion_probable_mild',
#   'bibasilar_airspace_disease',
#   'interstitial_edema',
#   'right_greater_left',
#   'bilateral_pleural_effusion',
#   'cardiomegaly',
#   'bony',
#   'finding',
#   'stable',
#   'pulmonary',
#   'acute',
#   'pneumothora',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm'],
#  ['infrahilar',
#   'along',
#   'abnormality',
#   'granuloma',
#   'identified',
#   'vasculature',
#   'calcified',
#   'mild',
#   'seen',
#   'thoracic',
#   'degenerative',
#   'unremarkable',
#   'bony',
#   'stable',
#   'acute',
#   'right',
#   'spine',
#   'change',
#   'opacity',
#   'cardiomediastinal'],
#  ['scarring_atelectasis_right_midlung',
#   'mild_cardiomegaly',
#   'width',
#   'wellaerated',
#   'vasculature',
#   'normal',
#   'mediastinal',
#   'disease',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'acute',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['within_normal_limit',
#   'appear',
#   'suspicious',
#   'definite',
#   'pulmonary',
#   'visualized',
#   'intact',
#   'vascularity',
#   'osseous',
#   'structure',
#   'opacity',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute'],
#  ['prior_granulomatous_infection',
#   'testis',
#   'scattered',
#   'consistent',
#   'bilaterally',
#   'calcified',
#   'vascularity',
#   'unremarkable',
#   'bony',
#   'stable',
#   'structure',
#   'normal',
#   'cardiomediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary'],
#  ['right_midlung',
#   'resolution',
#   'inflammatoryinfectious',
#   'sulcal',
#   'resolved',
#   'described',
#   'previously',
#   'flattened',
#   'emphysematous',
#   'suggesting',
#   'previous',
#   'interval',
#   'hyperepanded',
#   'diaphragm',
#   'soft',
#   'tissue',
#   'prior',
#   'infiltrate',
#   'process',
#   'lung'],
#  ['abnormal',
#   'appearance',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'structure',
#   'opacity',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['piercings',
#   'curvilinear',
#   'shadow',
#   'breast',
#   'compatible',
#   'density',
#   'suspicious',
#   'pulmonary',
#   'cardiac',
#   'visualized',
#   'intact',
#   'vascularity',
#   'appear',
#   'osseous',
#   'structure',
#   'opacity',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'consolidation'],
#  ['left_lower_lobe',
#   'right_upper_lobe',
#   'andor',
#   'favoring',
#   'opacity',
#   'illdefined',
#   'suggests',
#   'concerning',
#   'scar',
#   'patchy',
#   'airspace',
#   'granulomatous',
#   'posterior',
#   'calcification',
#   'scarring',
#   'pneumonia',
#   'granuloma',
#   'vasculature',
#   'cardiomediastinal',
#   'silhouette'],
#  ['show',
#   'abnormality',
#   'pulmonary',
#   'space',
#   'vascularity',
#   'acute',
#   'limit',
#   'within',
#   'size',
#   'heart',
#   'lung',
#   'normal',
#   'pleural',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13'],
#  ['hyperepanded',
#   'fusion',
#   'overall',
#   'lung',
#   'cervical',
#   'spine',
#   'flattening',
#   'obstructive',
#   'previous',
#   'diaphragm',
#   'consistent',
#   'pneumothoraces',
#   'lower',
#   'clear',
#   'mediastinum',
#   'degenerative',
#   'without',
#   'change',
#   'contour',
#   'disease'],
#  ['low_lung_volume',
#   'significant',
#   'limited',
#   'eam',
#   'otherwise',
#   'appearance',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'structure',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'acute',
#   'pneumothora'],
#  ['several',
#   'old',
#   'skeletal',
#   'study',
#   'show',
#   'rib',
#   'unchanged',
#   'fracture',
#   'prior',
#   'mediastinum',
#   'left',
#   'structure',
#   'disease',
#   'clear',
#   'pulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal'],
#  ['intrathoracic',
#   'appears',
#   'area',
#   'appearance',
#   'intact',
#   'thoracic',
#   'spine',
#   'cardiomediastinal',
#   'silhouette',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'focal',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['stable_chronic',
#   'artifactual',
#   'coarse',
#   'reveals',
#   'cervical',
#   'projecting',
#   'without',
#   'right',
#   'ape',
#   'limited',
#   'evaluation',
#   'marking',
#   'anterior',
#   'posterior',
#   'interstitial',
#   'rib',
#   'view',
#   'grossly',
#   'negative',
#   'intact'],
#  ['focal_airspace_consolidation',
#   'hyperepanded',
#   'postoperative',
#   'suggestive',
#   'change',
#   'diffuse',
#   'obstructive',
#   'sternotomy',
#   'atherosclerotic',
#   'aortic',
#   'lung',
#   'mildly',
#   'vascular',
#   'calcification',
#   'degenerative',
#   'spine',
#   'disease',
#   'limit',
#   'within',
#   'size'],
#  ['right_basilar_subsegmental_atelectasis',
#   'stable_appearance',
#   'thoracic',
#   'osteopenia',
#   'loss',
#   'since',
#   'remain',
#   'vertebral',
#   'moderate',
#   'demonstrated',
#   'body',
#   'mid',
#   'scattered',
#   'surgical',
#   'clip',
#   'sternotomy',
#   'eam',
#   'appears',
#   'minimal',
#   'tortuous'],
#  ['low',
#   'volume',
#   'infiltrate',
#   'mediastinum',
#   'lung',
#   'unremarkable',
#   'without',
#   'disease',
#   'clear',
#   'cardiopulmonary',
#   'heart',
#   'acute',
#   'pneumothora',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['displaced_rib_fracture_demonstrated',
#   'mild_cardiomegaly',
#   'favoring',
#   'caliber',
#   'scar',
#   'vertebral',
#   'body',
#   'specifically',
#   'otherwise',
#   'grossly',
#   'bilaterally',
#   'atelectasis',
#   'vasculature',
#   'visualized',
#   'intact',
#   'mild',
#   'finding',
#   'acute',
#   'opacity',
#   'clear'],
#  ['hyperdense',
#   'subcentimeter',
#   'alternatively',
#   'end',
#   'two',
#   'nodular',
#   'represent',
#   'may',
#   'granuloma',
#   'infiltrate',
#   'noted',
#   'calcified',
#   'mediastinum',
#   'lung',
#   'unremarkable',
#   'without',
#   'right',
#   'opacity',
#   'disease',
#   'clear'],
#  ['lateral_right_base',
#   'oblong_opacity',
#   'illdefined',
#   'eact',
#   'suggested',
#   'unclear',
#   'present',
#   'right_base',
#   'based',
#   'clearing',
#   'confirm',
#   'stability',
#   'remainder',
#   'somewhat',
#   'appear',
#   'followup',
#   'previous',
#   'study',
#   'eam',
#   'represent'],
#  ['identified',
#   'convincing',
#   'engorgement',
#   'image',
#   'vascular',
#   'base',
#   'granuloma',
#   'calcified',
#   'appear',
#   'unremarkable',
#   'bony',
#   'finding',
#   'acute',
#   'right',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within'],
#  ['tomogram',
#   'largely',
#   'previously',
#   'since',
#   'eventration',
#   'computed',
#   'obstructive',
#   'previous',
#   'hemidiaphragm',
#   'hyperepanded',
#   'infiltrates',
#   'mass',
#   'unchanged',
#   'chronic',
#   'pulmonary',
#   'identified',
#   'finding',
#   'left',
#   'change',
#   'disease'],
#  ['cava',
#   'vena',
#   'mid',
#   'superior',
#   'tip',
#   'intact',
#   'chest',
#   'left',
#   'mediastinal',
#   'contour',
#   'silhouette',
#   'abnormality',
#   'clear',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'lung',
#   'acute'],
#  ['findingsopacitiesinfiltrates',
#   'radiographic',
#   'small',
#   'base',
#   'granuloma',
#   'noted',
#   'calcified',
#   'mediastinum',
#   'unremarkable',
#   'bony',
#   'stable',
#   'left',
#   'acute',
#   'structure',
#   'evidence',
#   'disease',
#   'cardiopulmonary',
#   'heart',
#   'lung',
#   '02010'],
#  ['process',
#   'intact',
#   'mediastinum',
#   'bony',
#   'structure',
#   'clear',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['area',
#   'intact',
#   'osseous',
#   'structure',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10'],
#  ['increased_interstitial_opacity',
#   'cardiomegaly',
#   'represent',
#   'interstitial',
#   'edema',
#   'osseous',
#   'large',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'limit',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['intact',
#   'osseous',
#   'structure',
#   'mediastinal',
#   'silhouette',
#   'abnormality',
#   'clear',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['finding',
#   'vasculature',
#   'bony',
#   'acute',
#   'cardiomediastinal',
#   'airspace',
#   'silhouette',
#   'disease',
#   'clear',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['hyperepanded',
#   'suggestive',
#   'emphysema',
#   'suspicious',
#   'mass',
#   'consolidation',
#   'nodule',
#   'air',
#   'space',
#   'focal',
#   'seen',
#   'lung',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'pulmonary',
#   'size',
#   'heart',
#   'pneumothora',
#   'normal'],
#  ['lingular',
#   'pneumothoraces',
#   'hilar',
#   'pulmonary',
#   'normal',
#   'granuloma',
#   'air',
#   'space',
#   'calcified',
#   'vascularity',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'clear',
#   'consolidation',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute'],
#  ['several',
#   'region',
#   'trachea',
#   'midline',
#   'bilateral',
#   'hilar',
#   'negative',
#   'granuloma',
#   'calcified',
#   'airspace',
#   'abnormality',
#   'consolidation',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural'],
#  ['pulmonary_disease',
#   'hyperinflation',
#   'obstructive',
#   'skeletal',
#   'chronic',
#   'mediastinum',
#   'lung',
#   'structure',
#   'normal',
#   'clear',
#   'heart',
#   'acute',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11'],
#  ['tuberculosis',
#   'active',
#   'vasculature',
#   'intact',
#   'appear',
#   'evidence',
#   'airspace',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['shoulder',
#   'glenohumeral',
#   'osteoarthritis',
#   'recess',
#   'prosthetic',
#   'aillary',
#   'degenerative',
#   'possible',
#   'left',
#   'body',
#   'finding',
#   'right',
#   'spine',
#   'disease',
#   'clear',
#   'within',
#   'pulmonary',
#   'size',
#   'heart',
#   'lung'],
#  ['left_upper_lobe',
#   'therapy',
#   'week',
#   'appropriate',
#   'eclude',
#   'indicated',
#   'underlying',
#   'perihilar',
#   'region',
#   'followup',
#   'radiograph',
#   'pneumonia',
#   'identified',
#   'mediastinum',
#   'opacity',
#   'abnormality',
#   'limit',
#   'within',
#   'pulmonary',
#   'heart'],
#  ['remains',
#   'slight',
#   'continued',
#   'slightly',
#   'failure',
#   'remain',
#   'tortuous',
#   'infiltrates',
#   'mass',
#   'cardiomegaly',
#   'pneumonia',
#   'aorta',
#   'large',
#   'evidence',
#   'pulmonary',
#   'size',
#   'heart',
#   'lung',
#   'normal',
#   '02010'],
#  ['process',
#   'intact',
#   'mediastinum',
#   'bony',
#   'structure',
#   'clear',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['pleural_thickening',
#   'present_left',
#   'left_upper_lobe',
#   'previous',
#   'collapsed',
#   'pneumatoceles',
#   'retracted',
#   'stranding',
#   'superiorly',
#   'additionally',
#   'collapse',
#   'outside',
#   'hilum',
#   'parenchymal',
#   'finding',
#   'associated',
#   'similar',
#   'tuberculosis',
#   'ape',
#   'eamination'],
#  ['finding',
#   'vasculature',
#   'bony',
#   'acute',
#   'cardiomediastinal',
#   'airspace',
#   'silhouette',
#   'disease',
#   'clear',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['specifically',
#   'abnormality',
#   'thora',
#   'upper',
#   'bilaterally',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'acute',
#   'structure',
#   'without',
#   'evidence',
#   'cardiomediastinal',
#   'silhouette',
#   'clear',
#   'consolidation',
#   'limit',
#   'cardiopulmonary',
#   'size',
#   'focal'],
#  ['cardiac',
#   'airway',
#   'configuration',
#   'show',
#   'frontal',
#   'central',
#   'view',
#   'volume',
#   'pulmonary',
#   'active',
#   'lateral',
#   'vasculature',
#   'chest',
#   'normal',
#   'mediastinal',
#   'pleural',
#   'contour',
#   'silhouette',
#   'disease',
#   'size'],
#  ['streaky_bibasilar',
#   'low_lung_volume',
#   'subsegmental',
#   'opacity',
#   'infiltrate',
#   'atelectasis',
#   'vasculature',
#   'osseous',
#   'finding',
#   'cardiomediastinal',
#   'airspace',
#   'silhouette',
#   'limit',
#   'within',
#   'pulmonary',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['subsegmental_atelectasis_scarring',
#   'focal_airspace_consolidation',
#   'hyperepanded',
#   'lingular',
#   'lingula',
#   'suggestive',
#   'emphysema',
#   'atherosclerotic',
#   'aortic',
#   'vascular',
#   'calcification',
#   'lung',
#   'degenerative',
#   'spine',
#   'change',
#   'opacity',
#   'limit',
#   'within',
#   'size',
#   'heart'],
#  ['near_anterior_right_first',
#   'atelectasis_right_lung_base',
#   'vague',
#   'minimal',
#   'calcification',
#   'costicartilage_junction',
#   'first_rib',
#   'relating',
#   'rib_costicartilage',
#   'may',
#   'artifact',
#   'inserted',
#   'peripherally',
#   'distal',
#   'junction',
#   'leftsided',
#   'line',
#   'nodular',
#   'vena',
#   'opacity'],
#  ['mild_cardiomegaly',
#   'cardio',
#   'intact',
#   'appear',
#   'unremarkable',
#   'bony',
#   'structure',
#   'mediastinal',
#   'airspace',
#   'silhouette',
#   'disease',
#   'focal',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11'],
#  ['airspace_disease',
#   'low_lung_volume',
#   'right',
#   'bronchovascular',
#   'crowding',
#   'basilar',
#   'base',
#   'upper',
#   'mild',
#   'limit',
#   'size',
#   'heart',
#   'pneumothora',
#   'normal',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11'],
#  ['finding',
#   'vasculature',
#   'bony',
#   'acute',
#   'cardiomediastinal',
#   'airspace',
#   'silhouette',
#   'disease',
#   'clear',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['evidence_focal_airspace',
#   'emphysematous_change',
#   'moderate',
#   'aortic',
#   'scarringemphysematous',
#   'ectasia',
#   'loss',
#   'demonstrate',
#   'hemidiaphragms',
#   'flattening',
#   'secondary',
#   'blunting',
#   'atherosclerotic',
#   'costophrenic',
#   'anterior',
#   'posterior',
#   'calcification',
#   'edema',
#   'visualized',
#   'intact'],
#  ['pneumothora_pleural_effusion',
#   'right_middle_lobe',
#   'representative',
#   'infiltrate',
#   'increased',
#   'cardiac',
#   'left',
#   'opacity',
#   'contour',
#   'clear',
#   'lung',
#   'normal',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm'],
#  ['show',
#   'abnormality',
#   'pulmonary',
#   'space',
#   'vascularity',
#   'acute',
#   'limit',
#   'within',
#   'size',
#   'heart',
#   'lung',
#   'normal',
#   'pleural',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13'],
#  ['thoracic_spine',
#   'scoliosis',
#   'trachea',
#   'midline',
#   'lower',
#   'degenerative',
#   'change',
#   'abnormality',
#   'clear',
#   'cardiopulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'normal',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['trachea',
#   'midline',
#   'eam',
#   'chest',
#   'normal',
#   'clear',
#   'heart',
#   'lung',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm',
#   '15'],
#  ['present',
#   'bandlike',
#   'appear',
#   'quadrant',
#   'abdomen',
#   'surgical',
#   'clip',
#   'represent',
#   'disease',
#   'small',
#   'scarring',
#   'area',
#   'view',
#   'free',
#   'active',
#   'lateral',
#   'upper',
#   'vascularity',
#   'seen',
#   'degenerative'],
#  ['focal_airspace_disease_right',
#   'middle_lobe',
#   'follow',
#   'ensure',
#   'concerning',
#   'resolution',
#   'recommend',
#   'pneumonia',
#   'contour',
#   'size',
#   'heart',
#   'pneumothora',
#   'normal',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['discrete',
#   'descending',
#   'tortuosity',
#   'adenopathy',
#   'disease',
#   'free',
#   'present',
#   'active',
#   'nodule',
#   'aorta',
#   'noted',
#   'vascularity',
#   'appear',
#   'mild',
#   'seen',
#   'thoracic',
#   'degenerative',
#   'spine',
#   'evidence',
#   'change'],
#  ['clearing_left_base_airspace',
#   'right_lung',
#   'right_pleural_effusion',
#   'present',
#   'improvement',
#   'inflammatory',
#   'removed',
#   'status',
#   'overt',
#   'continued',
#   'defibrillator',
#   'post',
#   'airspace_disease',
#   'venous',
#   'failure',
#   'line',
#   'sternotomy',
#   'patient',
#   'central',
#   'represent'],
#  ['finding',
#   'alveolar',
#   'edema',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['anteroposterior',
#   'bronchovascular',
#   'crowding',
#   'bibasilar',
#   'low',
#   'view',
#   'volume',
#   'atelectasis',
#   'appear',
#   'bony',
#   'finding',
#   'acute',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary'],
#  ['vagal_nerve_stimulator_overlying',
#   'left_chest',
#   'right_lung_base',
#   'atelectasis',
#   'representing',
#   'appears',
#   'minimal',
#   'otherwise',
#   'fracture',
#   'intact',
#   'without',
#   'opacity',
#   'clear',
#   'within',
#   'size',
#   'heart',
#   'lung',
#   'pneumothora',
#   'normal',
#   '02010'],
#  ['minimally_increased',
#   'opacity_bilaterally_prominent_lung',
#   'base',
#   'nonspecific',
#   'infectious',
#   'atypical',
#   'subsegmental',
#   'versus',
#   'represent',
#   'interstitial',
#   'may',
#   'grossly',
#   'edema',
#   'air',
#   'atelectasis',
#   'space',
#   'process',
#   'intact',
#   'osseous',
#   'mild'],
#  ['marking',
#   'granulomatous',
#   'vascular',
#   'soft',
#   'radiographic',
#   'tissue',
#   'hilar',
#   'area',
#   'prior',
#   'present',
#   'process',
#   'osseous',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'acute',
#   'without',
#   'spine',
#   'evidence',
#   'change'],
#  ['cardiac',
#   'airway',
#   'configuration',
#   'show',
#   'frontal',
#   'central',
#   'view',
#   'volume',
#   'pulmonary',
#   'active',
#   'lateral',
#   'vasculature',
#   'chest',
#   'normal',
#   'mediastinal',
#   'pleural',
#   'contour',
#   'silhouette',
#   'disease',
#   'size'],
#  ['identified',
#   'engorgement',
#   'vascular',
#   'appear',
#   'unremarkable',
#   'bony',
#   'acute',
#   'change',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'pneumothora'],
#  ['within_normal_limit',
#   'appear',
#   'suspicious',
#   'definite',
#   'pulmonary',
#   'visualized',
#   'intact',
#   'vascularity',
#   'osseous',
#   'structure',
#   'opacity',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute'],
#  ['compared_prior',
#   'airspace_disease',
#   'significantly',
#   'persistent',
#   'infection',
#   'significant',
#   'bibasilar',
#   'represent',
#   'bilateral',
#   'lower',
#   'enlarged',
#   'may',
#   'lobe',
#   'edema',
#   'cardiac',
#   'mild',
#   'bony',
#   'stable',
#   'change',
#   'silhouette'],
#  ['stent',
#   'coronary',
#   'artery',
#   'inflated',
#   'normally',
#   'bone',
#   'process',
#   'visualized',
#   'acute',
#   'without',
#   'evidence',
#   'cardiomediastinal',
#   'airspace',
#   'contour',
#   'silhouette',
#   'disease',
#   'abnormality',
#   'limit',
#   'within',
#   'cardiopulmonary'],
#  ['left_lower',
#   'airspace_disease',
#   'remainder',
#   'breast',
#   'surgical',
#   'clip',
#   'overlying',
#   'atherosclerotic',
#   'lobe',
#   'aorta',
#   'mediastinum',
#   'lung',
#   'stable',
#   'right',
#   'clear',
#   'within',
#   'size',
#   'heart',
#   'pneumothora',
#   'normal'],
#  ['epanded',
#   'well',
#   'radiographic',
#   'active',
#   'edema',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'structure',
#   'without',
#   'evidence',
#   'cardiomediastinal',
#   'silhouette',
#   'disease',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'lung',
#   'pneumothora'],
#  ['abnormality',
#   'bilaterally',
#   'cardiac',
#   'vasculature',
#   'bony',
#   'acute',
#   'normal',
#   'mediastinal',
#   'silhouette',
#   'clear',
#   'pulmonary',
#   'cardiopulmonary',
#   'lung',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['central_bronchovascular_crowding_without',
#   'low_lung_volume_bilaterally',
#   'pneumothoraces',
#   'focal',
#   'thoracic',
#   'degenerative',
#   'spine',
#   'change',
#   'cardiomediastinal',
#   'silhouette',
#   'disease',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09'],
#  ['may_represent_infiltrate',
#   'small_right_jutahilar_opacity',
#   'setting',
#   'engorged',
#   'treatment',
#   'following',
#   'appropriate',
#   'document',
#   'aerated',
#   'followup',
#   'recommended',
#   'well',
#   'interval',
#   'central',
#   'otherwise',
#   'enlarged',
#   'vasculature',
#   'visualized',
#   'osseous',
#   'chest'],
#  ['left_upper_lobe',
#   'possibility',
#   'ecluded',
#   'hyperinflated',
#   'tuberculosis',
#   'patchy',
#   'infiltrate',
#   'mediastinum',
#   'seen',
#   'unremarkable',
#   'opacity',
#   'size',
#   'heart',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09'],
#  ['mildly',
#   'obtained',
#   'tortuous',
#   'anterior',
#   'posterior',
#   'enlarged',
#   'view',
#   'limit',
#   'aorta',
#   'lateral',
#   'upper',
#   'air',
#   'space',
#   'thoracic',
#   'chest',
#   'normal',
#   'disease',
#   'consolidation',
#   'within',
#   'pulmonary'],
#  ['eam',
#   'chest',
#   'without',
#   'normal',
#   'clear',
#   'size',
#   'heart',
#   'lung',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm',
#   '15'],
#  ['clear',
#   'space',
#   'normal',
#   'mediastinal',
#   'contour',
#   'disease',
#   'pulmonary',
#   'cardiopulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'pleural',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13'],
#  ['air',
#   'space',
#   'intact',
#   'osseous',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'finding',
#   'structure',
#   'spine',
#   'change',
#   'opacity',
#   'cardiomediastinal',
#   'silhouette',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora'],
#  ['cardio',
#   'specifically',
#   'abnormality',
#   'thora',
#   'bilaterally',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'acute',
#   'structure',
#   'without',
#   'evidence',
#   'mediastinal',
#   'silhouette',
#   'clear',
#   'consolidation',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'pneumothora'],
#  ['lower_thoracic',
#   'slight_deformity',
#   'ageindeterminate',
#   'body',
#   'eam',
#   'suggest',
#   'otherwise',
#   'negative',
#   'pneumonia',
#   'air',
#   'space',
#   'mediastinum',
#   'mild',
#   'thoracic',
#   'degenerative',
#   'spine',
#   'change',
#   'opacity',
#   'limit',
#   'within'],
#  ['appearance',
#   'visualized',
#   'unremarkable',
#   'opacity',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10'],
#  ['cardiac',
#   'monitor',
#   'eternal',
#   'airway',
#   'lead',
#   'configuration',
#   'overlying',
#   'show',
#   'frontal',
#   'central',
#   'view',
#   'pulmonary',
#   'active',
#   'lateral',
#   'vasculature',
#   'chest',
#   'normal',
#   'pleural',
#   'airspace',
#   'silhouette'],
#  ['focal_area_scarring_atelectasis',
#   'lingula',
#   'otherwise',
#   'infiltrate',
#   'identified',
#   'process',
#   'without',
#   'contour',
#   'clear',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'effusion',
#   '02010'],
#  ['banding',
#   'gastric',
#   'procedure',
#   'tubing',
#   'overlies',
#   'projection',
#   'quadrant',
#   'catheter',
#   'show',
#   'suggest',
#   'abnormality',
#   'prior',
#   'pulmonary',
#   'appearance',
#   'lateral',
#   'upper',
#   'space',
#   'vascularity',
#   'left',
#   'acute'],
#  ['injury',
#   'demonstrated',
#   'nondisplaced',
#   'characteristic',
#   'note',
#   'please',
#   'related',
#   'widening',
#   'vascular',
#   'definite',
#   'fracture',
#   'may',
#   'appearance',
#   'vascularity',
#   'osseous',
#   'finding',
#   'acute',
#   'mediastinal',
#   'consolidation',
#   'limit'],
#  ['blunted',
#   'hypoinflated',
#   'costophrenic',
#   'infiltrate',
#   'mediastinum',
#   'seen',
#   'unremarkable',
#   'consolidation',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'normal',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['soft',
#   'tissue',
#   'pneumothoraces',
#   'abnormality',
#   'bilaterally',
#   'infiltrate',
#   'bony',
#   'acute',
#   'cardiomediastinal',
#   'silhouette',
#   'clear',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['consolidative',
#   'radiographic',
#   'appearance',
#   'visualized',
#   'intact',
#   'appear',
#   'osseous',
#   'structure',
#   'evidence',
#   'opacity',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal'],
#  ['chronic_emphysematous_lung_disease',
#   'thickeningscar',
#   'recess',
#   'hyperlucency',
#   'identified',
#   'calcified',
#   'stable',
#   'hyperepansion',
#   'flattening',
#   'well',
#   'blunting',
#   'mediastinal',
#   'basilar',
#   'costophrenic',
# ...
#   'cardiomediastinal',
#   'airspace',
#   'contour',
#   'silhouette',
#   'disease',
#   'abnormality',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'lung',
#   'pneumothora'],
#  ['negative_acute',
#   'bone',
#   'abnormality',
#   'large',
#   'cardiomediastinal',
#   'contour',
#   'silhouette',
#   'consolidation',
#   'size',
#   'focal',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['right_hemidiaphragm',
#   'mild',
#   'along',
#   'elevated',
#   'elevation',
#   'visible',
#   'mildly',
#   'otherwise',
#   'vasculature',
#   'seen',
#   'thoracic',
#   'degenerative',
#   'unremarkable',
#   'spine',
#   'change',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'consolidation'],
#  ['finding',
#   'similar',
#   'eventration',
#   'borderline',
#   'typical',
#   'hemidiaphragm',
#   'alveolar',
#   'definite',
#   'enlarged',
#   'edema',
#   'noted',
#   'appear',
#   'seen',
#   'right',
#   'mediastinal',
#   'contour',
#   'consolidation',
#   'pulmonary',
#   'cardiopulmonary',
#   'size'],
#  ['hemidiaphragm_stable',
#   'prior_eam',
#   'left',
#   'distending',
#   'ago',
#   'atelectasisscarring',
#   'incidentally',
#   'year',
#   'stomach',
#   'amount',
#   'associated',
#   'elevated',
#   'represents',
#   'elevation',
#   'opacity',
#   'also',
#   'sternotomy',
#   'basilar',
#   'appears',
#   'unchanged'],
#  ['disease',
#   'free',
#   'active',
#   'vascularity',
#   'appear',
#   'seen',
#   'evidence',
#   'airspace',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['low_lung_volume',
#   'indistinctness',
#   'overload',
#   'accentuated',
#   'congestion',
#   'probable',
#   'failure',
#   'consists',
#   'due',
#   'also',
#   'normally',
#   'versus',
#   'bibasilar',
#   'radiograph',
#   'frontal',
#   'eamination',
#   'vascular',
#   'present',
#   'volume',
#   'lateral'],
#  ['cm_diameter_within_posterior',
#   'round_opacity_measuring_2',
#   'region',
#   'intravenous',
#   'paratracheal',
#   'calcified',
#   'mediastinum',
#   'contrast',
#   'perihilar',
#   'recommend',
#   'tomography',
#   'computed',
#   'evaluation',
#   'density',
#   'represent',
#   'pneumothoraces',
#   'may',
#   'within',
#   'nodule',
#   'granuloma'],
#  ['ankle',
#   'calcaneal',
#   'left_ankle',
#   'midfoot_degenerative_change',
#   'right_elbow_forearm_acute',
#   'soft_tissue',
#   'acute_fracture',
#   'acute_traumatic',
#   'around',
#   'enthesopathy',
#   'enthesophyte',
#   'mortise',
#   'plantar',
#   'traumatic_finding',
#   'fracture_dislocation',
#   'dislocation',
#   'technique',
#   'joint',
#   'chest',
#   'unremarkable'],
#  ['lingular',
#   'perihilar',
#   'scattered',
#   'lymph',
#   'scarring',
#   'bilateral',
#   'abnormality',
#   'granuloma',
#   'identified',
#   'vasculature',
#   'calcified',
#   'large',
#   'bony',
#   'stable',
#   'mediastinal',
#   'contour',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary'],
#  ['interstitial_lung_disease',
#   'overlying',
#   'primarily',
#   'electronic',
#   'prior',
#   'reticular',
#   'there',
#   'increasing',
#   'worsening',
#   'confirm',
#   'high',
#   'placement',
#   'lobar',
#   'device',
#   'reveals',
#   'distal',
#   'wall',
#   'since',
#   'resolution',
#   'lead'],
#  ['visible',
#   'free',
#   'quadrant',
#   'intraperitoneal',
#   'fluid',
#   'surgical',
#   'clip',
#   'diaphragm',
#   'infiltrates',
#   'radiographic',
#   'mass',
#   'grossly',
#   'nodule',
#   'normal',
#   'upper',
#   'air',
#   'process',
#   'seen',
#   'right',
#   'mediastinal'],
#  ['finding',
#   'bronchovascular',
#   'crowding',
#   'typical',
#   'alveolar',
#   'definite',
#   'hilar',
#   'edema',
#   'seen',
#   'stable',
#   'without',
#   'mediastinal',
#   'contour',
#   'consolidation',
#   'limit',
#   'within',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart'],
#  ['abnormality',
#   'upper',
#   'large',
#   'bony',
#   'normal',
#   'mediastinal',
#   'contour',
#   'clear',
#   'limit',
#   'cardiopulmonary',
#   'size',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10'],
#  ['specifically',
#   'abnormality',
#   'thora',
#   'bilaterally',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'acute',
#   'structure',
#   'without',
#   'evidence',
#   'cardiomediastinal',
#   'silhouette',
#   'clear',
#   'consolidation',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'pneumothora',
#   'pleural'],
#  ['hyperinflated_lung',
#   'inspiratory',
#   'trapping',
#   'irregular',
#   'retrosternal',
#   'flattened',
#   'appearing',
#   'versus',
#   'marking',
#   'scattered',
#   'typical',
#   'increased',
#   'alveolar',
#   'diaphragm',
#   'interstitial',
#   'definite',
#   'chronic',
#   'edema',
#   'air',
#   'seen'],
#  ['low_lung_volume',
#   'cardiac',
#   'large',
#   'without',
#   'opacity',
#   'mediastinal',
#   'contour',
#   'silhouette',
#   'disease',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'focal',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09'],
#  ['appreciated',
#   'fluid',
#   'cardiac',
#   'vasculature',
#   'mediastinum',
#   'chest',
#   'unremarkable',
#   'silhouette',
#   'clear',
#   'limit',
#   'within',
#   'pulmonary',
#   'lung',
#   'pneumothora',
#   'normal',
#   'pleural',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['interstitial_prominence_basilar_patchy',
#   'maybe',
#   'useful',
#   'nonspecific',
#   'cardiac',
#   'outside',
#   'monitor',
#   'fibrosis',
#   'eternal',
#   'film',
#   'andor',
#   'airway',
#   'lead',
#   'comparison',
#   'due',
#   'configuration',
#   'previous',
#   'airspace',
#   'overlying',
#   'show'],
#  ['old',
#   'rib',
#   'fracture',
#   'right',
#   'abnormality',
#   'clear',
#   'cardiopulmonary',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['biapical_opacity',
#   'scarring',
#   'mastectomy',
#   'aillary',
#   'several',
#   'postoperative',
#   'rightsided',
#   'right',
#   'possibly',
#   'cava',
#   'vena',
#   'superior',
#   'catheter',
#   'tip',
#   'surgical',
#   'clip',
#   'otherwise',
#   'lower',
#   'noted',
#   'appear'],
#  ['stable',
#   'chronic',
#   'lower',
#   'lobe',
#   'granuloma',
#   'calcified',
#   'mediastinum',
#   'thoracic',
#   'degenerative',
#   'unremarkable',
#   'left',
#   'spine',
#   'change',
#   'airspace',
#   'disease',
#   'abnormality',
#   'within',
#   'cardiopulmonary',
#   'size',
#   'focal'],
#  ['thora',
#   'unremarkable',
#   'bony',
#   'without',
#   'cardiomediastinal',
#   'silhouette',
#   'abnormality',
#   'clear',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['right_lung_base_airspace',
#   't12',
#   'atelectasis',
#   'wedge',
#   'lung_base',
#   'left',
#   'deformity',
#   'frontal',
#   'consistent',
#   'disease',
#   'base',
#   'mild',
#   'opacity',
#   'mediastinal',
#   'contour',
#   'size',
#   'heart',
#   'pneumothora',
#   'normal',
#   'pleural'],
#  ['appearance',
#   'chest',
#   'normal',
#   'cardiomediastinal',
#   'silhouette',
#   'clear',
#   'size',
#   'lung',
#   'pneumothora',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm',
#   '15'],
#  ['pneumothoraces',
#   'hilar',
#   'normal',
#   'air',
#   'space',
#   'vascularity',
#   'mediastinal',
#   'contour',
#   'abnormality',
#   'clear',
#   'consolidation',
#   'pulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'pleural',
#   'effusion',
#   '02010'],
#  ['abnormality',
#   'bony',
#   'acute',
#   'cardiomediastinal',
#   'silhouette',
#   'consolidation',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'focal',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['cardiomegaly_especially_enlarged_left',
#   'mitral_valve_surgery',
#   'scarring_left_midlung',
#   'atrium',
#   'continued',
#   'postoperative',
#   'amount',
#   'sternotomy',
#   'interval',
#   'small',
#   'pneumothoraces',
#   'change',
#   'consolidation',
#   'focal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['adenopathy',
#   'mass',
#   'nodule',
#   'normal',
#   'pneumonia',
#   'edema',
#   'chest',
#   'clear',
#   'size',
#   'heart',
#   'lung',
#   'pneumothora',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13'],
#  ['prosthesis',
#   'breast',
#   'hyperinflation',
#   'obstructive',
#   'skeletal',
#   'bilateral',
#   'chronic',
#   'mediastinum',
#   'structure',
#   'normal',
#   'disease',
#   'clear',
#   'pulmonary',
#   'heart',
#   'lung',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11'],
#  ['prior',
#   'round',
#   'calcific',
#   'reveal',
#   'density',
#   'trachea',
#   'midline',
#   'eamination',
#   'granulomatous',
#   'consistent',
#   'acute',
#   'otherwise',
#   'unchanged',
#   'abnormality',
#   'infiltrate',
#   'visualized',
#   'lung',
#   'bony',
#   'structure',
#   'without'],
#  ['epiratory',
#   'repeated',
#   'one',
#   'demonstrate',
#   'anteroposterior',
#   'obtained',
#   'aortic',
#   'eamination',
#   'infiltrates',
#   'view',
#   'lateral',
#   'appear',
#   'chest',
#   'unremarkable',
#   'contour',
#   'silhouette',
#   'disease',
#   'pulmonary',
#   'size',
#   'focal'],
#  ['area',
#   'thoracic',
#   'degenerative',
#   'spine',
#   'evidence',
#   'change',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09'],
#  ['interstitial_marking',
#   'bronchovascular_crowding',
#   'prominent',
#   'central',
#   'hypoventilation',
#   'include',
#   'inflammatory',
#   'etiology',
#   'consideration',
#   'considering',
#   'infectious',
#   'technical',
#   'factor',
#   'differential',
#   'mild',
#   'correlation',
#   'clinical',
#   'secondary',
#   'recommended',
#   'demonstrated'],
#  ['soft_tissue_density_upper',
#   'eam',
#   'enlargementprominence',
#   'glenohumeral',
#   'follow',
#   'performed',
#   'recent',
#   'mediastinum',
#   'degenerative',
#   'joint',
#   'related',
#   'similar',
#   'however',
#   'represents',
#   'recommend',
#   'opacity',
#   'compared',
#   'tomography',
#   'computed',
#   'evaluation'],
#  ['negative_acute',
#   'bone',
#   'abnormality',
#   'large',
#   'cardiomediastinal',
#   'contour',
#   'silhouette',
#   'consolidation',
#   'size',
#   'focal',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12'],
#  ['cardiac',
#   'perhaps',
#   'incidental',
#   'azygos',
#   'monitor',
#   'note',
#   'eternal',
#   'fissure',
#   'cholecystectomy',
#   'quadrant',
#   'airway',
#   'lead',
#   'configuration',
#   'surgical',
#   'clip',
#   'overlying',
#   'show',
#   'frontal',
#   'central',
#   'view'],
#  ['airspace_opacity',
#   'basal',
#   'right',
#   'basilar',
#   'intact',
#   'mediastinal',
#   'contour',
#   'silhouette',
#   'limit',
#   'within',
#   'size',
#   'heart',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th'],
#  ['opacity_left',
#   'base',
#   'moderately',
#   'typical',
#   'alveolar',
#   'definite',
#   'otherwise',
#   'enlarged',
#   'cardiomegaly',
#   'edema',
#   'atelectasis',
#   'seen',
#   'finding',
#   'stable',
#   'mediastinal',
#   'contour',
#   'consolidation',
#   'pulmonary',
#   'size',
#   'focal'],
#  ['low',
#   'volume',
#   'appearance',
#   'visualized',
#   'unremarkable',
#   'bony',
#   'structure',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'abnormality',
#   'consolidation',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal'],
#  ['lung_grossly_clear',
#   'degraded',
#   'motion',
#   'limited',
#   'study',
#   'patient',
#   'mildly',
#   'pneumothoraces',
#   'view',
#   'lateral',
#   'mediastinum',
#   'degenerative',
#   'spine',
#   'change',
#   'contour',
#   'size',
#   'heart',
#   'normal',
#   'pleural',
#   'effusion'],
#  ['pleural_effusion',
#   'interstitial',
#   'predominantly',
#   'prominence',
#   'diffuse',
#   'central',
#   'soft',
#   'tissue',
#   'pneumothoraces',
#   'bilateral',
#   'enlarged',
#   'base',
#   'cardiomegaly',
#   'pulmonary',
#   'edema',
#   'bilaterally',
#   'vasculature',
#   'mild',
#   'unremarkable',
#   'opacity'],
#  ['costophrenic_consistent_small',
#   'effusion_andor_pleural_scarring',
#   'right_fissure_minimal_blunting',
#   'right_midlung_zone',
#   'posterior',
#   'observed',
#   'pleural_scarring',
#   'cardiomegaly',
#   'earlier',
#   'parenchyma',
#   'curvilinear',
#   'mild',
#   'detroscoliosis',
#   'right',
#   'thickening',
#   'compared',
#   'versus',
#   'study',
#   'density',
#   'minimal'],
#  ['pneumothoraces',
#   'clear',
#   'mediastinum',
#   'lung',
#   'contour',
#   'size',
#   'heart',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm',
#   '15',
#   '15_cm_nodule'],
#  ['remain',
#   'adenopathy',
#   'infiltrates',
#   'bilateral',
#   'unchanged',
#   'hilar',
#   'enlarged',
#   'free',
#   'stable',
#   'left',
#   'right',
#   'size',
#   'heart',
#   'lung',
#   'normal',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11'],
#  ['denser',
#   'adjacent',
#   'middle',
#   'endplate',
#   'inflated',
#   'normally',
#   'radiographic',
#   'lobe',
#   'nodule',
#   'process',
#   'calcified',
#   'degenerative',
#   'without',
#   'right',
#   'spine',
#   'evidence',
#   'change',
#   'cardiomediastinal',
#   'airspace',
#   'contour'],
#  ['interpretation',
#   'hour',
#   'available',
#   'associated',
#   'subsegmental',
#   'bronchovascular',
#   'crowding',
#   'radiograph',
#   'basilar',
#   'low',
#   'area',
#   'volume',
#   'atelectasis',
#   'vasculature',
#   'cardiomediastinal',
#   'silhouette',
#   'abnormality',
#   'consolidation',
#   'limit',
#   'within'],
#  ['evidence',
#   'disease',
#   'radiographic',
#   'cardiac',
#   'large',
#   'unremarkable',
#   'without',
#   'mediastinal',
#   'airspace',
#   'contour',
#   'clear',
#   'limit',
#   'within',
#   'cardiopulmonary',
#   'focal',
#   'lung',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural'],
#  ['cardiothoracic',
#   'seen',
#   'consists',
#   'significant',
#   'sternotomy',
#   'radiograph',
#   'interval',
#   'frontal',
#   'eamination',
#   'unchanged',
#   'grossly',
#   'lateral',
#   'granuloma',
#   'calcified',
#   'chest',
#   'right',
#   'change',
#   'cardiomediastinal',
#   'contour',
#   'disease'],
#  ['visible',
#   'bibasilar',
#   'unfolded',
#   'intraperitoneal',
#   'streaky',
#   'versus',
#   'fluid',
#   'diaphragm',
#   'infiltrates',
#   'otherwise',
#   'mass',
#   'enlarged',
#   'free',
#   'cardiomegaly',
#   'grossly',
#   'nodule',
#   'aorta',
#   'air',
#   'atelectasis',
#   'mild'],
#  ['right_lateral',
#   'subcutaneous_emphysema',
#   'neck',
#   'upper',
#   'noted',
#   'abdominal',
#   'chest',
#   'along',
#   'left',
#   'quadrant',
#   'abdomen',
#   'surgical',
#   'suspicious',
#   'soft',
#   'tissue',
#   'pulmonary',
#   'lateral',
#   'bilaterally',
#   'identified',
#   'visualized'],
#  ['specifically_evidence',
#   'cardio',
#   'rib',
#   'abnormality',
#   'fracture',
#   'thora',
#   'bilaterally',
#   'visualized',
#   'osseous',
#   'unremarkable',
#   'acute',
#   'structure',
#   'without',
#   'mediastinal',
#   'silhouette',
#   'clear',
#   'consolidation',
#   'cardiopulmonary',
#   'focal',
#   'lung'],
#  ['removal',
#   'inserted',
#   'peripherally',
#   'persistent',
#   'elevation',
#   'catheter',
#   'hemidiaphragm',
#   'interval',
#   'central',
#   'grossly',
#   'visualized',
#   'intact',
#   'large',
#   'left',
#   'without',
#   'right',
#   'opacity',
#   'mediastinal',
#   'airspace',
#   'silhouette'],
#  ['edema_gross_airspace_consolidation',
#   'interstitial_marking_related_low',
#   'lung_volume_technique_grossly',
#   'prior_eam_without_overt',
#   'stable_appearance_lung_compared',
#   'stable_cardiomegaly_crowded_bronchovascular',
#   'sternotomy_mediastinal_postsurgical_change',
#   '02010',
#   '09',
#   '10',
#   '10th',
#   '11',
#   '12',
#   '13',
#   '14_cm',
#   '15',
#   '15_cm_nodule',
#   '16',
#   '17',
#   '17_cm_nodular_opacity'],
#  ['chronicappearing',
#   'opacity',
#   'emphysema',
#   'represent',
#   'unchanged',
#   'large',
#   'airspace',
#   'abnormality',
#   'cardiopulmonary',
#   'size',
#   'focal',
#   'heart',
#   'acute',
#   'pneumothora',
#   'normal',
#   'pleural',
#   'effusion',
#   '02010',
#   '09',
#   '10'],
#  ['cavitary',
#   'unremarkable',
#   'lesion',
#   'tuberculosis',
#   'radiographic',
#   'grossly',
#   'active',
#   'air',
#   'space',
#   'cardiac',
#   'vascularity',
#   'evidence',
#   'opacity',
#   'mediastinal',
#   'contour',
#   'clear',
#   'limit',
#   'within',
#   'pulmonary',
#   'focal'],
#  ['associated_airspace_disease',
#   'lung_clear',
#   'small_left_pleural_effusion',
#   'heart_size_upper_limit',
#   'sequela',
#   'old',
#   'blunting',
#   'costophrenic',
#   'granulomatous',
#   'consistent',
#   'degenerative',
#   'left',
#   'right',
#   'spine',
#   'change',
#   'normal',
#   'disease',
#   '02010',
#   '09',
#   '10'],
#  ...]
