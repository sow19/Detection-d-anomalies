# %%
import gensim.downloader as api
import pandas as pd
import numpy as np
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
wv = api.load('glove-wiki-gigaword-300')

# %%
csv1 = "../../data/cleaned/final_clean_data1.csv"
csv2 = "../../data/cleaned/final_clean_data2.csv"
base_texts = pd.read_csv(csv1).iloc[:, 0]
anomaly_texts = pd.read_csv(csv2).iloc[:, 0]

# %%
def key_words(column, top_n=20):
    """
    En utilisant la métrique tf-dif, la fonction retourne les top_n premiers mots-clés dans le dataset.
    """
    vectorizer = TfidfVectorizer()
    x = vectorizer.fit_transform(column)
    feature_names = vectorizer.get_feature_names_out()
    
    kw_per_text = []
    for doc_idx in range(x.shape[0]):
        # récupérer les scores tf-dif pour le texte courant
        tfidf_scores = x[doc_idx].toarray()[0]

        # associer chaque mot avec son score tf-dif
        word_scores = [(feature_names[i], tfidf_scores[i]) for i in range(len(feature_names))]

        # trier les mots par score décroissant
        sorted_words = sorted(word_scores, key=lambda x: x[1], reverse=True)

        # récupérer les top_n mots-clés
        keywords = [word for word, score in sorted_words[:top_n]]
        kw_per_text.append(keywords)

    return kw_per_text

# %%
def contamination_function(data1, data2, contamination_rate=0.5):
    contaminated_texts = []
    contamination_log = []
    data1_kw = key_words(data1)
    data2_kw = key_words(data2)
    
    #on prend 15% des documents 
    df_size = max(1, int(len(data1) * 0.15))  
    selected_indices = random.sample(range(len(data1)), df_size)


    #pour mesurer la similarité entre les mots-clés
    vectorizer = TfidfVectorizer()
    all_keywords = data1_kw + data2_kw
    tfidf_matrice = vectorizer.fit_transform([' '.join(kw) for kw in all_keywords]) #matrice de tout les mots clés
    base_vectors = tfidf_matrice[:len(data1_kw)] 
    anomaly_vectors = tfidf_matrice[len(data1_kw):]
    
    for i in selected_indices:
        base_text = data1[i]
        words = base_text.split()  
        total_words = len(words)
        words_to_contaminate = max(1, int(total_words * contamination_rate))  # mots à contaminer
        # trouver les anomalies les moins similaires (mots clés du text avec toutes les anomalies)
        similarities = cosine_similarity(base_vectors[i], anomaly_vectors)
        best_anomaly_idx = similarities.argmin()
        anomaly_text = data2[best_anomaly_idx]
        anomaly_words = anomaly_text.split()  # les mots de l'anomalie
        # tontaminer les mots du texte de base
        contaminated_words = words[:]
        contaminated_positions = []

        for _ in range(words_to_contaminate):
            # choisir un mot d'anomalie aléatoire
            anomaly_word = random.choice(anomaly_words)
            #position aléatoire dans le document de base
            position = random.randint(0, total_words - 1)

            # mettre le mot à cette position
            contaminated_words[position] = anomaly_word
            contaminated_positions.append((position, anomaly_word))

        #le texte contaminé
        contaminated_text = ' '.join(contaminated_words)
        contaminated_texts.append(contaminated_text)
        data1[i] = contaminated_text

        #résumé des contaminations (à supprimer aprés)
        contamination_log.append({
            "base_text": base_text,
            "contaminated_text": contaminated_text,
            "contaminated_positions": contaminated_positions,
            "anomaly_text": anomaly_text
        })

    return data1, contamination_log, selected_indices

# %%
contaminated, log, indices = contamination_function(base_texts, anomaly_texts)
log
# Out:
# [{'base_text': 'cavity left upper_lobe decreased size bilateral apical bulla parenchymal scar unchanged infiltrates lower lobe heart size remains normal bullous disease upper_lobe scar decreasing right upper_lobe cavity',
#   'contaminated_text': 'thecal thecal upper_lobe decreased size bilateral sac bulla parenchymal root noted infiltrates lower noted heart size significant root noted disease upper_lobe scar nerve significant upper_lobe cavity',
#   'contaminated_positions': [(13, 'noted'),
#    (6, 'sac'),
#    (16, 'evidence'),
#    (9, 'root'),
#    (1, 'thecal'),
#    (18, 'herniation'),
#    (22, 'nerve'),
#    (23, 'significant'),
#    (10, 'noted'),
#    (16, 'significant'),
#    (18, 'noted'),
#    (17, 'root'),
#    (0, 'thecal')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette within normal limit size contour lung normally inflated without evidence focal airspace disease pleural effusion pneumothora acute bone abnormality acute cardiopulmonary process',
#   'contaminated_text': 'protrusion protrusion significant normal noted size thecal_sac spasm normally inflated small evidence focal airspace disease pleural effusion pneumothora noted bone abnormality acute cardiopulmonary process',
#   'contaminated_positions': [(18, 'l5s1'),
#    (1, 'noted'),
#    (1, 'noted'),
#    (10, 'l5s1'),
#    (18, 'noted'),
#    (4, 'noted'),
#    (0, 'protrusion'),
#    (1, 'protrusion'),
#    (6, 'thecal_sac'),
#    (7, 'spasm'),
#    (10, 'small'),
#    (2, 'significant')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart mediastinum unremarkable identified numerous calcified mediastinal lymph well large calcification within left upper left lower lobe appear similar patient previous chest computed tomography sequela prior_granulomatous_disease lung otherwise clear without infiltrate effusion pneumothora evidence prior_granulomatous_disease stable acute abnormality',
#   'contaminated_text': 'heart mediastinum thecal compression numerous calcified mediastinal lymph well large calcification within noted upper noted lower evidence disc root evidence evidence root computed tomography sequela thecal root otherwise noted disc infiltrate disc pneumothora evidence prior_granulomatous_disease stable nerve sac',
#   'contaminated_positions': [(19, 'evidence'),
#    (12, 'noted'),
#    (20, 'evidence'),
#    (16, 'evidence'),
#    (25, 'thecal'),
#    (31, 'disc'),
#    (26, 'sac'),
#    (2, 'thecal'),
#    (21, 'root'),
#    (26, 'root'),
#    (14, 'herniation'),
#    (29, 'disc'),
#    (28, 'noted'),
#    (37, 'sac'),
#    (14, 'noted'),
#    (17, 'disc'),
#    (36, 'nerve'),
#    (18, 'root'),
#    (3, 'compression')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit lung clear pneumothora pleural effusion acute osseous finding acute cardiopulmonary finding',
#   'contaminated_text': 'cardiomediastinal silhouette nerve vasculature within root significant lung compression noted herniation effusion noted osseous finding acute cardiopulmonary finding',
#   'contaminated_positions': [(8, 'evidence'),
#    (12, 'noted'),
#    (5, 'noted'),
#    (5, 'root'),
#    (2, 'nerve'),
#    (6, 'significant'),
#    (9, 'noted'),
#    (8, 'compression'),
#    (10, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'low lung volume magnified appearance heart normal heart size negative consolidation effusion pneumothora bony thora soft tissue grossly unremarkable negative acute cardiopulmonary abnormality',
#   'contaminated_text': 'degenerative hyperintense volume magnified appearance hyperintense paramedianposterolateral heart size negative consolidation effusion left neural thora soft tissue foramen unremarkable negative left neural abnormality',
#   'contaminated_positions': [(12, 'left'),
#    (21, 'left'),
#    (17, 'foramen'),
#    (20, 'left'),
#    (1, 'thecal'),
#    (5, 'hyperintense'),
#    (1, 'hyperintense'),
#    (21, 'neural'),
#    (13, 'neural'),
#    (6, 'paramedianposterolateral'),
#    (0, 'degenerative')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear bilaterally specifically evidence focal consolidation pneumothora pleural effusion cardio mediastinal silhouette unremarkable visualized osseous structure thora without acute abnormality leftsided_peripherally_inserted_central catheter_line placed interval tip_innominate_vein acute cardiopulmonary abnormality interval placement leftsided_peripherally_inserted_central catheter_line tip_innominate_vein',
#   'contaminated_text': 'lumbosacral central l5s1 specifically imaging thecal_sac consolidation pneumothora pleural abutting cardio mediastinal significant l5s1 visualized osseous lumbosacral protrusion without acute abutting nerve catheter_line placed interval tip_innominate_vein acute cardiopulmonary abnormality interval placement leftsided_peripherally_inserted_central l5s1 muscle',
#   'contaminated_positions': [(12, 'significant'),
#    (21, 'thecal_sac'),
#    (20, 'muscle'),
#    (17, 'resonance'),
#    (4, 'imaging'),
#    (2, 'l5s1'),
#    (20, 'abutting'),
#    (0, 'lumbosacral'),
#    (32, 'l5s1'),
#    (9, 'abutting'),
#    (17, 'protrusion'),
#    (33, 'muscle'),
#    (16, 'lumbosacral'),
#    (5, 'thecal_sac'),
#    (1, 'central'),
#    (21, 'nerve'),
#    (13, 'l5s1')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart normal size mediastinum unremarkable scarring emphysematous change noted lung grossly clear acute disease',
#   'contaminated_text': 'heart normal hyperintense within unremarkable scarring emphysematous hyperintense annulus right grossly clear acute disease',
#   'contaminated_positions': [(3, 'within'),
#    (8, 'fibrosus'),
#    (8, 'annulus'),
#    (2, 'represents'),
#    (2, 'hyperintense'),
#    (7, 'hyperintense'),
#    (9, 'right')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size pulmonary vascularity appear within normal limit lung free focal airspace disease pleural effusion pneumothora seen evidence active disease',
#   'contaminated_text': 'feature size magnetic magnetic appear within normal limit lung central muscle thecal_sac disease pleural spasm resonance seen disc central disease',
#   'contaminated_positions': [(11, 'thecal_sac'),
#    (17, 'disc'),
#    (9, 'central'),
#    (15, 'resonance'),
#    (3, 'magnetic'),
#    (2, 'magnetic'),
#    (14, 'spasm'),
#    (18, 'central'),
#    (10, 'muscle'),
#    (0, 'feature')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'eamination performed nipple marker previously noted small nodule_right_lower lung wellseen_today_study may secondary summation structure heart normal size mediastinum unremarkable lung otherwise clear acute disease previously visualized nodule_right_lower lobe wellseen_today_study summation artifact',
#   'contaminated_text': 'eamination paramedianposterolateral nipple marker previously bulge small root represents wellseen_today_study disc left summation left heart annulus fibrosus mediastinum unremarkable lung otherwise right acute disease paramedianposterolateral visualized nodule_right_lower represents probably summation artifact',
#   'contaminated_positions': [(16, 'fibrosus'),
#    (28, 'probably'),
#    (11, 'left'),
#    (1, 'compressing'),
#    (27, 'left'),
#    (27, 'represents'),
#    (24, 'paramedianposterolateral'),
#    (15, 'annulus'),
#    (13, 'left'),
#    (21, 'right'),
#    (8, 'represents'),
#    (1, 'paramedianposterolateral'),
#    (10, 'disc'),
#    (7, 'root'),
#    (5, 'bulge')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear bilaterally specifically evidence focal consolidation pneumothora pleural effusion cardio mediastinal silhouette unremarkable visualized osseous structure thora without acute abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'compression clear bilaterally specifically evidence spasm consolidation significant pleural effusion resonance mediastinal silhouette lumbosacral visualized thecal_sac noted imaging lumbosacral thecal_sac abnormality acute cardiopulmonary abnormality',
#   'contaminated_positions': [(17, 'muscle'),
#    (17, 'spine'),
#    (0, 'compression'),
#    (5, 'spasm'),
#    (13, 'lumbosacral'),
#    (7, 'significant'),
#    (17, 'imaging'),
#    (10, 'resonance'),
#    (16, 'noted'),
#    (15, 'thecal_sac'),
#    (18, 'lumbosacral'),
#    (19, 'thecal_sac')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'focal consolidation pneumothora large pleural effusion cardiomediastinal contour grossly unremarkable heart size within normal limit cardiac generator overlies left upper thora tip overlying right atrium ventricle acute cardiopulmonary finding',
#   'contaminated_text': 'focal consolidation significant compression pleural effusion significant contour grossly unremarkable heart size within evidence significant sac generator herniation left nerve thora nerve overlying right atrium ventricle acute disc root',
#   'contaminated_positions': [(27, 'disc'),
#    (28, 'significant'),
#    (15, 'significant'),
#    (28, 'root'),
#    (15, 'compression'),
#    (3, 'compression'),
#    (14, 'significant'),
#    (15, 'sac'),
#    (6, 'significant'),
#    (21, 'nerve'),
#    (2, 'significant'),
#    (13, 'evidence'),
#    (17, 'herniation'),
#    (19, 'nerve')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'heart lung interval lung clear epanded heart mediastinum normal active disease',
#   'contaminated_text': 'heart torn interval narrowing clear epanded heart mediastinum l45 thecal annular',
#   'contaminated_positions': [(10, 'annular'),
#    (3, 'narrowing'),
#    (9, 'thecal'),
#    (1, 'torn'),
#    (8, 'l45')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear bilaterally specifically evidence focal consolidation pneumothora pleural effusion cardio mediastinal silhouette unremarkable visualized osseous structure thora without acute abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'lung clear thecal_sac noted evidence focal consolidation pneumothora nerve muscle small mediastinal silhouette unremarkable level compression structure thora abutting acute abnormality acute cardiopulmonary noted',
#   'contaminated_positions': [(18, 'central'),
#    (8, 'nerve'),
#    (18, 'abutting'),
#    (14, 'level'),
#    (9, 'compression'),
#    (2, 'thecal_sac'),
#    (9, 'muscle'),
#    (10, 'compression'),
#    (10, 'small'),
#    (23, 'noted'),
#    (3, 'noted'),
#    (15, 'compression')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'minimal_left_basilar opacity subsegmental_atelectasis_scarring focal airspace consolidation suggest pneumonia pleural effusion pneumothora heart size upper limit normal cardiac defibrillator overlies right ventricle appears intact aortic atherosclerotic vascular calcification calcified mediastinal hilar lymph consistent prior granulomatous disease multiple calcified splenic granuloma also noted minimal degenerative change spine minimal_left_basilar subsegmental_atelectasis_scarring acute finding',
#   'contaminated_text': 'minimal_left_basilar opacity subsegmental_atelectasis_scarring focal disc consolidation compressing compressing torn effusion pneumothora heart probably left limit l45 cardiac defibrillator left right represents appears side aortic noted vascular calcification side noted hilar lymph consistent compressing degenerative disease disc calcified splenic granuloma also sac minimal degenerative left spine minimal_left_basilar annulus acute finding',
#   'contaminated_positions': [(7, 'left'),
#    (40, 'sac'),
#    (8, 'thecal'),
#    (43, 'right'),
#    (15, 'l45'),
#    (12, 'probably'),
#    (7, 'compressing'),
#    (13, 'left'),
#    (35, 'disc'),
#    (20, 'represents'),
#    (6, 'compressing'),
#    (18, 'left'),
#    (8, 'neural'),
#    (27, 'side'),
#    (43, 'l45'),
#    (22, 'side'),
#    (24, 'noted'),
#    (33, 'degenerative'),
#    (8, 'torn'),
#    (32, 'compressing'),
#    (43, 'left'),
#    (28, 'noted'),
#    (46, 'annulus'),
#    (4, 'disc')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette stable appearance interval change diffuse increased_bilateral_pulmonary_interstitial marking_greatest_peripheral_aspect left_lung_left_lung base opacity appear slightly increased compared prior eamination mild_leftsided_volume_loss redemonstrated unchanged pneumothora pleural effusion thoracic spine appears intact slight_interval_worsening diffusely increased_bilateral_pulmonary_interstitial marking_greatest_peripheral_aspect left_lung_left_lung base finding consistent slight_interval_worsening patient known interstitial lung disease stable mild_leftsided_volume_loss',
#   'contaminated_text': 'bulge silhouette stable l45 fibrosus represents diffuse increased_bilateral_pulmonary_interstitial marking_greatest_peripheral_aspect disc base represents appear degenerative increased compared prior eamination mild_leftsided_volume_loss redemonstrated unchanged fibrosus pleural effusion neural degenerative appears intact slight_interval_worsening diffusely signal evidence left_lung_left_lung root represents left noted patient known interstitial lung disease stable mild_leftsided_volume_loss',
#   'contaminated_positions': [(25, 'degenerative'),
#    (21, 'compressing'),
#    (0, 'left'),
#    (33, 'root'),
#    (4, 'fibrosus'),
#    (5, 'represents'),
#    (13, 'degenerative'),
#    (3, 'l45'),
#    (31, 'compressing'),
#    (24, 'neural'),
#    (31, 'annular'),
#    (30, 'hyperintense'),
#    (9, 'disc'),
#    (0, 'left'),
#    (34, 'represents'),
#    (0, 'bulge'),
#    (35, 'left'),
#    (31, 'evidence'),
#    (11, 'represents'),
#    (30, 'signal'),
#    (21, 'fibrosus'),
#    (36, 'noted')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'normal stable cardiomediastinal contour interval removal leftsided intravenous catheter pneumothora opacity obscuring hemidiaphragms slightly improved prior eam rightsided rib fracture noted mildly improved opacity may represent atelectasis infiltrate andor pleural effusion',
#   'contaminated_text': 'annulus torn paramedianposterolateral contour interval left leftsided intravenous catheter annulus opacity side foramen within improved left annulus rightsided rib fracture noted mildly annulus opacity neural sac atelectasis infiltrate andor pleural effusion',
#   'contaminated_positions': [(24, 'neural'),
#    (11, 'side'),
#    (9, 'annulus'),
#    (16, 'annulus'),
#    (2, 'paramedianposterolateral'),
#    (22, 'hyperintense'),
#    (12, 'foramen'),
#    (5, 'left'),
#    (15, 'left'),
#    (22, 'left'),
#    (22, 'annulus'),
#    (25, 'sac'),
#    (1, 'torn'),
#    (13, 'within'),
#    (0, 'annulus')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart pulmonary mediastinum within normal limit pleural effusion pneumothora focal air space opacity suggest pneumonia acute cardiopulmonary disease',
#   'contaminated_text': 'disc pulmonary mediastinum within root limit pleural disc pneumothora compression herniation disc opacity suggest pneumonia significant nerve disease',
#   'contaminated_positions': [(9, 'compression'),
#    (4, 'root'),
#    (16, 'nerve'),
#    (15, 'significant'),
#    (11, 'disc'),
#    (10, 'compression'),
#    (10, 'herniation'),
#    (0, 'disc'),
#    (7, 'disc')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'eamination consists frontal lateral radiograph chest cardiomediastinal contour within_normal_limit pulmonary vascularity within_normal_limit focal consolidation pleural effusion pneumothora identified multilevel thoracic spondylosis demonstrated acute cardiopulmonary disease',
#   'contaminated_text': 'eamination consists frontal lateral foramen annulus hyperintense l45 within_normal_limit compressing torn within_normal_limit narrowing consolidation bulge effusion thecal identified left thoracic annular demonstrated left cardiopulmonary disease',
#   'contaminated_positions': [(6, 'hyperintense'),
#    (18, 'left'),
#    (7, 'l45'),
#    (14, 'bulge'),
#    (22, 'left'),
#    (5, 'annulus'),
#    (12, 'narrowing'),
#    (10, 'torn'),
#    (9, 'compressing'),
#    (20, 'annular'),
#    (4, 'foramen'),
#    (16, 'thecal')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size normal lung grossly clear pleural effusion pneumothoraces hilar mediastinal contour stable normal pulmonary vascularity overt edema acute abnormality',
#   'contaminated_text': 'within size normal nerve side clear degenerative probably pneumothoraces hilar mediastinal contour neural normal pulmonary vascularity degenerative edema bulge abnormality',
#   'contaminated_positions': [(3, 'neural'),
#    (7, 'annular'),
#    (18, 'bulge'),
#    (0, 'within'),
#    (16, 'degenerative'),
#    (6, 'degenerative'),
#    (12, 'neural'),
#    (4, 'side'),
#    (3, 'nerve'),
#    (7, 'probably')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'mm_nodular_opacity right_upper_lobe appears prior study lung otherwise appear clear pleural effusion pneumothora seen heart size mediastinal contour appear within normal limit acute traumatic finding right_upper_lobe mm_nodular_opacity may artifactual secondary overlapping vascular structure however true pulmonary nodule possibility appears consider evaluation dedicated posterior-anterior lateral chest radiograph patient',
#   'contaminated_text': 'mm_nodular_opacity right appears annulus study lung signal appear clear sac effusion pneumothora bulge heart size mediastinal contour appear within within annulus acute traumatic finding signal mm_nodular_opacity left thecal secondary overlapping foramen structure fibrosus true narrowing nodule possibility appears consider evaluation thecal evidence lateral side radiograph hyperintense',
#   'contaminated_positions': [(45, 'hyperintense'),
#    (32, 'fibrosus'),
#    (6, 'noted'),
#    (1, 'right'),
#    (19, 'within'),
#    (12, 'bulge'),
#    (6, 'left'),
#    (43, 'compressing'),
#    (41, 'fibrosus'),
#    (43, 'side'),
#    (34, 'compressing'),
#    (41, 'degenerative'),
#    (9, 'sac'),
#    (27, 'thecal'),
#    (6, 'signal'),
#    (24, 'signal'),
#    (30, 'foramen'),
#    (40, 'thecal'),
#    (20, 'annulus'),
#    (26, 'left'),
#    (41, 'evidence'),
#    (3, 'annulus'),
#    (34, 'narrowing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size normal lung clear pneumothora pleural effusion normal chest eam',
#   'contaminated_text': 'heart size left fibrosus clear within pleural hyperintense normal chest eam',
#   'contaminated_positions': [(2, 'side'),
#    (5, 'within'),
#    (7, 'hyperintense'),
#    (3, 'fibrosus'),
#    (2, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'change appearance left upper lobectomy left parahilar scar unchanged infiltrates mass lung heart size remains normal stable chest evidence recurrence metastasis',
#   'contaminated_text': 'spine appearance left upper level left feature scar thecal_sac infiltrates nerve lung heart size imaging central stable spine evidence recurrence noted',
#   'contaminated_positions': [(20, 'noted'),
#    (10, 'nerve'),
#    (17, 'spine'),
#    (4, 'level'),
#    (14, 'imaging'),
#    (0, 'l5s1'),
#    (15, 'central'),
#    (6, 'feature'),
#    (8, 'thecal_sac'),
#    (0, 'spine')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart size pulmonary vascularity appear within normal limit lung free focal airspace disease pleural effusion pneumothora seen low left_paraspinalretrocrural_adenopathy present appears unchanged left_paraspinalretrocrural_adenopathy',
#   'contaminated_text': 'heart sac pulmonary vascularity appear within normal limit disc free sac significant herniation thecal noted pneumothora thecal sac significant root appears unchanged left_paraspinalretrocrural_adenopathy',
#   'contaminated_positions': [(19, 'root'),
#    (18, 'significant'),
#    (17, 'sac'),
#    (10, 'sac'),
#    (1, 'sac'),
#    (8, 'disc'),
#    (14, 'noted'),
#    (16, 'thecal'),
#    (12, 'herniation'),
#    (11, 'significant'),
#    (13, 'thecal')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear heart size normal unremarkable acute cardiopulmonary finding',
#   'contaminated_text': 'root clear nerve size left degenerative acute cardiopulmonary finding',
#   'contaminated_positions': [(2, 'nerve'),
#    (4, 'left'),
#    (5, 'degenerative'),
#    (0, 'root')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette normal size appearance pleural effusion pneumothora lung clear normal chest',
#   'contaminated_text': 'narrowing silhouette within within appearance pleural effusion pneumothora represents clear normal chest',
#   'contaminated_positions': [(0, 'narrowing'),
#    (3, 'narrowing'),
#    (2, 'within'),
#    (3, 'within'),
#    (3, 'within'),
#    (8, 'represents')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomegaly unfolded aorta pulmonary edema focal consolidation large pleural effusion evidence pneumothora cardiomegaly clear lung',
#   'contaminated_text': 'cardiomegaly unfolded level abutting edema focal muscle large pleural root l5s1 feature cardiomegaly clear lung',
#   'contaminated_positions': [(10, 'noted'),
#    (11, 'feature'),
#    (6, 'muscle'),
#    (9, 'root'),
#    (10, 'l5s1'),
#    (2, 'level'),
#    (3, 'abutting')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'chest heart normal size normal appearance cardia mediastinal silhouette focal airspace opacity pleural effusion pneumothora mild degenerative_change thoracic spine right_knee_severe_tricompartmental degenerative_change obliteration joint_space_fracture_dislocation left_knee joint_space loss prominent medial_compartment lateral view limit evaluation effusion patellofemoral joint_space_fracture_dislocation chest acute cardiopulmonary finding right_knee_severe_tricompartmental degenerative_change without fracture_dislocation_left_knee severe medial_compartment degenerative_change',
#   'contaminated_text': 'chest heart disc side normal right cardia mediastinal silhouette focal airspace root pleural effusion side mild degenerative_change thoracic signal disc noted annulus joint_space_fracture_dislocation root within probably prominent medial_compartment l45 view bulge evaluation effusion patellofemoral paramedianposterolateral chest hyperintense cardiopulmonary finding right_knee_severe_tricompartmental degenerative_change without fracture_dislocation_left_knee severe right bulge',
#   'contaminated_positions': [(44, 'noted'),
#    (21, 'annulus'),
#    (3, 'narrowing'),
#    (18, 'signal'),
#    (34, 'paramedianposterolateral'),
#    (44, 'compressing'),
#    (5, 'right'),
#    (20, 'noted'),
#    (2, 'disc'),
#    (45, 'bulge'),
#    (24, 'within'),
#    (30, 'bulge'),
#    (25, 'annulus'),
#    (36, 'hyperintense'),
#    (19, 'disc'),
#    (14, 'side'),
#    (3, 'side'),
#    (28, 'l45'),
#    (44, 'right'),
#    (25, 'probably'),
#    (23, 'nerve'),
#    (11, 'root'),
#    (23, 'root')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiac mediastinal contour within normal limit granulomatous calcification mediastinum lung clear bony structure intact acute finding',
#   'contaminated_text': 'compression mediastinal herniation within normal limit granulomatous noted mediastinum nerve herniation bony thecal intact nerve finding',
#   'contaminated_positions': [(14, 'nerve'),
#    (10, 'herniation'),
#    (0, 'compression'),
#    (7, 'noted'),
#    (9, 'evidence'),
#    (2, 'herniation'),
#    (9, 'nerve'),
#    (12, 'thecal')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'heart size mildly enlarged pulmonary mediastinum within normal limit pleural effusion pneumothora focal air space opacity suggest pneumonia moderate sized hiatal_hernia mild degenerative change spine cardiomegaly hiatal_hernia without acute abnormality identified',
#   'contaminated_text': 'heart veretbral flavum enlarged pulmonary mediastinum within normal limit pleural effusion pneumothora focal vertebra space opacity suggest neural level associated magnetic flavum degenerative change imaging intensity level without acute canal identified',
#   'contaminated_positions': [(29, 'right'),
#    (29, 'canal'),
#    (18, 'etending'),
#    (20, 'magnetic'),
#    (19, 'associated'),
#    (25, 'intensity'),
#    (26, 'level'),
#    (21, 'flavum'),
#    (18, 'imaging'),
#    (13, 'vertebra'),
#    (17, 'neural'),
#    (1, 'veretbral'),
#    (2, 'flavum'),
#    (24, 'imaging'),
#    (18, 'level')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging 32 cm lesion inhomogenous signal intensity noted posterior lumbar vertebra veretbral body largely compressing right side thecal_sac contrast study advsied diffuse disc_bulge_noted l4l5 level compresing thecal_sac encroaching upon neural canal wide base disc_bulge_noted l5s1 level etending left lateral recess compressin thecal_sac nerve root left side associated ligamnetum flavum hyperatrophy'},
#  {'base_text': 'soft tissue appear normal cardiac silhouette mediastinum size normal aortic left trachea well seen appears normal lung clear unremarkable chest study',
#   'contaminated_text': 'soft sac sac root cardiac thecal noted size normal aortic evidence herniation well seen disc normal lung clear nerve chest study',
#   'contaminated_positions': [(2, 'sac'),
#    (3, 'root'),
#    (6, 'noted'),
#    (14, 'thecal'),
#    (10, 'evidence'),
#    (14, 'disc'),
#    (5, 'thecal'),
#    (1, 'sac'),
#    (18, 'nerve'),
#    (11, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'cardiac mediastinal appear normal visible pneumothora focal airspace opacity pleural effusion seen visible free air diaphragm osseous structure appear intact acute radiographic cardiopulmonary process',
#   'contaminated_text': 'sac annulus appear fibrosus area pneumothora focal airspace within pleural effusion seen visible annular fibrosus diaphragm osseous right appear intact l45 probably cardiopulmonary process',
#   'contaminated_positions': [(13, 'annular'),
#    (14, 'fibrosus'),
#    (3, 'fibrosus'),
#    (17, 'right'),
#    (20, 'l45'),
#    (21, 'probably'),
#    (0, 'probably'),
#    (20, 'l45'),
#    (1, 'annulus'),
#    (8, 'within'),
#    (0, 'sac'),
#    (4, 'area')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart normal size mediastinum unremarkable lung clear evidence active tuberculosis acute disease',
#   'contaminated_text': 'l5s1 normal noted mediastinum abutting spine clear evidence root tuberculosis acute abutting',
#   'contaminated_positions': [(11, 'abutting'),
#    (8, 'root'),
#    (2, 'noted'),
#    (0, 'l5s1'),
#    (4, 'abutting'),
#    (5, 'spine')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'trachea midline cardiomediastinal silhouette normal lung clear without evidence focal infiltrate effusion pneumothora visualized bony structure reveal acute abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'trachea midline cardiomediastinal lumbosacral imaging protrusion clear spasm evidence focal infiltrate significant nerve visualized bony structure reveal lumbosacral nerve acute cardiopulmonary central',
#   'contaminated_positions': [(11, 'significant'),
#    (17, 'lumbosacral'),
#    (7, 'spasm'),
#    (3, 'magnetic'),
#    (21, 'central'),
#    (3, 'lumbosacral'),
#    (12, 'nerve'),
#    (18, 'nerve'),
#    (4, 'imaging'),
#    (5, 'muscle'),
#    (5, 'protrusion')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart mediastinal contour stable lung clear without focal infiltrate pleural effusion pneumothora acute cardiopulmonary disease',
#   'contaminated_text': 'left mediastinal contour stable lung left without degenerative annulus pleural effusion annular foramen cardiopulmonary disease',
#   'contaminated_positions': [(7, 'degenerative'),
#    (5, 'left'),
#    (11, 'narrowing'),
#    (8, 'annulus'),
#    (0, 'left'),
#    (12, 'foramen'),
#    (11, 'annular')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart pulmonary mediastinum within normal limit pleural effusion pneumothora focal air space opacity suggest pneumonia minimal degenerative change spine acute cardiopulmonary disease',
#   'contaminated_text': 'heart pulmonary mediastinum significant herniation limit pleural effusion pneumothora focal air space sac evidence evidence minimal degenerative change spine disc cardiopulmonary disease',
#   'contaminated_positions': [(14, 'root'),
#    (13, 'significant'),
#    (14, 'compression'),
#    (13, 'evidence'),
#    (4, 'disc'),
#    (3, 'significant'),
#    (19, 'disc'),
#    (14, 'herniation'),
#    (12, 'sac'),
#    (14, 'evidence'),
#    (4, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette within normal limit size appearance lung hyperlucent hyperepanded negative focal airspace disease consolidation negative pneumothora pleural effusion limited evaluation reveals acute abnormality stable chronic lung change without acute cardiopulmonary abnormality',
#   'contaminated_text': 'compressing silhouette within normal limit size left lung hyperlucent hyperepanded negative right airspace left consolidation annular annular fibrosus effusion limited evaluation reveals disc abnormality thecal neural lung change without acute paramedianposterolateral compressing',
#   'contaminated_positions': [(24, 'thecal'),
#    (11, 'right'),
#    (6, 'area'),
#    (15, 'annular'),
#    (30, 'paramedianposterolateral'),
#    (16, 'neural'),
#    (0, 'compressing'),
#    (22, 'disc'),
#    (16, 'annular'),
#    (25, 'right'),
#    (17, 'fibrosus'),
#    (13, 'left'),
#    (25, 'neural'),
#    (6, 'left'),
#    (25, 'neural'),
#    (31, 'compressing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'mediastinal contour normal significant_change pneumothora right pleural_fluid significant_change right pneumothora pleural_fluid',
#   'contaminated_text': 'noted contour normal significant_change pneumothora right pleural_fluid central spine pneumothora pleural_fluid',
#   'contaminated_positions': [(8, 'spine'),
#    (0, 'thecal_sac'),
#    (7, 'central'),
#    (0, 'noted'),
#    (8, 'spine')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart size stable aorta ectatic atherosclerotic stable sternotomy noted scarring left_lower_lobe noted unchanged prior eam mild bilateral prominent lung interstitial opacity consistent emphysematous disease calcified granuloma stable change emphysema left_lower_lobe scarring stable unchanged degenerative atherosclerotic change thoracic aorta',
#   'contaminated_text': 'heart fibrosus stable aorta ectatic atherosclerotic stable sternotomy noted narrowing left_lower_lobe noted unchanged prior left represents bilateral prominent fibrosus interstitial paramedianposterolateral consistent evidence right calcified granuloma stable thecal fibrosus left_lower_lobe scarring stable degenerative degenerative atherosclerotic neural thoracic aorta',
#   'contaminated_positions': [(15, 'disc'),
#    (9, 'thecal'),
#    (27, 'thecal'),
#    (28, 'hyperintense'),
#    (15, 'degenerative'),
#    (20, 'l45'),
#    (23, 'right'),
#    (1, 'fibrosus'),
#    (18, 'fibrosus'),
#    (9, 'narrowing'),
#    (28, 'fibrosus'),
#    (20, 'paramedianposterolateral'),
#    (35, 'neural'),
#    (14, 'left'),
#    (32, 'narrowing'),
#    (15, 'annulus'),
#    (32, 'degenerative'),
#    (22, 'evidence'),
#    (15, 'represents')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'normal heart size focal air space consolidation pneumothora pleural effusion pulmonary edema focal bony abnormality acute cardiopulmonary disease',
#   'contaminated_text': 'normal right within focal air evidence annulus sac disc area pulmonary edema focal bony abnormality acute cardiopulmonary disease',
#   'contaminated_positions': [(8, 'foramen'),
#    (6, 'annulus'),
#    (2, 'within'),
#    (5, 'evidence'),
#    (1, 'left'),
#    (8, 'disc'),
#    (1, 'right'),
#    (7, 'sac'),
#    (9, 'area')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung mildly_hyperepanded focal_airspace_consolidation suspicious pulmonary mass nodule identified heart size mediastinal contour within normal limit degenerative change spine focal_airspace_consolidation mildly_hyperepanded lung suggestive emphysema',
#   'contaminated_text': 'herniation mildly_hyperepanded focal_airspace_consolidation suspicious root sac nodule noted heart size mediastinal herniation root normal thecal degenerative change spine focal_airspace_consolidation mildly_hyperepanded compression suggestive nerve',
#   'contaminated_positions': [(4, 'root'),
#    (5, 'sac'),
#    (11, 'herniation'),
#    (12, 'disc'),
#    (0, 'herniation'),
#    (20, 'compression'),
#    (12, 'root'),
#    (22, 'nerve'),
#    (7, 'disc'),
#    (14, 'thecal'),
#    (7, 'noted')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'normal heart size focal air space consolidation pneumothora pleural effusion pulmonary edema anterior osteophyte thoracic spine acute cardiopulmonary disease',
#   'contaminated_text': 'noted heart right degenerative air probably foramen pneumothora pleural effusion pulmonary evidence anterior osteophyte thoracic spine acute cardiopulmonary degenerative',
#   'contaminated_positions': [(5, 'annulus'),
#    (18, 'root'),
#    (2, 'right'),
#    (6, 'foramen'),
#    (0, 'noted'),
#    (18, 'degenerative'),
#    (3, 'degenerative'),
#    (11, 'evidence'),
#    (5, 'probably')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'frontal lateral view chest overlying eternal cardiac monitor lead show normal size configuration cardiac silhouette scattered nodular opacity calcified granuloma focal airspace consolidation pleural effusion acute active cardiac pulmonary pleural disease probable previous granulomatous disease',
#   'contaminated_text': 'degenerative lateral noted neural overlying torn cardiac probably lead show normal area configuration cardiac silhouette side nodular opacity bulge granuloma thecal airspace consolidation area effusion acute thecal cardiac pulmonary pleural disease probable previous granulomatous left',
#   'contaminated_positions': [(2, 'noted'),
#    (26, 'thecal'),
#    (5, 'left'),
#    (3, 'narrowing'),
#    (7, 'foramen'),
#    (11, 'area'),
#    (7, 'probably'),
#    (23, 'area'),
#    (3, 'neural'),
#    (5, 'foramen'),
#    (5, 'torn'),
#    (18, 'bulge'),
#    (34, 'left'),
#    (15, 'annulus'),
#    (20, 'thecal'),
#    (0, 'degenerative'),
#    (15, 'side')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart within normal limit size given low lung volume anteroposterior portable technique lung clear without evidence infiltrate pneumothora effusion acute cardiopulmonary disease',
#   'contaminated_text': 'heart level normal nerve size given low lung noted anteroposterior portable technique lung clear root muscle infiltrate pneumothora effusion compression cardiopulmonary compression',
#   'contaminated_positions': [(8, 'l5s1'),
#    (1, 'disc'),
#    (21, 'feature'),
#    (1, 'level'),
#    (3, 'nerve'),
#    (14, 'root'),
#    (19, 'imaging'),
#    (15, 'muscle'),
#    (8, 'noted'),
#    (19, 'compression'),
#    (21, 'compression')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart normal size mild conveity right mediastinal contour superimposed vasculature aortic tortuosity focal consolidation pleural effusion seen acute disease',
#   'contaminated_text': 'noted normal size mild herniation noted nerve contour superimposed vasculature aortic tortuosity focal root disc significant seen acute disease',
#   'contaminated_positions': [(5, 'noted'),
#    (15, 'significant'),
#    (13, 'root'),
#    (6, 'disc'),
#    (6, 'nerve'),
#    (14, 'disc'),
#    (4, 'noted'),
#    (0, 'noted'),
#    (4, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear bilaterally specifically evidence focal consolidation pneumothora pleural effusion cardio mediastinal silhouette unremarkable visualized osseous structure thora without acute abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'lung root level imaging evidence lumbosacral consolidation pneumothora pleural l5s1 cardio mediastinal silhouette unremarkable visualized thecal_sac small thora resonance acute abnormality acute thecal_sac abnormality',
#   'contaminated_positions': [(22, 'thecal_sac'),
#    (15, 'protrusion'),
#    (18, 'resonance'),
#    (16, 'significant'),
#    (9, 'l5s1'),
#    (1, 'root'),
#    (16, 'small'),
#    (5, 'lumbosacral'),
#    (15, 'resonance'),
#    (2, 'level'),
#    (15, 'thecal_sac'),
#    (3, 'imaging')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'intact sternotomy stable_cardiomegaly grossly unchanged rightward mediastinal_shift unchanged_appearance left perihilar calcified lymph left basilar calcified granuloma relatively unchanged_appearance prominent interstitial_marking patchy bibasilar atelectasis negative pneumothora focal infiltrate large pleural effusion acute bony abnormality stable_cardiomegaly right mediastinal_shift stable interstitial_marking prominent bibasilar airspace opacity represent atelectasis',
#   'contaminated_text': 'intact sternotomy stable_cardiomegaly grossly unchanged nerve mediastinal_shift sac left perihilar thecal root left root calcified granuloma relatively disc prominent interstitial_marking thecal bibasilar atelectasis root pneumothora focal compression compression pleural evidence acute bony evidence compression right noted stable significant prominent bibasilar airspace opacity represent atelectasis',
#   'contaminated_positions': [(23, 'nerve'),
#    (29, 'disc'),
#    (11, 'root'),
#    (20, 'thecal'),
#    (37, 'significant'),
#    (5, 'root'),
#    (13, 'root'),
#    (35, 'noted'),
#    (10, 'thecal'),
#    (32, 'evidence'),
#    (33, 'sac'),
#    (26, 'root'),
#    (33, 'disc'),
#    (5, 'nerve'),
#    (27, 'compression'),
#    (26, 'compression'),
#    (29, 'evidence'),
#    (33, 'thecal'),
#    (17, 'disc'),
#    (7, 'sac'),
#    (33, 'compression'),
#    (23, 'root')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear epanded heart mediastinum normal active disease',
#   'contaminated_text': 'lung nerve l45 heart narrowing normal area disease',
#   'contaminated_positions': [(1, 'nerve'),
#    (4, 'narrowing'),
#    (2, 'l45'),
#    (6, 'area')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung relatively clear sulcus heart size normal lv contour slightly unfolded ascending descending aorta tspine unremarkable significant finding',
#   'contaminated_text': 'lung relatively side sulcus heart size normal left foramen slightly unfolded narrowing narrowing aorta annulus bulge area finding',
#   'contaminated_positions': [(8, 'area'),
#    (15, 'bulge'),
#    (8, 'foramen'),
#    (11, 'narrowing'),
#    (2, 'side'),
#    (16, 'area'),
#    (7, 'left'),
#    (14, 'annulus'),
#    (12, 'narrowing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear heart pulmonary normal pleural space clear mediastinal contour normal acute cardiopulmonary disease',
#   'contaminated_text': 'narrowing clear heart pulmonary normal pleural space clear right compressing probably acute cardiopulmonary disease',
#   'contaminated_positions': [(9, 'side'),
#    (10, 'l45'),
#    (0, 'narrowing'),
#    (9, 'side'),
#    (9, 'compressing'),
#    (10, 'probably'),
#    (8, 'right')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear pneumothora pleural effusion leftsided pacemaker noted 1 right atrium another right ventricle third left ventricle stable stable cardiomegaly significant change prior study',
#   'contaminated_text': 'level clear compressing pleural resonance leftsided root noted 1 spasm atrium another imaging ventricle third left ventricle stable noted spasm muscle change prior resonance',
#   'contaminated_positions': [(20, 'muscle'),
#    (2, 'compressing'),
#    (18, 'noted'),
#    (6, 'l4l5'),
#    (0, 'ar'),
#    (19, 'spasm'),
#    (9, 'spasm'),
#    (23, 'resonance'),
#    (6, 'root'),
#    (12, 'imaging'),
#    (0, 'level'),
#    (4, 'resonance')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm diffuse disc bulge noted ar l4l5 level mildly compressing thecal sac eit nerve root'},
#  {'base_text': 'frontal lateral view chest show normal size configuration cardiac silhouette normal mediastinal contour pulmonary vasculature central airway aeration lung pleural effusion gastroesophageal junction epigastric postsurgical change acute active cardiac pulmonary pleural disease',
# ...
#   'contaminated_positions': [(39, 'evidence'),
#    (19, 'thecal'),
#    (1, 'l45'),
#    (76, 'within'),
#    (44, 'paramedianposterolateral'),
#    (69, 'left'),
#    (17, 'sac'),
#    (66, 'degenerative'),
#    (39, 'sac'),
#    (28, 'side'),
#    (32, 'compressing'),
#    (84, 'within'),
#    (74, 'side'),
#    (17, 'left'),
#    (54, 'signal'),
#    (59, 'left'),
#    (53, 'l45'),
#    (44, 'thecal'),
#    (63, 'evidence'),
#    (60, 'evidence'),
#    (52, 'left'),
#    (48, 'compressing'),
#    (39, 'torn'),
#    (31, 'signal'),
#    (45, 'left'),
#    (6, 'annulus'),
#    (21, 'thecal'),
#    (43, 'annulus'),
#    (37, 'root'),
#    (85, 'annulus'),
#    (26, 'right'),
#    (55, 'foramen'),
#    (26, 'annulus'),
#    (63, 'l45'),
#    (3, 'disc'),
#    (81, 'foramen'),
#    (72, 'noted'),
#    (64, 'bulge'),
#    (70, 'compressing'),
#    (80, 'left'),
#    (71, 'nerve'),
#    (70, 'side'),
#    (83, 'bulge')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'within_posterior_lateral 8th rib deformity along corte associated oblique lucency addition within_posterior_lateral 9th rib appears obliquely oriented lucency cortical disruption finding concerning possible left_rib_fracture otherwise cardiomediastinal silhouette within normal limit lung clear bilaterally multiple small punctate radiopaque foreign body seen within subcutaneous tissue present previous computed tomography scan possible lower posterior_lateral left_rib_fracture described concern rib_fracture dedicated rib film would better evaluate otherwise acute cardiopulmonary disease',
#   'contaminated_text': 'within_posterior_lateral evidence rib disc side represents associated oblique lucency addition left 9th rib left right oriented lucency cortical disruption finding concerning compressing left_rib_fracture otherwise cardiomediastinal silhouette within normal limit foramen clear narrowing torn small punctate thecal foreign body seen within subcutaneous left left sac probably tomography scan possible lower posterior_lateral right annular concern nerve right rib film would better evaluate narrowing acute cardiopulmonary disease',
#   'contaminated_positions': [(50, 'right'),
#    (1, 'evidence'),
#    (42, 'paramedianposterolateral'),
#    (32, 'torn'),
#    (54, 'probably'),
#    (35, 'thecal'),
#    (31, 'right'),
#    (3, 'disc'),
#    (44, 'probably'),
#    (5, 'annular'),
#    (14, 'right'),
#    (5, 'torn'),
#    (53, 'torn'),
#    (43, 'side'),
#    (13, 'root'),
#    (26, 'sac'),
#    (5, 'represents'),
#    (4, 'side'),
#    (43, 'sac'),
#    (54, 'right'),
#    (51, 'annular'),
#    (29, 'foramen'),
#    (26, 'within'),
#    (42, 'left'),
#    (13, 'left'),
#    (10, 'left'),
#    (21, 'compressing'),
#    (41, 'hyperintense'),
#    (31, 'narrowing'),
#    (53, 'nerve'),
#    (41, 'left'),
#    (60, 'narrowing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'eamination consists frontal lateral radiograph chest cardiomediastinal contour within normal limit right greater left biapical bullous emphysema focal consolidation pleural effusion pneumothora identified degenerative change thoracic spine evidence acute cardiopulmonary process',
#   'contaminated_text': 'eamination root noted nerve radiograph chest cardiomediastinal feature feature thecal root right greater left biapical bullous eit focal nerve l4l5 effusion pneumothora identified degenerative change thoracic nerve evidence diffuse cardiopulmonary muscle',
#   'contaminated_positions': [(26, 'nerve'),
#    (3, 'muscle'),
#    (2, 'noted'),
#    (9, 'thecal'),
#    (18, 'level'),
#    (16, 'eit'),
#    (10, 'root'),
#    (19, 'l4l5'),
#    (28, 'diffuse'),
#    (18, 'nerve'),
#    (7, 'feature'),
#    (3, 'nerve'),
#    (30, 'muscle'),
#    (8, 'feature'),
#    (1, 'root')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'heart upper limit normal size lung clear without evidence infiltrate pneumothora effusion acute cardiopulmonary disease',
#   'contaminated_text': 'heart level thecal_sac thecal_sac feature lung clear without evidence infiltrate pneumothora effusion acute lumbosacral resonance',
#   'contaminated_positions': [(13, 'l5s1'),
#    (1, 'level'),
#    (3, 'thecal_sac'),
#    (4, 'feature'),
#    (13, 'lumbosacral'),
#    (14, 'resonance'),
#    (2, 'thecal_sac')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'pneumothora pleural effusion normal cardiac contour clear lung bilaterally acute cardiopulmonary abnormality',
#   'contaminated_text': 'side pleural effusion annular left area represents lung bilaterally acute cardiopulmonary paramedianposterolateral',
#   'contaminated_positions': [(4, 'left'),
#    (6, 'represents'),
#    (11, 'paramedianposterolateral'),
#    (3, 'annular'),
#    (0, 'side'),
#    (5, 'area')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart normal size mediastinum stable lung hypoinflated scarring left_lung_base focal consolidation significant effusion mild chronic change left_lung_base without acute disease',
#   'contaminated_text': 'evidence normal noted mediastinum stable lung signal scarring left_lung_base focal foramen neural effusion annulus chronic change noted without l45 disease',
#   'contaminated_positions': [(10, 'foramen'),
#    (0, 'evidence'),
#    (6, 'paramedianposterolateral'),
#    (13, 'annulus'),
#    (16, 'noted'),
#    (2, 'noted'),
#    (18, 'compressing'),
#    (11, 'neural'),
#    (18, 'l45'),
#    (6, 'signal')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size normal aorta tortuous eclude_ascending_aortic_aneurysm pulmonary vascularity normal residual prior granulomatous infection lung otherwise clear degenerative change spine acute cardiopulmonary process tortuous aorta eclude_ascending_aortic_aneurysm',
#   'contaminated_text': 'root compression thecal thecal tortuous nerve pulmonary vascularity thecal residual nerve granulomatous infection sac otherwise clear degenerative change nerve acute nerve root tortuous aorta eclude_ascending_aortic_aneurysm',
#   'contaminated_positions': [(20, 'nerve'),
#    (13, 'sac'),
#    (0, 'root'),
#    (2, 'thecal'),
#    (5, 'root'),
#    (3, 'thecal'),
#    (18, 'nerve'),
#    (1, 'compression'),
#    (21, 'root'),
#    (10, 'nerve'),
#    (5, 'nerve'),
#    (8, 'thecal')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'heart normal size mediastinum stable lung mildly hypoinflated increased opacity lateral projection reflect bronchovascular crowding acute infiltrate pleural effusion acute disease',
#   'contaminated_text': 'heart normal size left thecal lung mildly hypoinflated increased opacity lateral signal fibrosus l45 crowding nerve infiltrate pleural right l45 disease',
#   'contaminated_positions': [(18, 'right'),
#    (3, 'side'),
#    (3, 'left'),
#    (11, 'signal'),
#    (19, 'foramen'),
#    (12, 'fibrosus'),
#    (13, 'l45'),
#    (19, 'l45'),
#    (4, 'thecal'),
#    (15, 'nerve')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lateral chest eamination obtained heart silhouette normal size contour aortic appear unremarkable lung demonstrate acute finding effusion pneumothora acute pulmonary disease',
#   'contaminated_text': 'lateral chest eamination within heart silhouette compressing nerve disc compressing annulus unremarkable foramen demonstrate narrowing finding effusion pneumothora acute pulmonary nerve',
#   'contaminated_positions': [(10, 'annulus'),
#    (9, 'left'),
#    (20, 'nerve'),
#    (7, 'nerve'),
#    (8, 'disc'),
#    (6, 'compressing'),
#    (12, 'foramen'),
#    (9, 'compressing'),
#    (14, 'narrowing'),
#    (3, 'within')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size within normal limit negative focal pulmonary consolidation pleural effusion pneumothora hyperepansion lung mild degenerative change present spine evidence metastatic disease',
#   'contaminated_text': 'bulge size l5s1 normal sac negative disc encroaching consolidation level effusion spasm encroaching diffuse mild l4l5 change present spine evidence muscle disease',
#   'contaminated_positions': [(4, 'sac'),
#    (15, 'l4l5'),
#    (7, 'encroaching'),
#    (11, 'spasm'),
#    (13, 'diffuse'),
#    (6, 'disc'),
#    (0, 'bulge'),
#    (2, 'l5s1'),
#    (20, 'muscle'),
#    (12, 'encroaching'),
#    (9, 'level')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'cardiomediastinal silhouette normal pulmonary vasculature normal consolidation pneumothora large pleural effusion osseous structure soft tissue normal acute cardiopulmonary disease',
#   'contaminated_text': 'hyperintense silhouette normal pulmonary vasculature area consolidation pneumothora within pleural effusion osseous annulus evidence tissue hyperintense acute cardiopulmonary root',
#   'contaminated_positions': [(13, 'evidence'),
#    (15, 'hyperintense'),
#    (5, 'sac'),
#    (0, 'hyperintense'),
#    (5, 'compressing'),
#    (12, 'annulus'),
#    (18, 'root'),
#    (5, 'area'),
#    (8, 'within')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size pulmonary vascularity appear within normal limit lung free focal airspace disease pleural effusion pneumothora seen discrete nodule adenopathy noted degenerative change present spine evidence active disease',
#   'contaminated_text': 'wide size pulmonary vascularity ligamnetum within normal compresing neural free focal resonance disease imaging effusion pneumothora seen discrete nodule adenopathy noted degenerative change present lumbar cm active noted',
#   'contaminated_positions': [(24, 'recess'),
#    (24, 'encroaching'),
#    (7, 'compresing'),
#    (0, 'wide'),
#    (8, 'neural'),
#    (11, 'largely'),
#    (11, 'resonance'),
#    (4, 'left'),
#    (24, 'lumbar'),
#    (25, 'thecal_sac'),
#    (25, 'cm'),
#    (13, 'imaging'),
#    (4, 'ligamnetum'),
#    (27, 'noted')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging 32 cm lesion inhomogenous signal intensity noted posterior lumbar vertebra veretbral body largely compressing right side thecal_sac contrast study advsied diffuse disc_bulge_noted l4l5 level compresing thecal_sac encroaching upon neural canal wide base disc_bulge_noted l5s1 level etending left lateral recess compressin thecal_sac nerve root left side associated ligamnetum flavum hyperatrophy'},
#  {'base_text': 'heart normal size contour lung clear without evidence infiltrate pneumothora effusion acute cardiopulmonary disease',
#   'contaminated_text': 'lumbosacral normal size l5s1 lung clear compression imaging infiltrate pneumothora effusion acute small disease',
#   'contaminated_positions': [(7, 'muscle'),
#    (0, 'lumbosacral'),
#    (3, 'imaging'),
#    (3, 'l5s1'),
#    (7, 'imaging'),
#    (6, 'compression'),
#    (12, 'small')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit size lung clear focal airspace disease pneumothora pleural effusion lung volume low normal acute bony finding acute cardiopulmonary finding',
#   'contaminated_text': 'cardiomediastinal silhouette herniation sac evidence normal limit root lung significant thecal airspace compression sac sac herniation lung herniation low normal disc bony finding acute compression finding',
#   'contaminated_positions': [(15, 'herniation'),
#    (14, 'sac'),
#    (13, 'sac'),
#    (10, 'thecal'),
#    (9, 'significant'),
#    (17, 'herniation'),
#    (2, 'herniation'),
#    (12, 'compression'),
#    (4, 'evidence'),
#    (20, 'disc'),
#    (3, 'sac'),
#    (24, 'compression'),
#    (7, 'root')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'small_nodular_opacity_left lung seen frontal view overlying left 6th posterior rib lung otherwise appear clear focal airspace consolidation overt pulmonary edema pleural effusion pneumothora heart size mediastinal contour within normal limit calcified mediastinal hilar lymph consistent prior granulomatous_disease mild degenerative change spine small_nodular_opacity_left upper lung small nodule relatively dense suggestive chronic granulomatous_disease comparison chest radiograph would helpful establish stability',
#   'contaminated_text': 'left lung evidence left sac overlying left signal posterior foramen lung otherwise within left foramen airspace consolidation left pulmonary bulge pleural effusion pneumothora heart size mediastinal contour narrowing normal annular calcified mediastinal annulus lymph left within noted mild degenerative change spine degenerative upper lung small nodule relatively left suggestive probably granulomatous_disease comparison chest radiograph would helpful establish fibrosus',
#   'contaminated_positions': [(0, 'sac'),
#    (2, 'evidence'),
#    (32, 'annulus'),
#    (35, 'within'),
#    (7, 'left'),
#    (7, 'side'),
#    (7, 'annulus'),
#    (9, 'foramen'),
#    (17, 'degenerative'),
#    (17, 'left'),
#    (7, 'signal'),
#    (13, 'left'),
#    (34, 'left'),
#    (14, 'foramen'),
#    (3, 'left'),
#    (0, 'disc'),
#    (36, 'noted'),
#    (27, 'narrowing'),
#    (41, 'degenerative'),
#    (29, 'annular'),
#    (19, 'bulge'),
#    (4, 'sac'),
#    (12, 'compressing'),
#    (49, 'probably'),
#    (47, 'paramedianposterolateral'),
#    (47, 'left'),
#    (0, 'left'),
#    (12, 'within'),
#    (57, 'fibrosus')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'}]

# %%
def vectorisation_glove(data, wv, indice_anomalie=None):
    """
    Fonction qui vectorise les données textuelles en utilisant le modèle GLOVE, puis réduit les dimensions 
    des vecteurs pour les afficher graphiquement dans un espace 2D.
    
    - data : liste de document (chaque texte sera vectorisé mot par mot, puis moyenné).
    - wv : Le modèle GLOVE chargé ('glove-wiki-gigaword-300').
    - indice_anomalie : les indices des documents ou on a injecté des anomalies. 
    
    retourne la liste des vecteurs correspondant aux textes ou chaque document sera présenté par un point.
    """
    
    def vectoriser_texte(texte, wv, embedding_dim=300):
        """
        Vectorise un texte en moyennant les vecteurs de ses mots. 
        Si un mot n'existe pas dans le modèle GLOVE, il est ignoré.
        """
        mots = texte.split()
        vecteurs = [wv[mot] for mot in mots if mot in wv]  # extraire les vecteurs des mots existants dans GLOVE
        return np.mean(vecteurs, axis=0) if vecteurs else np.zeros(embedding_dim)  # retourner le vecteur moyen

    # vectorisation de tous les textes
    vecteurs = [vectoriser_texte(texte, wv) for texte in data]
    vecteurs = np.array(vecteurs)

    # réduction de la dimension avec t-SNE
    tsne = TSNE(n_components=2, random_state=42)  # réduire à 2 dimensions
    vecteurs_2d = tsne.fit_transform(vecteurs)  # appliquer t-SNE
    
    # couleurs des points ( rouge : anomalie, bleu : noraml)
    couleurs = ['b'] * len(data)
    if indice_anomalie:
        for i in indice_anomalie:
            if 0 <= i < len(data): 
                couleurs[i] = 'r'

    # affichage graphique des données dans l'espace 2D
    plt.figure(figsize=(60, 30)) 
    plt.scatter(vecteurs_2d[:, 0], vecteurs_2d[:, 1], c=couleurs, marker='o') 

    plt.title("Représentation graphique des documents vectorisés")
    plt.grid(True)
    #plt.savefig("output.jpg")
    plt.show()
    return vecteurs

# %%
vectorisation_glove(contaminated, wv, indices)
# Out:
# array([[-0.24678329,  0.12556681,  0.01996319, ..., -0.1001235 ,
#         -0.00785575, -0.19792338],
#        [-0.08675133,  0.16263327,  0.08046556, ..., -0.0704555 ,
#          0.08676589, -0.29724643],
#        [-0.33040616, -0.04434942,  0.26378086, ..., -0.17089991,
#         -0.03175143, -0.26263165],
#        ...,
#        [-0.21126644,  0.08089105, -0.07059405, ..., -0.1443377 ,
#         -0.01731796, -0.26016346],
#        [-0.19477817,  0.18117069,  0.0568497 , ...,  0.0003723 ,
#          0.03765953, -0.36902636],
#        [-0.19373263,  0.13672999,  0.0099001 , ..., -0.0798294 ,
#          0.066955  , -0.25152177]])

# %%
def contamination_function_bis(data1, data2, contamination_rate=0.1):
    """
    Fonction qui génère des anomalie dans notre jeu de données data1, en injectant des donnée de data2.
    
    - data1 : Corpus de données sain
    - data2 : Corpus de données considérées "anomalie"
    - contamination_rate : le taux de document contaminé par rapport a la taille de data1
    
    retourne un nouveau corpus de données avec des anomalies + les indices des anomalies
    """
    contamination_log = []
    
    #on contamine % des documents dans data1 
    df_size = max(1, int(len(data1) * contamination_rate))  
    selected_indices = random.sample(range(len(data1)), df_size)
    
    for i in selected_indices:
        base_text = data1[i]
        new_text = random.choice(data2)
        data1[i] = new_text  # remplacement de la ligne 

        # un log pour surveiller le fonctionnement de la fonction (à ajouter dans le return)
        contamination_log.append({
            "base_text": base_text,  # le texte original avant remplacement
            "contaminated_text": new_text,  # le texte après remplacement
            "index_replaced": i  # l'index de la ligne modifiée
        })

    return data1, selected_indices

# %%
data_new, ind= contamination_function_bis(base_texts, anomaly_texts)

# %%
X_glove = vectorisation_glove(data_new, wv, ind)

# %%
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X_glove, test_size=0.2, random_state=42)

# Initialisation et entraînement du modèle sur les données d'entraînement
model_iforest = IsolationForest(n_estimators=100, contamination=0.1, random_state=42)
model_iforest.fit(X_train)

# Prédiction sur l'ensemble d'entraînement et de test
y_pred_train = model_iforest.predict(X_train)
y_pred_test = model_iforest.predict(X_test)

# %%
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Fonction pour afficher les anomalies détectées
def create_scatter_plots(X1, y1, title1, X2, y2, title2):
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Scatter plot pour les données d'entraînement
    axes[0].scatter(X1[y1 == 1, 0], X1[y1 == 1, 1], color='blue', label='Normal', s=10)
    axes[0].scatter(X1[y1 == -1, 0], X1[y1 == -1, 1], color='red', label='Anomaly', s=10)
    axes[0].set_title(title1)
    axes[0].legend()

    # Scatter plot pour les données de test
    axes[1].scatter(X2[y2 == 1, 0], X2[y2 == 1, 1], color='blue', label='Normal', s=10)
    axes[1].scatter(X2[y2 == -1, 0], X2[y2 == -1, 1], color='red', label='Anomaly', s=10)
    axes[1].set_title(title2)
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# Affichage des anomalies détectées
create_scatter_plots(X_train_pca, y_pred_train, 'Training Data', X_test_pca, y_pred_test, 'Test Data')
