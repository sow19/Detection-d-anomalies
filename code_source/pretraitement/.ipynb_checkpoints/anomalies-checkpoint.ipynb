# %%
import gensim.downloader as api
import pandas as pd
import numpy as np
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.decomposition import PCA
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import StandardScaler
wv = api.load('glove-wiki-gigaword-300')
# Out:
# 2025-03-16 22:02:12.335094: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-16 22:02:12.472508: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-16 22:02:13.009234: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-16 22:02:13.011113: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-16 22:02:15.223623: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [===-----------------------------------------------] 6.2% 23.4/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=======-------------------------------------------] 14.2% 53.6/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===========---------------------------------------] 22.4% 84.1/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===============-----------------------------------] 30.8% 115.8/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===================-------------------------------] 39.2% 147.4/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=======================---------------------------] 47.5% 178.6/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===========================-----------------------] 55.9% 210.1/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [================================------------------] 64.3% 241.7/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [====================================--------------] 72.4% 272.5/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [========================================----------] 80.9% 304.2/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=============================================-----] 91.3% 343.3/376.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==================================================] 100.0% 376.1/376.1MB downloaded

# %%
csv1 = "../../data/cleaned/final_clean_data1.csv"
csv2 = "../../data/cleaned/final_clean_data2.csv"
base_texts = pd.read_csv(csv1).iloc[:, 0]
anomaly_texts = pd.read_csv(csv2).iloc[:, 0]

# %%
def key_words(column, top_n=20):
    """
    En utilisant la métrique tf-dif, la fonction retourne les top_n premiers mots-clés dans le dataset.
    """
    vectorizer = TfidfVectorizer()
    x = vectorizer.fit_transform(column)
    feature_names = vectorizer.get_feature_names_out()
    
    kw_per_text = []
    for doc_idx in range(x.shape[0]):
        # récupérer les scores tf-dif pour le texte courant
        tfidf_scores = x[doc_idx].toarray()[0]

        # associer chaque mot avec son score tf-dif
        word_scores = [(feature_names[i], tfidf_scores[i]) for i in range(len(feature_names))]

        # trier les mots par score décroissant
        sorted_words = sorted(word_scores, key=lambda x: x[1], reverse=True)

        # récupérer les top_n mots-clés
        keywords = [word for word, score in sorted_words[:top_n]]
        kw_per_text.append(keywords)

    return kw_per_text

# %%
def contamination_function(data1, data2, contamination_rate=0.5):
    contaminated_texts = []
    contamination_log = []
    data1_kw = key_words(data1)
    data2_kw = key_words(data2)
    
    #on prend 15% des documents 
    df_size = max(1, int(len(data1) * 0.15))  
    selected_indices = random.sample(range(len(data1)), df_size)


    #pour mesurer la similarité entre les mots-clés
    vectorizer = TfidfVectorizer()
    all_keywords = data1_kw + data2_kw
    tfidf_matrice = vectorizer.fit_transform([' '.join(kw) for kw in all_keywords]) #matrice de tout les mots clés
    base_vectors = tfidf_matrice[:len(data1_kw)] 
    anomaly_vectors = tfidf_matrice[len(data1_kw):]
    
    for i in selected_indices:
        base_text = data1[i]
        words = base_text.split()  
        total_words = len(words)
        words_to_contaminate = max(1, int(total_words * contamination_rate))  # mots à contaminer
        # trouver les anomalies les moins similaires (mots clés du text avec toutes les anomalies)
        similarities = cosine_similarity(base_vectors[i], anomaly_vectors)
        best_anomaly_idx = similarities.argmin()
        anomaly_text = data2[best_anomaly_idx]
        anomaly_words = anomaly_text.split()  # les mots de l'anomalie
        # tontaminer les mots du texte de base
        contaminated_words = words[:]
        contaminated_positions = []

        for _ in range(words_to_contaminate):
            # choisir un mot d'anomalie aléatoire
            anomaly_word = random.choice(anomaly_words)
            #position aléatoire dans le document de base
            position = random.randint(0, total_words - 1)

            # mettre le mot à cette position
            contaminated_words[position] = anomaly_word
            contaminated_positions.append((position, anomaly_word))

        #le texte contaminé
        contaminated_text = ' '.join(contaminated_words)
        contaminated_texts.append(contaminated_text)
        data1[i] = contaminated_text

        #résumé des contaminations (à supprimer aprés)
        contamination_log.append({
            "base_text": base_text,
            "contaminated_text": contaminated_text,
            "contaminated_positions": contaminated_positions,
            "anomaly_text": anomaly_text
        })

    return data1, contamination_log, selected_indices

# %%
contaminated, log, indices = contamination_function(base_texts, anomaly_texts)
log
# Out:
# [{'base_text': 'heart size normal lung clear normal pneumonia effusion edema pneumothora adenopathy nodule mass normal chest evidence sarcoidosis',
#   'contaminated_text': 'heart protrusion normal lung protrusion spine pneumonia effusion edema pneumothora adenopathy nodule significant normal noted central sarcoidosis',
#   'contaminated_positions': [(12, 'feature'),
#    (12, 'thecal_sac'),
#    (4, 'protrusion'),
#    (5, 'spine'),
#    (14, 'noted'),
#    (15, 'central'),
#    (1, 'protrusion'),
#    (12, 'significant')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart slightly large pulmonary normal infiltrates slight cardiomegaly failure pneumonia',
#   'contaminated_text': 'thecal slightly large annulus left infiltrates nerve cardiomegaly signal pneumonia',
#   'contaminated_positions': [(6, 'nerve'),
#    (4, 'left'),
#    (0, 'thecal'),
#    (3, 'annulus'),
#    (8, 'signal')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiopulmonary silhouette normal heart size normal lung clear pulmonary effusion pneumothora acute cardiopulmonary finding',
#   'contaminated_text': 'area neural normal heart narrowing annulus torn clear pulmonary effusion evidence acute cardiopulmonary finding',
#   'contaminated_positions': [(10, 'evidence'),
#    (6, 'torn'),
#    (4, 'left'),
#    (0, 'area'),
#    (1, 'neural'),
#    (4, 'narrowing'),
#    (5, 'annulus')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'focal airspace disease pleural effusion pneumothora cardiomediastinal silhouette within normal limit free subdiaphragmatic air acute pulmonary disease',
#   'contaminated_text': 'nerve airspace disease herniation effusion pneumothora cardiomediastinal herniation nerve noted limit free subdiaphragmatic sac acute pulmonary nerve',
#   'contaminated_positions': [(9, 'noted'),
#    (16, 'nerve'),
#    (7, 'herniation'),
#    (8, 'herniation'),
#    (3, 'herniation'),
#    (0, 'nerve'),
#    (13, 'sac'),
#    (8, 'nerve')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'normal cardiomediastinal silhouette focal consolidation large pleural effusion pneumothora acute bony abnormality seen probable old lateral right rib fracture radiographic evidence acute cardiopulmonary disease',
#   'contaminated_text': 'normal cardiomediastinal significant nerve consolidation large pleural feature thecal_sac acute bony abnormality seen imaging old l5s1 thecal_sac rib fracture compression small acute cardiopulmonary disease',
#   'contaminated_positions': [(7, 'root'),
#    (3, 'nerve'),
#    (15, 'imaging'),
#    (7, 'feature'),
#    (8, 'lumbosacral'),
#    (19, 'compression'),
#    (2, 'significant'),
#    (16, 'thecal_sac'),
#    (13, 'imaging'),
#    (20, 'small'),
#    (8, 'thecal_sac'),
#    (15, 'l5s1')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart normal size mediastinum unremarkable lung clear slight thoracolumbar curvature noted acute disease',
#   'contaminated_text': 'compressing disc size mediastinum unremarkable lung right probably right curvature noted acute disease',
#   'contaminated_positions': [(8, 'annular'),
#    (8, 'right'),
#    (0, 'compressing'),
#    (1, 'disc'),
#    (7, 'probably'),
#    (6, 'right')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'airspace_opacity_left_upper lung heart size within normal limit mild calcification aortic pneumothora pleural effusion airspace_opacity_left_upper lung may represent streaky atelectasis resolving pneumonia',
#   'contaminated_text': 'airspace_opacity_left_upper lung heart noted within normal root mild calcification thecal root pleural effusion thecal lung herniation thecal noted atelectasis resolving pneumonia',
#   'contaminated_positions': [(6, 'root'),
#    (16, 'thecal'),
#    (10, 'thecal'),
#    (15, 'noted'),
#    (10, 'root'),
#    (13, 'thecal'),
#    (15, 'herniation'),
#    (3, 'noted'),
#    (9, 'thecal'),
#    (17, 'noted')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'patchy_airspace_disease left lingula significant effusion clear right lung normal heart size granulomatous mediastinal calcification right chest tip superior vena cava patchy_airspace_disease lingula without evidence effusion pneumonia differential followup eam week considered ensure resolution process',
#   'contaminated_text': 'patchy_airspace_disease left lingula significant effusion sac l4l5 lung normal bulge noted granulomatous mediastinal calcification compressing chest l4l5 superior vena cava encroaching thecal without compressing effusion compressing encroaching followup eam thecal muscle ensure resolution sac',
#   'contaminated_positions': [(6, 'disc'),
#    (6, 'l4l5'),
#    (21, 'thecal'),
#    (16, 'l4l5'),
#    (29, 'root'),
#    (33, 'sac'),
#    (30, 'muscle'),
#    (14, 'compressing'),
#    (25, 'compressing'),
#    (10, 'noted'),
#    (26, 'encroaching'),
#    (29, 'thecal'),
#    (5, 'sac'),
#    (9, 'bulge'),
#    (23, 'spasm'),
#    (20, 'encroaching'),
#    (23, 'compressing')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'heart size mediastinal contour normal lung clear ecept residual prior granulomatous infection pleural effusion pneumothoraces acute cardiopulmonary process',
#   'contaminated_text': 'sac disc mediastinal contour normal lung compressing ecept area prior granulomatous fibrosus evidence effusion area acute cardiopulmonary process',
#   'contaminated_positions': [(6, 'left'),
#    (12, 'neural'),
#    (11, 'fibrosus'),
#    (8, 'area'),
#    (6, 'compressing'),
#    (0, 'sac'),
#    (14, 'area'),
#    (12, 'evidence'),
#    (1, 'disc')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung hyperepanded infiltrates mass lung heart size normal change calcified left hilar left small granuloma change chronic obstructive pulmonary disease acute disease',
#   'contaminated_text': 'sac hyperepanded infiltrates noted herniation nerve root normal change significant left hilar left sac granuloma change chronic obstructive pulmonary evidence acute disease',
#   'contaminated_positions': [(0, 'sac'),
#    (6, 'disc'),
#    (19, 'evidence'),
#    (3, 'herniation'),
#    (6, 'root'),
#    (13, 'sac'),
#    (5, 'nerve'),
#    (9, 'significant'),
#    (4, 'evidence'),
#    (4, 'herniation'),
#    (3, 'noted')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'focal consolidation visualized pneumothora heart size normal large pleural effusion cardiomediastinal silhouette grossly unremarkable acute cardiopulmonary finding',
#   'contaminated_text': 'l45 within fibrosus pneumothora probably size root large pleural left cardiomediastinal silhouette right unremarkable acute cardiopulmonary annulus',
#   'contaminated_positions': [(6, 'root'),
#    (0, 'l45'),
#    (12, 'right'),
#    (16, 'annulus'),
#    (9, 'left'),
#    (4, 'probably'),
#    (2, 'fibrosus'),
#    (1, 'within')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size normal cardiomediastinal silhouette normal contour lung clear bilaterally pleural effusion pneumothora bony soft tissue abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'l45 size normal cardiomediastinal probably normal represents lung clear probably pleural effusion side thecal soft tissue fibrosus acute cardiopulmonary abnormality',
#   'contaminated_positions': [(9, 'narrowing'),
#    (16, 'fibrosus'),
#    (12, 'side'),
#    (13, 'thecal'),
#    (4, 'probably'),
#    (6, 'represents'),
#    (9, 'foramen'),
#    (0, 'l45'),
#    (13, 'thecal'),
#    (9, 'probably')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'normal cardiac contour clear lung bilaterally pleural effusion pneumothora degenerative seen throughout cervical spine acute cardiopulmonary abnormality',
#   'contaminated_text': 'normal cardiac contour clear encroaching l5s1 pleural l5s1 pneumothora degenerative seen throughout cervical encroaching acute noted spasm',
#   'contaminated_positions': [(15, 'noted'),
#    (7, 'l5s1'),
#    (16, 'spasm'),
#    (13, 'encroaching'),
#    (5, 'muscle'),
#    (5, 'level'),
#    (4, 'encroaching'),
#    (5, 'l5s1')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'lung hyperepanded focal airspace consolidation suspicious pulmonary mass nodule seen pleural effusion pneumothora normal heart size mediastinal contour focal air space consolidation hyperepanded lung suggestive emphysema',
#   'contaminated_text': 'lung hyperepanded focal airspace root suspicious evidence within bulge seen pleural effusion annular signal heart size mediastinal right annular air compressing consolidation area fibrosus left emphysema',
#   'contaminated_positions': [(7, 'within'),
#    (17, 'right'),
#    (18, 'annular'),
#    (23, 'fibrosus'),
#    (20, 'compressing'),
#    (13, 'signal'),
#    (4, 'torn'),
#    (6, 'evidence'),
#    (4, 'root'),
#    (22, 'area'),
#    (12, 'annular'),
#    (8, 'bulge'),
#    (24, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear without focal air space opacity cardiomediastinal silhouette normal size contour pneumothora large pleural effusion acute cardiopulmonary abnormality',
#   'contaminated_text': 'noted clear without focal sac space opacity annular silhouette normal size area pneumothora right pleural effusion evidence evidence abnormality',
#   'contaminated_positions': [(13, 'right'),
#    (11, 'area'),
#    (4, 'signal'),
#    (17, 'evidence'),
#    (7, 'paramedianposterolateral'),
#    (16, 'evidence'),
#    (7, 'annular'),
#    (4, 'sac'),
#    (0, 'noted')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette vasculature within normal limit size contour chronic appearing interstitial marking right upper lobe granuloma stable lung normally inflated clear degenerative change spine chronic change without acute process',
#   'contaminated_text': 'cardiomediastinal silhouette thecal thecal normal limit size contour thecal appearing interstitial root right disc lobe herniation herniation lung normally inflated clear degenerative herniation herniation chronic change disc acute nerve',
#   'contaminated_positions': [(26, 'disc'),
#    (3, 'thecal'),
#    (28, 'thecal'),
#    (22, 'herniation'),
#    (28, 'nerve'),
#    (16, 'root'),
#    (23, 'herniation'),
#    (13, 'disc'),
#    (8, 'thecal'),
#    (2, 'evidence'),
#    (2, 'thecal'),
#    (15, 'herniation'),
#    (11, 'root'),
#    (16, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung pleural space show acute abnormality heart size pulmonary vascularity within normal limit acute pulmonary abnormality',
#   'contaminated_text': 'lung muscle space show acute abnormality thecal_sac muscle thecal_sac vascularity within abutting limit feature pulmonary abnormality',
#   'contaminated_positions': [(6, 'compression'),
#    (8, 'thecal_sac'),
#    (7, 'muscle'),
#    (6, 'abutting'),
#    (1, 'muscle'),
#    (11, 'abutting'),
#    (6, 'thecal_sac'),
#    (13, 'feature')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'lung clear focal airspace consolidation pleural effusion pneumothora normal cardiomediastinal silhouette postoperative change cervical spine fusion active disease',
#   'contaminated_text': 'nerve clear focal airspace consolidation paramedianposterolateral effusion left normal cardiomediastinal silhouette postoperative change right spine probably right root',
#   'contaminated_positions': [(7, 'left'),
#    (15, 'probably'),
#    (16, 'right'),
#    (5, 'thecal'),
#    (5, 'area'),
#    (13, 'right'),
#    (17, 'root'),
#    (0, 'nerve'),
#    (5, 'paramedianposterolateral')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'central venous catheter tip right atrium heart size shape normal trachea bronchus appear normal lung reasonably well epanded patchy nodular density lower lung marked right left scattered area bronchial wall thickening wellseen left upper lobe loss definition part left heart effusion pneumothora finding consistent widespread change cystic fibrosis difficult differentiate acute chronic change',
#   'contaminated_text': 'central venous catheter tip right sac evidence size shape herniation trachea bronchus appear normal lung noted well epanded nerve nodular density lower lung marked right left scattered herniation bronchial wall root evidence left root lobe evidence definition part disc root effusion pneumothora noted compression compression nerve cystic disc difficult differentiate noted thecal thecal',
#   'contaminated_positions': [(47, 'sac'),
#    (6, 'evidence'),
#    (44, 'compression'),
#    (42, 'noted'),
#    (47, 'disc'),
#    (30, 'root'),
#    (15, 'noted'),
#    (31, 'evidence'),
#    (6, 'root'),
#    (33, 'nerve'),
#    (33, 'root'),
#    (18, 'sac'),
#    (18, 'thecal'),
#    (6, 'evidence'),
#    (27, 'herniation'),
#    (9, 'herniation'),
#    (38, 'disc'),
#    (45, 'nerve'),
#    (18, 'nerve'),
#    (43, 'compression'),
#    (35, 'evidence'),
#    (51, 'thecal'),
#    (52, 'thecal'),
#    (39, 'root'),
#    (5, 'sac'),
#    (50, 'noted')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'focal area consolidation suspicious pulmonary opacity mild degenerative change thoracic spine pleural effusion evidence pneumothora heart size normal limit acute cardiopulmonary abnormality',
#   'contaminated_text': 'focal l5s1 consolidation suspicious pulmonary opacity eit degenerative change mildly compressing pleural effusion l5s1 pneumothora heart size normal nerve acute cardiopulmonary abnormality',
#   'contaminated_positions': [(10, 'bulge'),
#    (10, 'muscle'),
#    (10, 'spasm'),
#    (18, 'compressing'),
#    (10, 'compressing'),
#    (1, 'l5s1'),
#    (13, 'l5s1'),
#    (6, 'eit'),
#    (18, 'nerve'),
#    (9, 'diffuse'),
#    (9, 'mildly')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'minimal_righttoleft_cardiomediastinal_shift cardiomediastinal silhouette otherwise normal size configuration pulmonary vasculature within normal limit moderate_sized_right_pneumothora measure 32 cm level right ape moderate_sized_right_pneumothora minimal_righttoleft_cardiomediastinal_shift suggesting',
#   'contaminated_text': 'minimal_righttoleft_cardiomediastinal_shift cardiomediastinal level_mild_compressing_thecal l5s1 normal size configuration muscle vasculature muscle l5s1 limit lumbosacral imaging 32 cm sac_nerve_root right muscle moderate_sized_right_pneumothora minimal_righttoleft_cardiomediastinal_shift imaging',
#   'contaminated_positions': [(13, 'imaging'),
#    (18, 'muscle'),
#    (12, 'lumbosacral'),
#    (21, 'imaging'),
#    (7, 'muscle'),
#    (16, 'spasm'),
#    (9, 'muscle'),
#    (3, 'l5s1'),
#    (2, 'level_mild_compressing_thecal'),
#    (10, 'l5s1'),
#    (16, 'sac_nerve_root')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm diffuse disc_bulge_noted l4l5 level_mild_compressing_thecal sac_nerve_root wide base disc_bulge_noted l5s1 level_mild_compressing_thecal sac_nerve_root'},
#  {'base_text': 'cardiomediastinal silhouette stable lung_volume remain low pleural line suggest pneumothora costophrenic blunting suggest large pleural effusion bony structure within normal limit low lung_volume acute cardiopulmonary finding',
#   'contaminated_text': 'evidence herniation compression thecal remain low significant line sac significant costophrenic nerve compression large pleural effusion bony structure within normal limit evidence thecal disc cardiopulmonary thecal',
#   'contaminated_positions': [(0, 'evidence'),
#    (1, 'herniation'),
#    (11, 'nerve'),
#    (8, 'sac'),
#    (3, 'thecal'),
#    (2, 'compression'),
#    (12, 'compression'),
#    (25, 'thecal'),
#    (9, 'significant'),
#    (6, 'significant'),
#    (22, 'thecal'),
#    (23, 'disc'),
#    (21, 'evidence')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear without focal consolidation effusion pneumothora normal heart size negative pneumoperitoneum mild degenerative change thoracic spine negative acute cardiopulmonary abnormality',
#   'contaminated_text': 'diffuse spasm bulge focal consolidation effusion diffuse normal heart size negative compressing mild degenerative change thecal spasm negative acute eit abnormality',
#   'contaminated_positions': [(1, 'spasm'),
#    (11, 'compressing'),
#    (2, 'bulge'),
#    (0, 'diffuse'),
#    (16, 'encroaching'),
#    (6, 'diffuse'),
#    (16, 'spasm'),
#    (19, 'eit'),
#    (15, 'thecal'),
#    (11, 'compressing')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'heart normal size mediastinum unremarkable lung clear acute disease',
#   'contaminated_text': 'disc normal size mediastinum unremarkable neural clear acute evidence',
#   'contaminated_positions': [(5, 'neural'),
#    (0, 'torn'),
#    (0, 'disc'),
#    (8, 'evidence')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit size lung wellinflated grossly clear focal airspace disease pneumothora pleural effusion acute bony finding a terminating superior surgical clip left breast ailla acute cardiopulmonary finding',
#   'contaminated_text': 'cardiomediastinal thecal pulmonary sac compression normal nerve evidence lung wellinflated grossly clear focal airspace disease pneumothora disc effusion significant significant sac a sac superior evidence clip left breast herniation evidence thecal finding',
#   'contaminated_positions': [(30, 'sac'),
#    (24, 'evidence'),
#    (28, 'herniation'),
#    (1, 'thecal'),
#    (29, 'evidence'),
#    (19, 'significant'),
#    (22, 'sac'),
#    (4, 'compression'),
#    (3, 'disc'),
#    (7, 'evidence'),
#    (20, 'sac'),
#    (30, 'thecal'),
#    (3, 'sac'),
#    (16, 'disc'),
#    (6, 'nerve'),
#    (18, 'significant')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung appear clear thoracic_aorta remains tortuous presence aortic aneurysm_ecluded study calcified mediastinal hilar lymph suggesting prior histoplasmosis infection pleural space clear stable tortuosity thoracic_aorta presence underlying aneurysm_ecluded clear lung',
#   'contaminated_text': 'disc appear clear l45 remains tortuous presence aortic aneurysm_ecluded study calcified signal hyperintense lymph suggesting prior probably thecal pleural fibrosus clear narrowing tortuosity nerve presence underlying aneurysm_ecluded clear annulus',
#   'contaminated_positions': [(12, 'annular'),
#    (0, 'disc'),
#    (16, 'probably'),
#    (21, 'narrowing'),
#    (12, 'hyperintense'),
#    (3, 'l45'),
#    (11, 'paramedianposterolateral'),
#    (28, 'torn'),
#    (28, 'paramedianposterolateral'),
#    (23, 'nerve'),
#    (11, 'signal'),
#    (28, 'annulus'),
#    (17, 'thecal'),
#    (19, 'fibrosus')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size mediastinal contour pulmonary vascularity within normal limit focal consolidation large pleural effusion pneumothora identified minimal thoracic spondylosis acute cardiopulmonary abnormality',
#   'contaminated_text': 'heart size mediastinal contour nerve vascularity within normal abutting muscle consolidation feature pleural l5s1 thecal_sac disc minimal thoracic spondylosis small cardiopulmonary abnormality',
#   'contaminated_positions': [(14, 'thecal_sac'),
#    (9, 'muscle'),
#    (8, 'muscle'),
#    (15, 'spine'),
#    (8, 'abutting'),
#    (15, 'disc'),
#    (4, 'nerve'),
#    (19, 'small'),
#    (13, 'spine'),
#    (11, 'feature'),
#    (13, 'l5s1')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart pulmonary mediastinum within normal limit pleural effusion pneumothora focal air space opacity suggest pneumonia minimal degenerative change spine acute cardiopulmonary disease',
#   'contaminated_text': 'heart pulmonary mediastinum root significant nerve pleural effusion pneumothora focal air significant nerve nerve disc minimal degenerative root noted acute cardiopulmonary disease',
#   'contaminated_positions': [(13, 'nerve'),
#    (18, 'herniation'),
#    (3, 'root'),
#    (12, 'nerve'),
#    (17, 'herniation'),
#    (14, 'disc'),
#    (18, 'noted'),
#    (4, 'significant'),
#    (11, 'significant'),
#    (5, 'nerve'),
#    (17, 'root')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'normal heart size stable tortuous aorta pneumothora pleural effusion suspicious focal airspace opacity prior granulomatous disease unchanged eam without acute abnormality',
#   'contaminated_text': 'annulus heart degenerative signal tortuous nerve pneumothora pleural effusion suspicious focal paramedianposterolateral opacity prior left disease unchanged eam foramen acute abnormality',
#   'contaminated_positions': [(18, 'within'),
#    (14, 'left'),
#    (11, 'paramedianposterolateral'),
#    (18, 'annular'),
#    (18, 'foramen'),
#    (3, 'signal'),
#    (5, 'nerve'),
#    (0, 'right'),
#    (2, 'degenerative'),
#    (0, 'annulus')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear without focal consolidation effusion pneumothora normal heart size bony thora soft tissue unremarkable negative acute cardiopulmonary abnormality',
#   'contaminated_text': 'left clear without focal fibrosus effusion pneumothora foramen left size compressing evidence compressing tissue unremarkable negative acute cardiopulmonary abnormality',
#   'contaminated_positions': [(0, 'left'),
#    (8, 'left'),
#    (11, 'represents'),
#    (4, 'narrowing'),
#    (10, 'compressing'),
#    (4, 'fibrosus'),
#    (12, 'compressing'),
#    (7, 'foramen'),
#    (11, 'evidence')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'borderline_enlarged_heart torturousectatic thoracic_aorta focal pulmonary opacity pleural effusion pneumothora degenerative_change spine fracture_distal_right_clavicle better_seen right shoulder radiograph dated small round lucency distal left clavicle appears benign degenerative_change joint borderline_enlarged_heart tortuousectatic thoracic_aorta fracture_distal_right_clavicle better_seen today radiograph shoulder',
#   'contaminated_text': 'borderline_enlarged_heart torturousectatic thoracic_aorta disc pulmonary thecal pleural evidence nerve sac spine sac root right noted radiograph dated small round lucency distal left clavicle appears significant degenerative_change joint evidence significant thoracic_aorta fracture_distal_right_clavicle significant today radiograph disc',
#   'contaminated_positions': [(34, 'disc'),
#    (14, 'noted'),
#    (24, 'significant'),
#    (9, 'sac'),
#    (27, 'evidence'),
#    (12, 'root'),
#    (31, 'thecal'),
#    (31, 'significant'),
#    (8, 'nerve'),
#    (5, 'noted'),
#    (7, 'sac'),
#    (5, 'herniation'),
#    (28, 'significant'),
#    (11, 'sac'),
#    (7, 'evidence'),
#    (3, 'disc'),
#    (5, 'thecal')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear epanded heart mediastinum normal surgical clip epigastrium abdomen active disease',
#   'contaminated_text': 'annulus paramedianposterolateral side heart bulge normal surgical clip epigastrium represents active disease',
#   'contaminated_positions': [(9, 'represents'),
#    (2, 'side'),
#    (4, 'bulge'),
#    (0, 'nerve'),
#    (0, 'annulus'),
#    (1, 'paramedianposterolateral')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart normal size mediastinum unremarkable pleural effusion pneumothora focal airspace disease unremarkable acute cardiopulmonary abnormality',
#   'contaminated_text': 'heart normal annulus signal unremarkable right effusion pneumothora focal annular disease unremarkable acute sac compressing',
#   'contaminated_positions': [(9, 'annular'),
#    (5, 'right'),
#    (2, 'annulus'),
#    (13, 'sac'),
#    (14, 'nerve'),
#    (14, 'compressing'),
#    (3, 'signal')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiac mediastinal silhouette unremarkable lung well epanded clear focal air space opacity pneumothora effusion calcified hilar lymph suggesting prior granulomatous disease bony structure thora intact evidence_acute osseous abnormality evidence_acute cardiopulmonary process',
#   'contaminated_text': 'root mediastinal thecal unremarkable lung well epanded clear side air space disc pneumothora within compressing probably left suggesting noted neural compressing bony structure thora annular compressing osseous abnormality compressing within process',
#   'contaminated_positions': [(18, 'noted'),
#    (19, 'neural'),
#    (11, 'disc'),
#    (25, 'compressing'),
#    (15, 'probably'),
#    (8, 'side'),
#    (13, 'within'),
#    (29, 'within'),
#    (0, 'root'),
#    (16, 'left'),
#    (14, 'compressing'),
#    (2, 'thecal'),
#    (20, 'compressing'),
#    (24, 'annular'),
#    (28, 'compressing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'eamination consists frontal lateral radiograph_chest cardiomediastinal contour lung pleura osseous structure visualized upper abdomen normal unremarkable radiograph_chest',
#   'contaminated_text': 'eamination consists frontal lateral annulus narrowing area lung pleura osseous structure side compressing noted normal narrowing radiograph_chest',
#   'contaminated_positions': [(5, 'narrowing'),
#    (6, 'thecal'),
#    (6, 'area'),
#    (4, 'annulus'),
#    (13, 'noted'),
#    (15, 'narrowing'),
#    (12, 'compressing'),
#    (11, 'side')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart pulmonary mediastinum within normal limit pleural effusion pneumothora focal air space opacity suggest pneumonia small stable foreign body noted left chest vascular calcification aortic mild degenerative change spine acute cardiopulmonary disease',
#   'contaminated_text': 'heart pulmonary compression neural normal limit pleural effusion disc_bulge focal right space opacity suggest central right posterolateral compression body noted endplate chest vascular thecal_sac disc_bulge_noted_indenting formation formation posterolateral spine right cardiopulmonary disease',
#   'contaminated_positions': [(26, 'formation'),
#    (23, 'thecal_sac'),
#    (15, 'endplate'),
#    (27, 'posterolateral'),
#    (29, 'right'),
#    (24, 'disc_bulge_noted_indenting'),
#    (17, 'compression'),
#    (15, 'right'),
#    (2, 'compression'),
#    (10, 'right'),
#    (3, 'neural'),
#    (16, 'posterolateral'),
#    (14, 'central'),
#    (8, 'disc_bulge'),
#    (20, 'endplate'),
#    (25, 'formation')],
#   'anomaly_text': 'l12 central disc_bulge_noted_indenting thecal_sac l34 right posterolateral disc_bulge noted endplate osteophyte formation causing compression right nerve root within neural foramen l5s1 right paramedian disc_bulge_noted_indenting thecal_sac'},
#  {'base_text': 'image heart size pulmonary vascular engorgement appear within limit normal mediastinal contour unremarkable focal consolidation pleural effusion pneumothora identified convincing acute bony finding acute cardiopulmonary abnormality identified',
#   'contaminated_text': 'image heart size pulmonary vascular engorgement compression within lumbosacral level noted magnetic unremarkable abutting consolidation pleural feature pneumothora identified convincing acute bony spine acute l5s1 abnormality identified',
#   'contaminated_positions': [(13, 'imaging'),
#    (24, 'l5s1'),
#    (13, 'abutting'),
#    (9, 'significant'),
#    (11, 'small'),
#    (9, 'level'),
#    (22, 'lumbosacral'),
#    (10, 'noted'),
#    (6, 'compression'),
#    (16, 'feature'),
#    (22, 'spine'),
#    (8, 'lumbosacral'),
#    (11, 'magnetic')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'normal heart size mild tortuosity aorta pneumothora pleural effusion suspicious airspace opacity mild levoscoliosis lumbar spine acute abnormality seen',
#   'contaminated_text': 'normal probably size degenerative tortuosity aorta area annular root suspicious hyperintense narrowing mild levoscoliosis compressing spine acute probably seen',
#   'contaminated_positions': [(6, 'area'),
#    (10, 'hyperintense'),
#    (1, 'probably'),
#    (14, 'compressing'),
#    (3, 'degenerative'),
#    (8, 'root'),
#    (7, 'annular'),
#    (17, 'probably'),
#    (11, 'narrowing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette vasculature within_normal_limit size contour lung normally inflated clear osseous structure within_normal_limit patient age acute radiographic cardiopulmonary process',
#   'contaminated_text': 'cardiomediastinal silhouette vasculature within_normal_limit size contour lung hyperintense disc annulus annulus structure annulus root age acute radiographic evidence process',
#   'contaminated_positions': [(7, 'hyperintense'),
#    (13, 'signal'),
#    (10, 'annulus'),
#    (8, 'disc'),
#    (13, 'root'),
#    (9, 'side'),
#    (17, 'evidence'),
#    (12, 'annulus'),
#    (9, 'annulus')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'moderate_sized_right_pleural effusion severe slightly smaller compared small_left_pleural_effusion unchanged compared prior_study right chest wall venous appears accessed pneumothora scaphoid abdomen moderate_sized_right_pleural effusion_appears smaller prior_study small_left_pleural_effusion appears unchanged',
#   'contaminated_text': 'moderate_sized_right_pleural effusion root slightly evidence compared small_left_pleural_effusion unchanged compared prior_study right chest sac venous compression nerve pneumothora scaphoid abdomen moderate_sized_right_pleural root significant prior_study sac nerve significant',
#   'contaminated_positions': [(15, 'herniation'),
#    (2, 'root'),
#    (4, 'evidence'),
#    (24, 'noted'),
#    (20, 'root'),
#    (12, 'disc'),
#    (12, 'sac'),
#    (24, 'nerve'),
#    (14, 'compression'),
#    (15, 'nerve'),
#    (25, 'significant'),
#    (21, 'significant'),
#    (23, 'sac')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'increasing primarily basilar interstitial reticular opacity lung volume low focal airspace opacity suggest lobar pneumonia heart size appears normal thoracic aorta calcified since prior study placement electronic cardiac device overlying left chest wall distal lead overlying right heart there pneumothora finding consistent worsening interstitial_lung_disease high resolution recommended confirm prior reveals evidence interstitial_lung_disease',
#   'contaminated_text': 'increasing annular basilar interstitial represents opacity torn nerve annulus focal airspace opacity suggest left pneumonia paramedianposterolateral size left torn thoracic aorta compressing since disc study placement electronic cardiac device hyperintense left chest wall sac lead overlying right heart annulus pneumothora compressing consistent probably interstitial_lung_disease high resolution left nerve degenerative represents evidence interstitial_lung_disease',
#   'contaminated_positions': [(1, 'annular'),
#    (38, 'annulus'),
#    (29, 'hyperintense'),
#    (13, 'within'),
#    (15, 'degenerative'),
#    (21, 'neural'),
#    (13, 'left'),
#    (17, 'area'),
#    (48, 'annulus'),
#    (47, 'compressing'),
#    (15, 'paramedianposterolateral'),
#    (17, 'left'),
#    (6, 'torn'),
#    (21, 'compressing'),
#    (23, 'disc'),
#    (4, 'represents'),
#    (7, 'nerve'),
#    (46, 'left'),
#    (47, 'nerve'),
#    (42, 'probably'),
#    (40, 'compressing'),
#    (18, 'torn'),
#    (48, 'degenerative'),
#    (8, 'annulus'),
#    (49, 'represents'),
#    (33, 'sac')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size mediastinal contour normal pulmonary vascularity normal lung clear pleural effusion pneumothoraces acute cardiopulmonary process',
#   'contaminated_text': 'heart size left contour annulus pulmonary neural normal within hyperintense pleural left pneumothoraces acute cardiopulmonary process',
#   'contaminated_positions': [(2, 'left'),
#    (9, 'hyperintense'),
#    (6, 'neural'),
#    (4, 'annulus'),
#    (4, 'sac'),
#    (4, 'annulus'),
#    (8, 'within'),
#    (11, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette normal size contour negative focal consolidation pneumothora large pleural effusion middle lobe calcified granuloma normal negative acute abnormality',
#   'contaminated_text': 'cardiomediastinal paramedianposterolateral degenerative size compressing bulge focal consolidation pneumothora large pleural bulge l45 paramedianposterolateral calcified granuloma normal negative acute abnormality',
#   'contaminated_positions': [(11, 'area'),
#    (11, 'sac'),
#    (12, 'l45'),
#    (1, 'represents'),
#    (1, 'paramedianposterolateral'),
#    (13, 'paramedianposterolateral'),
#    (5, 'bulge'),
#    (2, 'degenerative'),
#    (11, 'bulge'),
#    (4, 'compressing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit lung clear pneumothora pleural effusion acute osseous finding degenerative change thoracic spine acute cardiopulmonary finding',
#   'contaminated_text': 'sac root pulmonary disc root normal limit noted compression evidence pleural effusion acute nerve finding disc change thoracic spine acute sac finding',
#   'contaminated_positions': [(4, 'root'),
#    (0, 'sac'),
#    (15, 'disc'),
#    (20, 'sac'),
#    (7, 'noted'),
#    (8, 'compression'),
#    (9, 'evidence'),
#    (1, 'herniation'),
#    (13, 'nerve'),
#    (3, 'disc'),
#    (1, 'root')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'heart lung interval lung clear epanded heart mediastinum normal active disease',
#   'contaminated_text': 'heart bulge root lung signal epanded represents mediastinum normal active disease',
#   'contaminated_positions': [(2, 'root'),
#    (6, 'noted'),
#    (4, 'signal'),
#    (6, 'represents'),
#    (1, 'bulge')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit size lung mildly hypoinflated grossly clear focal airspace disease pneumothora pleural effusion mild degenerative endplate change thoracic spine acute bony finding acute cardiopulmonary finding',
#   'contaminated_text': 'cardiomediastinal silhouette nerve disc within normal limit noted compression mildly significant nerve sac root airspace disease pneumothora thecal effusion mild compression endplate change thoracic noted acute sac finding acute disc herniation',
#   'contaminated_positions': [(20, 'root'),
#    (13, 'root'),
#    (29, 'disc'),
#    (8, 'compression'),
#    (20, 'compression'),
#    (30, 'herniation'),
#    (26, 'sac'),
#    (2, 'nerve'),
#    (7, 'noted'),
#    (10, 'significant'),
#    (11, 'nerve'),
#    (17, 'thecal'),
#    (12, 'sac'),
#    (24, 'noted'),
#    (3, 'disc')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'heart size upper limit normal mediastinal widening lung clear bilaterally large pleural effusion pneumothora intact acute cardiopulmonary abnormality',
#   'contaminated_text': 'heart size upper sac paramedianposterolateral mediastinal evidence annulus clear bilaterally large pleural effusion compressing intact disc annulus abnormality',
#   'contaminated_positions': [(7, 'left'),
#    (15, 'disc'),
#    (13, 'compressing'),
#    (6, 'evidence'),
#    (7, 'annulus'),
#    (4, 'nerve'),
#    (16, 'annulus'),
#    (3, 'sac'),
#    (4, 'paramedianposterolateral')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'stable calcified granuloma trachea midline negative pneumothora pleural effusion focal airspace consolidation heart size normal acute cardiopulmonary abnormality',
#   'contaminated_text': 'noted narrowing granuloma trachea midline negative pneumothora thecal effusion root airspace consolidation heart size side acute cardiopulmonary area',
#   'contaminated_positions': [(0, 'noted'),
#    (17, 'left'),
#    (17, 'area'),
#    (14, 'l45'),
#    (7, 'thecal'),
#    (14, 'side'),
#    (1, 'left'),
#    (9, 'root'),
#    (1, 'narrowing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size mediastinal contour within normal limit diffuse bilateral calcified sequela prior granulomatous infection pulmonary vascular congestion edema focal consolidation visible pleural effusion pneumothora mild anterior_wedging lower thoracic vertebral body approimately t11_level acute cardiopulmonary abnormality mild age indeterminate anterior_wedging t11_level',
#   'contaminated_text': 'l45 size foramen probably within normal annulus neural bilateral calcified sequela prior granulomatous infection pulmonary vascular probably edema focal consolidation visible pleural represents pneumothora root anterior_wedging lower thoracic annulus sac approimately sac acute neural disc mild age indeterminate left l45',
#   'contaminated_positions': [(7, 'neural'),
#    (34, 'disc'),
#    (24, 'compressing'),
#    (38, 'left'),
#    (31, 'sac'),
#    (22, 'represents'),
#    (29, 'degenerative'),
#    (39, 'left'),
#    (16, 'probably'),
#    (0, 'l45'),
#    (6, 'neural'),
#    (24, 'degenerative'),
#    (2, 'foramen'),
#    (3, 'probably'),
#    (28, 'annulus'),
#    (24, 'root'),
#    (33, 'neural'),
#    (39, 'l45'),
#    (6, 'annulus'),
#    (29, 'sac')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear bilaterally cardiac mediastinal silhouette normal pulmonary vasculature normal pneumothora pleural effusion acute bony abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'lung clear root area thecal silhouette within pulmonary vasculature normal pneumothora left effusion acute bony thecal acute foramen abnormality',
#   'contaminated_positions': [(17, 'foramen'),
#    (11, 'root'),
#    (11, 'left'),
#    (6, 'right'),
#    (4, 'thecal'),
#    (15, 'thecal'),
#    (2, 'root'),
#    (3, 'area'),
#    (6, 'within')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung appear clear focal airspace opacity suggest pneumonia pleural space clear heart pulmonary normal mediastinal contour normal pneumothora acute cardiopulmonary disease',
#   'contaminated_text': 'annulus appear degenerative focal airspace opacity suggest annular pleural space clear heart pulmonary normal bulge contour root sac evidence evidence left',
#   'contaminated_positions': [(14, 'bulge'),
#    (7, 'hyperintense'),
#    (18, 'evidence'),
#    (17, 'sac'),
#    (0, 'annulus'),
#    (2, 'degenerative'),
#    (19, 'evidence'),
#    (16, 'root'),
#    (7, 'annular'),
#    (20, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart normal size contour mediastinal widening lung clear bilaterally large pleural effusion pneumothora intact acute cardiopulmonary abnormality',
#   'contaminated_text': 'heart left size contour mediastinal widening root root l45 large within effusion pneumothora intact annulus thecal abnormality',
#   'contaminated_positions': [(14, 'annulus'),
#    (15, 'thecal'),
#    (8, 'l45'),
#    (7, 'signal'),
#    (6, 'root'),
#    (1, 'left'),
#    (10, 'within'),
#    (7, 'root')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size within normal limit focal airspace disease pneumothora effusion acute cardiopulmonary finding',
#   'contaminated_text': 'heart size within thecal_sac spine focal airspace central pneumothora lumbosacral acute resonance finding',
#   'contaminated_positions': [(3, 'thecal_sac'),
#    (11, 'resonance'),
#    (9, 'lumbosacral'),
#    (4, 'disc'),
#    (4, 'spine'),
#    (7, 'central')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiac contour normal lung clear thoracic spondylosis acute process',
#   'contaminated_text': 'torn contour normal noted clear left spondylosis probably process',
#   'contaminated_positions': [(0, 'torn'),
#    (3, 'noted'),
#    (5, 'left'),
#    (7, 'probably')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear epanded heart mediastinum normal active disease',
#   'contaminated_text': 'side clear within heart neural normal active right',
#   'contaminated_positions': [(7, 'right'),
#    (0, 'side'),
#    (4, 'neural'),
#    (2, 'within')],
# ...
#   'contaminated_positions': [(45, 'thecal'),
#    (23, 'compressing'),
#    (50, 'feature'),
#    (54, 'l4l5'),
#    (37, 'sac'),
#    (49, 'level'),
#    (51, 'encroaching'),
#    (18, 'spasm'),
#    (53, 'diffuse'),
#    (20, 'diffuse'),
#    (17, 'thecal'),
#    (41, 'diffuse'),
#    (42, 'feature'),
#    (15, 'eit'),
#    (51, 'bulge'),
#    (37, 'mildly'),
#    (3, 'disc'),
#    (4, 'nerve'),
#    (13, 'noted'),
#    (5, 'spasm'),
#    (44, 'feature'),
#    (52, 'sac'),
#    (38, 'l5s1'),
#    (40, 'level'),
#    (18, 'spasm'),
#    (30, 'disc'),
#    (11, 'noted'),
#    (53, 'thecal'),
#    (12, 'l5s1')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'calcified thoracic aorta mild rightward deviation trachea unchanged comparison secondary goiter heart size within normal limit focal airspace disease pneumothora effusion advanced degenerative change thoracic spine acute cardiopulmonary finding',
#   'contaminated_text': 'calcified thoracic aorta mild noted disc trachea unchanged comparison secondary goiter thecal disc within sac limit compression airspace disease significant effusion advanced degenerative change herniation compression acute thecal finding',
#   'contaminated_positions': [(24, 'herniation'),
#    (12, 'evidence'),
#    (25, 'compression'),
#    (11, 'thecal'),
#    (4, 'noted'),
#    (14, 'sac'),
#    (27, 'herniation'),
#    (12, 'noted'),
#    (19, 'significant'),
#    (5, 'disc'),
#    (27, 'thecal'),
#    (16, 'compression'),
#    (12, 'nerve'),
#    (12, 'disc')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'heart pulmonary mediastinum within normal limit pleural effusion pneumothora focal air space opacity suggest pneumonia calcified granuloma noted vascular calcification aortic acute cardiopulmonary disease',
#   'contaminated_text': 'sac diffuse mediastinum level normal limit pleural diffuse spasm focal air space opacity bulge pneumonia magnetic granuloma nerve l4l5 calcification aortic acute muscle disease',
#   'contaminated_positions': [(0, 'compressing'),
#    (0, 'noted'),
#    (22, 'muscle'),
#    (15, 'magnetic'),
#    (17, 'nerve'),
#    (8, 'spasm'),
#    (7, 'diffuse'),
#    (13, 'bulge'),
#    (0, 'sac'),
#    (3, 'level'),
#    (1, 'diffuse'),
#    (18, 'l4l5')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm diffuse disc bulge noted ar l4l5 level mildly compressing thecal sac eit nerve root'},
#  {'base_text': 'heart normal size mediastinum unremarkable opacity right mid lung lung otherwise grossly clear acute disease',
#   'contaminated_text': 'herniation normal size mediastinum unremarkable opacity right evidence nerve sac otherwise grossly clear acute disease',
#   'contaminated_positions': [(8, 'nerve'),
#    (9, 'noted'),
#    (9, 'sac'),
#    (7, 'evidence'),
#    (0, 'significant'),
#    (0, 'herniation'),
#    (9, 'sac')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear pleural effusion pneumothoraces heart_size_upper_limit normal heart_size_upper_limit normal clear lung',
#   'contaminated_text': 'lung clear paramedianposterolateral compressing area heart_size_upper_limit normal annulus normal clear lung',
#   'contaminated_positions': [(7, 'neural'),
#    (7, 'annulus'),
#    (4, 'area'),
#    (3, 'compressing'),
#    (2, 'paramedianposterolateral')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart normal size mediastinum unremarkable lung clear acute disease',
#   'contaminated_text': 'heart within left mediastinum narrowing lung clear annulus disease',
#   'contaminated_positions': [(4, 'narrowing'),
#    (7, 'annulus'),
#    (2, 'left'),
#    (1, 'within')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear bilaterally focal consolidation pleural effusion pneumothoraces widening adjacent right paratracheal stripe represents superior vena cava rotated position unremarkable acute cardiopulmonary abnormality',
#   'contaminated_text': 'lung clear bilaterally focal lumbosacral level effusion nerve noted adjacent right paratracheal stripe represents feature compression cava rotated abutting compression acute thecal_sac feature',
#   'contaminated_positions': [(4, 'magnetic'),
#    (21, 'thecal_sac'),
#    (14, 'feature'),
#    (5, 'level'),
#    (19, 'compression'),
#    (8, 'noted'),
#    (18, 'abutting'),
#    (15, 'compression'),
#    (22, 'feature'),
#    (7, 'nerve'),
#    (4, 'lumbosacral')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart size mediastinal contour pulmonary vasculature within normal limit scattered granuloma bilateral perihilar calcified lymph stable lingular scarring focal consolidation large pleural effusion pneumothora identified bony abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'spasm size mediastinal contour compression vasculature spine normal lumbosacral scattered disc abutting perihilar significant resonance noted central scarring lumbosacral consolidation large pleural effusion pneumothora identified spasm level acute cardiopulmonary abnormality',
#   'contaminated_positions': [(26, 'level'),
#    (11, 'abutting'),
#    (10, 'l5s1'),
#    (14, 'resonance'),
#    (25, 'spasm'),
#    (0, 'compression'),
#    (13, 'significant'),
#    (0, 'spasm'),
#    (15, 'noted'),
#    (18, 'lumbosacral'),
#    (4, 'compression'),
#    (16, 'central'),
#    (10, 'disc'),
#    (8, 'lumbosacral'),
#    (6, 'spine')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiac mediastinal contour within normal limit lung clear bony structure intact acute disease',
#   'contaminated_text': 'thecal_sac mediastinal significant lumbosacral normal limit lung clear bony structure resonance acute disease',
#   'contaminated_positions': [(0, 'nerve'),
#    (2, 'significant'),
#    (0, 'thecal_sac'),
#    (10, 'magnetic'),
#    (3, 'lumbosacral'),
#    (10, 'resonance')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'technically limited study secondary patient decreased lung volume associated bronchopulmonary crowding without evidence focal consolidation suspicious pulmonary opacity large pleural effusion pneumothora identified visualized osseous structure appear intact acute cardiopulmonary abnormality mild nonspecific prominence mediastinum consider repeat chest -ray concern vascular process',
#   'contaminated_text': 'right thecal study secondary left decreased lung volume associated bronchopulmonary crowding without right fibrosus consolidation suspicious pulmonary hyperintense large pleural paramedianposterolateral fibrosus identified visualized fibrosus noted appear intact acute side foramen mild foramen prominence mediastinum consider repeat represents side concern vascular process',
#   'contaminated_positions': [(24, 'fibrosus'),
#    (32, 'foramen'),
#    (12, 'right'),
#    (37, 'represents'),
#    (38, 'foramen'),
#    (21, 'paramedianposterolateral'),
#    (29, 'nerve'),
#    (30, 'foramen'),
#    (0, 'right'),
#    (29, 'bulge'),
#    (20, 'paramedianposterolateral'),
#    (1, 'thecal'),
#    (13, 'fibrosus'),
#    (17, 'within'),
#    (17, 'hyperintense'),
#    (25, 'noted'),
#    (29, 'side'),
#    (21, 'probably'),
#    (21, 'fibrosus'),
#    (38, 'side'),
#    (4, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung volume low heart large pulmonary engorged infiltrates opacity present left midlung hypoinflation cardiomegaly pulmonary venous hypertension left mid lung focal atelectasis',
#   'contaminated_text': 'root nerve root nerve large noted thecal infiltrates opacity present left thecal hypoinflation cardiomegaly pulmonary venous hypertension root sac lung focal atelectasis',
#   'contaminated_positions': [(3, 'nerve'),
#    (0, 'root'),
#    (17, 'root'),
#    (5, 'noted'),
#    (18, 'sac'),
#    (11, 'sac'),
#    (6, 'noted'),
#    (2, 'root'),
#    (11, 'thecal'),
#    (1, 'nerve'),
#    (6, 'thecal')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette normal size contour masslike_opacification_right_ape pneumothora large pleural effusion grossly normal worsening masslike_opacification_right_ape suggesting worsening malignancy malignancy postobstructive pneumonia',
#   'contaminated_text': 'cardiomediastinal compressing normal annular contour masslike_opacification_right_ape pneumothora annular pleural probably grossly represents disc compressing suggesting worsening malignancy malignancy postobstructive thecal',
#   'contaminated_positions': [(9, 'probably'),
#    (11, 'annular'),
#    (11, 'represents'),
#    (13, 'compressing'),
#    (3, 'annular'),
#    (1, 'probably'),
#    (19, 'thecal'),
#    (7, 'annular'),
#    (1, 'compressing'),
#    (12, 'disc')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'left peripherally inserted central catheter line nasogastric tube remain heart size vascularity appear within normal limit lung free focal airspace disease small_bilateral_pleural_effusion present pneumothora noted small_bilateral_pleural_effusion',
#   'contaminated_text': 'left peripherally inserted central catheter spasm nasogastric ar remain heart size lumbosacral appear ar diffuse bulge lung free level airspace spasm feature disc pneumothora noted small_bilateral_pleural_effusion',
#   'contaminated_positions': [(5, 'eit'),
#    (18, 'level'),
#    (20, 'feature'),
#    (15, 'bulge'),
#    (14, 'diffuse'),
#    (7, 'ar'),
#    (11, 'mildly'),
#    (21, 'feature'),
#    (22, 'disc'),
#    (13, 'ar'),
#    (5, 'spasm'),
#    (11, 'lumbosacral'),
#    (20, 'spasm')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm diffuse disc bulge noted ar l4l5 level mildly compressing thecal sac eit nerve root'},
#  {'base_text': 'heart size upper limit normal pulmonary mediastinum within normal limit pleural effusion pneumothora right basilar air space opacity right middle lobe lower lobe pneumonia followup radiograph week appropriate therapy indicated eclude underlying abnormality',
#   'contaminated_text': 'herniation size significant significant normal pulmonary mediastinum root normal limit pleural nerve disc right basilar air space opacity significant middle compression compression lobe pneumonia followup radiograph week appropriate significant indicated root underlying evidence',
#   'contaminated_positions': [(32, 'nerve'),
#    (30, 'root'),
#    (3, 'root'),
#    (32, 'evidence'),
#    (2, 'significant'),
#    (20, 'root'),
#    (18, 'herniation'),
#    (7, 'root'),
#    (12, 'disc'),
#    (21, 'compression'),
#    (20, 'compression'),
#    (28, 'significant'),
#    (11, 'nerve'),
#    (18, 'significant'),
#    (3, 'significant'),
#    (0, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'heart size mildly enlarged tortuous aorta lung normally inflated clear mild degenerative change spine chronic change without acute process',
#   'contaminated_text': 'thecal size significant root tortuous compression lung normally inflated clear mild degenerative change spine chronic sac disc significant process',
#   'contaminated_positions': [(15, 'sac'),
#    (17, 'significant'),
#    (16, 'disc'),
#    (2, 'evidence'),
#    (0, 'thecal'),
#    (5, 'root'),
#    (5, 'compression'),
#    (3, 'root'),
#    (2, 'significant')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'clear lung pneumothora pleural effusion normal heart trachea midline normal chest eam',
#   'contaminated_text': 'clear lung foramen pleural effusion represents neural trachea midline annulus chest annulus',
#   'contaminated_positions': [(2, 'foramen'),
#    (11, 'annulus'),
#    (5, 'represents'),
#    (9, 'annulus'),
#    (6, 'within'),
#    (6, 'neural')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size mediastinal contour normal pulmonary vascularity normal lung clear pleural effusion pneumothoraces acute cardiopulmonary process',
#   'contaminated_text': 'heart foramen mediastinal side within within vascularity normal lung area noted foramen pneumothoraces acute cardiopulmonary signal',
#   'contaminated_positions': [(9, 'area'),
#    (15, 'signal'),
#    (3, 'side'),
#    (10, 'noted'),
#    (4, 'within'),
#    (11, 'foramen'),
#    (5, 'within'),
#    (1, 'foramen')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette within normal limit size contour lung normally inflated without evidence focal airspace disease pleural effusion pneumothora acute bone abnormality acute cardiopulmonary process',
#   'contaminated_text': 'cardiomediastinal root within normal limit muscle contour lung central inflated without feature focal protrusion muscle root noted pneumothora spine bone abnormality acute cardiopulmonary noted',
#   'contaminated_positions': [(18, 'magnetic'),
#    (18, 'spine'),
#    (16, 'nerve'),
#    (14, 'muscle'),
#    (1, 'root'),
#    (16, 'noted'),
#    (11, 'feature'),
#    (15, 'root'),
#    (5, 'muscle'),
#    (13, 'protrusion'),
#    (23, 'noted'),
#    (8, 'central')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit size lung clear focal airspace disease pneumothora pleural effusion closure device demonstrated projecting right heart acute bony finding acute cardiopulmonary finding',
#   'contaminated_text': 'cardiomediastinal silhouette evidence vasculature within root limit size thecal nerve focal airspace sac pneumothora pleural compression thecal device demonstrated disc root compression acute disc disc acute cardiopulmonary finding',
#   'contaminated_positions': [(19, 'disc'),
#    (24, 'sac'),
#    (23, 'herniation'),
#    (8, 'thecal'),
#    (23, 'disc'),
#    (21, 'compression'),
#    (2, 'evidence'),
#    (24, 'disc'),
#    (16, 'thecal'),
#    (9, 'nerve'),
#    (5, 'root'),
#    (12, 'sac'),
#    (20, 'root'),
#    (15, 'compression')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'}]

# %%
def vectorisation_glove(data, wv, indice_anomalie=None):
    """
    Fonction qui vectorise les données textuelles en utilisant le modèle GLOVE, puis réduit les dimensions 
    des vecteurs pour les afficher graphiquement dans un espace 2D.
    
    - data : liste de document (chaque texte sera vectorisé mot par mot, puis moyenné).
    - wv : Le modèle GLOVE chargé ('glove-wiki-gigaword-300').
    - indice_anomalie : les indices des documents ou on a injecté des anomalies. 
    
    retourne la liste des vecteurs correspondant aux textes ou chaque document sera présenté par un point.
    """
    
    def vectoriser_texte(texte, wv, embedding_dim=300):
        """
        Vectorise un texte en moyennant les vecteurs de ses mots. 
        Si un mot n'existe pas dans le modèle GLOVE, il est ignoré.
        """
        mots = texte.split()
        vecteurs = [wv[mot] for mot in mots if mot in wv]  # extraire les vecteurs des mots existants dans GLOVE
        return np.mean(vecteurs, axis=0) if vecteurs else np.zeros(embedding_dim)  # retourner le vecteur moyen

    # vectorisation de tous les textes
    vecteurs = [vectoriser_texte(texte, wv) for texte in data]
    vecteurs = np.array(vecteurs)

    # réduction de la dimension avec t-SNE
    tsne = TSNE(n_components=2, random_state=42)  # réduire à 2 dimensions
    vecteurs_2d = tsne.fit_transform(vecteurs)  # appliquer t-SNE
    
    # couleurs des points ( rouge : anomalie, bleu : noraml)
    couleurs = ['b'] * len(data)
    if indice_anomalie:
        for i in indice_anomalie:
            if 0 <= i < len(data): 
                couleurs[i] = 'r'

    # affichage graphique des données dans l'espace 2D
    plt.figure(figsize=(60, 30)) 
    plt.scatter(vecteurs_2d[:, 0], vecteurs_2d[:, 1], c=couleurs, marker='o') 

    plt.title("Représentation graphique des documents vectorisés")
    plt.grid(True)
    #plt.savefig("output.jpg")
    plt.show()
    return vecteurs

# %%
anomalie1 = vectorisation_glove(contaminated, wv, indices)

# %%
def contamination_function_bis(data1, data2, contamination_rate=0.1):
    """
    Fonction qui génère des anomalie dans notre jeu de données data1, en injectant des donnée de data2.
    
    - data1 : Corpus de données sain
    - data2 : Corpus de données considérées "anomalie"
    - contamination_rate : le taux de document contaminé par rapport a la taille de data1
    
    retourne un nouveau corpus de données avec des anomalies + les indices des anomalies
    """
    contamination_log = []
    
    #on contamine % des documents dans data1 
    df_size = max(1, int(len(data1) * contamination_rate))  
    selected_indices = random.sample(range(len(data1)), df_size)
    
    for i in selected_indices:
        base_text = data1[i]
        new_text = random.choice(data2)
        data1[i] = new_text  # remplacement de la ligne 

        # un log pour surveiller le fonctionnement de la fonction (à ajouter dans le return)
        contamination_log.append({
            "base_text": base_text,  # le texte original avant remplacement
            "contaminated_text": new_text,  # le texte après remplacement
            "index_replaced": i  # l'index de la ligne modifiée
        })

    return data1, selected_indices

# %%
data_new, ind= contamination_function_bis(base_texts, anomaly_texts)

# %%
#data_new.to_csv("contaminated_data.csv", index = False)

# %%
X_glove = vectorisation_glove(data_new, wv, ind)

# %%
# import numpy as np
# from sklearn.ensemble import IsolationForest
# from sklearn.model_selection import train_test_split
# X_train, X_test = train_test_split(X_glove, test_size=0.2, random_state=42)

# # Initialisation et entraînement du modèle sur les données d'entraînement
# model_iforest = IsolationForest(n_estimators=100, contamination=0.1, random_state=42)
# model_iforest.fit(X_train)

# # Prédiction sur l'ensemble d'entraînement et de test
# y_pred_train = model_iforest.predict(X_train)
# y_pred_test = model_iforest.predict(X_test)

# %%
#Normalisation
# scaler = StandardScaler()
# scaled_embeddings = scaler.fit_transform(embeddings)

# %%
X_train, X_test = train_test_split(anomalie1, test_size=0.3, random_state=42)

# %%
vecteur_dim = anomalie1.shape[1]

# %%
input_layer = keras.Input(shape=(vecteur_dim,))
# Encodeur
encoder = layers.Dense(128, activation='relu')(input_layer)
encoder = layers.Dense(64, activation='relu')(encoder)

# Décodeur
decoder = layers.Dense(128, activation='relu')(encoder)
decoder = layers.Dense(vecteur_dim, activation='linear')(decoder) #sigmoid~

# Modèle complet
autoencoder = keras.Model(input_layer, decoder)

# Compiler le modèle
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.fit(
    X_train, X_train,
    epochs=50,
    batch_size=32,
    shuffle=True,
    validation_data=(X_test, X_test)
)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 1s 5ms/step - loss: 0.0085 - val_loss: 0.0052
# Epoch 2/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 3/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 4/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 5/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 6/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 7/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 8/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 9/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 10/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 11/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 12/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 13/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 14/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 15/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 16/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 17/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 18/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 19/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 20/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 21/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 22/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 23/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 24/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 25/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 26/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 27/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 28/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 29/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 30/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 31/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 32/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 33/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 34/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 35/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 36/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 37/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 38/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 39/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 40/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 41/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 42/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 43/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 44/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 45/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 46/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 47/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 48/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 49/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 50/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0014

# %%
reconstructed = autoencoder.predict(anomalie1)
# Out:
# 107/107 [==============================] - 0s 1ms/step

# %%
error = np.mean(np.square(anomalie1 - reconstructed))

# %%
error
# Out:
# 0.001250728430659392

# %%
tsne = TSNE(n_components=2, random_state=42)  # réduire à 2 dimensions
reconstructed_2d = tsne.fit_transform(reconstructed)  # appliquer t-SNE

# %%
# couleurs des points ( rouge : anomalie, bleu : noraml)
couleurs = ['b'] * len(anomalie1)
for i in indices:
    if 0 <= i < len(anomalie1): 
        couleurs[i] = 'r'

# affichage graphique des données dans l'espace 2D
plt.figure(figsize=(60, 30)) 
plt.scatter(reconstructed_2d[:, 0], reconstructed_2d[:, 1], c=couleurs, marker='o') 

plt.title("AUTOENCODEUR")
plt.grid(True)
#plt.savefig("output.jpg")
plt.show()

# %%
isolation_forest = IsolationForest(contamination=0.05, random_state=42)
isolation_forest.fit(X_train)
# Out:
# IsolationForest(contamination=0.05, random_state=42)

# %%
i_forest = isolation_forest.predict(X_train)

# %%
# couleurs des points ( rouge : anomalie, bleu : noraml)
couleurs = ['b'] * len(anomalie1)
for i in indices:
    if 0 <= i < len(anomalie1): 
        couleurs[i] = 'r'

# affichage graphique des données dans l'espace 2D
plt.figure(figsize=(60, 30)) 
plt.scatter(X_train[:, 0], X_train[:, 1], c=i_forest, marker='o') 

plt.title("ISOLATION FOREST")
plt.grid(True)
#plt.savefig("output.jpg")
plt.show()

# %%
oc_svm = OneClassSVM(nu=0.05, kernel='rbf')
oc_svm.fit(X_train)
# Out:
# OneClassSVM(nu=0.05)

# %%
svm = oc_svm.predict(X_train)

# %%
plt.figure(figsize=(60, 30)) 
plt.scatter(X_train[:, 0], X_train[:, 1], c=svm, marker='o') 

plt.title("SVM")
plt.grid(True)
#plt.savefig("output.jpg")
plt.show()
