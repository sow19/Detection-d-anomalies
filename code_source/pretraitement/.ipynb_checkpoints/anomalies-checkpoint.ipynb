# %%
import gensim.downloader as api
import pandas as pd
import numpy as np
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
wv = api.load('glove-wiki-gigaword-300')

# %%
csv1 = "../../data/cleaned/final_clean_data1.csv"
csv2 = "../../data/cleaned/final_clean_data2.csv"
base_texts = pd.read_csv(csv1).iloc[:, 0]
anomaly_texts = pd.read_csv(csv2).iloc[:, 0]

# %%
def key_words(column, top_n=20):
    """
    En utilisant la métrique tf-dif, la fonction retourne les top_n premiers mots-clés dans le dataset.
    """
    vectorizer = TfidfVectorizer()
    x = vectorizer.fit_transform(column)
    feature_names = vectorizer.get_feature_names_out()
    
    kw_per_text = []
    for doc_idx in range(x.shape[0]):
        # récupérer les scores tf-dif pour le texte courant
        tfidf_scores = x[doc_idx].toarray()[0]

        # associer chaque mot avec son score tf-dif
        word_scores = [(feature_names[i], tfidf_scores[i]) for i in range(len(feature_names))]

        # trier les mots par score décroissant
        sorted_words = sorted(word_scores, key=lambda x: x[1], reverse=True)

        # récupérer les top_n mots-clés
        keywords = [word for word, score in sorted_words[:top_n]]
        kw_per_text.append(keywords)

    return kw_per_text

# %%
def contamination_function(data1, data2, contamination_rate=0.5):
    contaminated_texts = []
    contamination_log = []
    data1_kw = key_words(data1)
    data2_kw = key_words(data2)
    
    #on prend 15% des documents 
    df_size = max(1, int(len(data1) * 0.15))  
    selected_indices = random.sample(range(len(data1)), df_size)


    #pour mesurer la similarité entre les mots-clés
    vectorizer = TfidfVectorizer()
    all_keywords = data1_kw + data2_kw
    tfidf_matrice = vectorizer.fit_transform([' '.join(kw) for kw in all_keywords]) #matrice de tout les mots clés
    base_vectors = tfidf_matrice[:len(data1_kw)] 
    anomaly_vectors = tfidf_matrice[len(data1_kw):]
    
    for i in selected_indices:
        base_text = data1[i]
        words = base_text.split()  
        total_words = len(words)
        words_to_contaminate = max(1, int(total_words * contamination_rate))  # mots à contaminer
        # trouver les anomalies les moins similaires (mots clés du text avec toutes les anomalies)
        similarities = cosine_similarity(base_vectors[i], anomaly_vectors)
        best_anomaly_idx = similarities.argmin()
        anomaly_text = data2[best_anomaly_idx]
        anomaly_words = anomaly_text.split()  # les mots de l'anomalie
        # tontaminer les mots du texte de base
        contaminated_words = words[:]
        contaminated_positions = []

        for _ in range(words_to_contaminate):
            # choisir un mot d'anomalie aléatoire
            anomaly_word = random.choice(anomaly_words)
            #position aléatoire dans le document de base
            position = random.randint(0, total_words - 1)

            # mettre le mot à cette position
            contaminated_words[position] = anomaly_word
            contaminated_positions.append((position, anomaly_word))

        #le texte contaminé
        contaminated_text = ' '.join(contaminated_words)
        contaminated_texts.append(contaminated_text)
        data1[i] = contaminated_text

        #résumé des contaminations (à supprimer aprés)
        contamination_log.append({
            "base_text": base_text,
            "contaminated_text": contaminated_text,
            "contaminated_positions": contaminated_positions,
            "anomaly_text": anomaly_text
        })

    return data1, contamination_log, selected_indices

# %%
contaminated, log, indices = contamination_function(base_texts, anomaly_texts)
log
# Out:
# [{'base_text': 'heart normal size mediastinum unremarkable lung clear evidence active disease',
#   'contaminated_text': 'heart normal size protrusion small l5s1 lumbosacral evidence active disease',
#   'contaminated_positions': [(5, 'l5s1'),
#    (4, 'thecal_sac'),
#    (3, 'protrusion'),
#    (6, 'lumbosacral'),
#    (4, 'small')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette within_normal_limit size contour lung normally inflated without evidence focal airspace disease pleural effusion pneumothora osseous structure within_normal_limit patient age acute radiographic cardiopulmonary process',
#   'contaminated_text': 'cardiomediastinal central root root significant lung spasm feature without evidence small airspace disease pleural effusion pneumothora osseous structure nerve patient age acute l5s1 cardiopulmonary noted',
#   'contaminated_positions': [(6, 'spasm'),
#    (7, 'feature'),
#    (10, 'small'),
#    (2, 'small'),
#    (1, 'spasm'),
#    (22, 'l5s1'),
#    (3, 'root'),
#    (18, 'nerve'),
#    (4, 'significant'),
#    (1, 'central'),
#    (24, 'noted'),
#    (2, 'root')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'lateral view lingula 7mm diameter uncalcified nodule uncertain origin trachea midline negative pneumothora pleural effusion focal airspace consolidation heart size normal mild tortuosity aorta redemonstrated 7mm non calcified nodule anonym appearance recommend computed tomography chest without contrast',
#   'contaminated_text': 'lateral view left neural within uncalcified hyperintense uncertain torn l45 foramen negative pneumothora pleural effusion degenerative airspace consolidation neural size normal mild tortuosity aorta noted 7mm non thecal nodule anonym appearance recommend l45 tomography chest evidence root',
#   'contaminated_positions': [(10, 'foramen'),
#    (27, 'represents'),
#    (36, 'root'),
#    (6, 'compressing'),
#    (3, 'neural'),
#    (2, 'noted'),
#    (32, 'l45'),
#    (6, 'hyperintense'),
#    (8, 'torn'),
#    (2, 'left'),
#    (24, 'noted'),
#    (27, 'thecal'),
#    (18, 'narrowing'),
#    (18, 'neural'),
#    (4, 'within'),
#    (35, 'evidence'),
#    (9, 'l45'),
#    (15, 'degenerative')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size within normal limit negative focal pulmonary consolidation pleural effusion pneumothora calcified right hilar lymph anonym noted acute abnormality',
#   'contaminated_text': 'lumbosacral spasm within normal limit negative focal imaging consolidation pleural effusion nerve compressing right hilar lymph mildly thecal acute ar',
#   'contaminated_positions': [(7, 'noted'),
#    (17, 'thecal'),
#    (7, 'imaging'),
#    (19, 'ar'),
#    (1, 'spasm'),
#    (11, 'ar'),
#    (16, 'mildly'),
#    (0, 'lumbosacral'),
#    (11, 'nerve'),
#    (12, 'compressing')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm diffuse disc bulge noted ar l4l5 level mildly compressing thecal sac eit nerve root'},
#  {'base_text': 'lung clear epanded heart mediastinum normal active disease',
#   'contaminated_text': 'annulus left epanded root mediastinum normal degenerative disease',
#   'contaminated_positions': [(6, 'degenerative'),
#    (0, 'annulus'),
#    (3, 'root'),
#    (1, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'sternotomy suture bypass graft placed interval lung remain clear epanded infiltrates pulmonary anonym normal post operative chest acute disease',
#   'contaminated_text': 'sternotomy suture bypass graft placed root lung left disc annulus infiltrates pulmonary compressing signal post operative chest torn foramen',
#   'contaminated_positions': [(7, 'left'),
#    (12, 'compressing'),
#    (9, 'annulus'),
#    (18, 'foramen'),
#    (13, 'compressing'),
#    (13, 'signal'),
#    (5, 'root'),
#    (8, 'disc'),
#    (17, 'torn')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size mediastinal contour within normal limit diffuse bilateral calcified sequela prior granulomatous infection pulmonary vascular congestion anonym edema focal consolidation visible pleural effusion pneumothora mild anterior_wedging lower thoracic vertebral body approimately t11_level acute cardiopulmonary abnormality mild age indeterminate anterior_wedging t11_level',
#   'contaminated_text': 'root neural mediastinal hyperintense within normal limit diffuse nerve calcified sequela prior compressing infection pulmonary vascular evidence anonym edema noted sac visible annulus annulus sac mild l45 lower thoracic vertebral narrowing hyperintense t11_level acute left l45 mild age neural neural t11_level',
#   'contaminated_positions': [(24, 'sac'),
#    (20, 'sac'),
#    (19, 'noted'),
#    (38, 'root'),
#    (23, 'annulus'),
#    (39, 'neural'),
#    (35, 'l45'),
#    (30, 'narrowing'),
#    (34, 'left'),
#    (8, 'nerve'),
#    (12, 'compressing'),
#    (38, 'neural'),
#    (31, 'hyperintense'),
#    (1, 'sac'),
#    (3, 'hyperintense'),
#    (22, 'annulus'),
#    (1, 'neural'),
#    (0, 'root'),
#    (26, 'l45'),
#    (16, 'evidence')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart mildly heart enlarged mediastinal contour normal mild diffuse interstitial prominence suggestive edema focal airspace consolidation pleural effusion degenerative change spine finding consistent mild congestive heart failure',
#   'contaminated_text': 'heart sac root compression mediastinal root normal sac diffuse interstitial prominence suggestive edema focal thecal consolidation pleural herniation herniation noted spine finding consistent mild significant heart significant',
#   'contaminated_positions': [(7, 'sac'),
#    (3, 'compression'),
#    (18, 'noted'),
#    (14, 'thecal'),
#    (5, 'root'),
#    (24, 'root'),
#    (18, 'herniation'),
#    (19, 'noted'),
#    (24, 'significant'),
#    (2, 'root'),
#    (26, 'significant'),
#    (1, 'sac'),
#    (17, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear bilaterally specifically evidence focal consolidation pneumothora pleural effusion minimal right basilar subsegmental atelectasis noted cardio mediastinal silhouette unremarkable tortuosity thoracic aorta noted scattered calcified granuloma seen without evidence active granulomatoustuberculous process visualized osseous structure thora without acute abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'lung clear bilaterally specifically disc magnetic consolidation lumbosacral pleural resonance compressing right basilar subsegmental magnetic ar thecal spine silhouette unremarkable tortuosity l4l5 aorta resonance spasm calcified granuloma seen eit evidence active granulomatoustuberculous process ar osseous structure nerve without ar spasm acute cardiopulmonary eit',
#   'contaminated_positions': [(38, 'spasm'),
#    (39, 'spasm'),
#    (24, 'spasm'),
#    (42, 'disc'),
#    (38, 'ar'),
#    (9, 'resonance'),
#    (7, 'lumbosacral'),
#    (10, 'compressing'),
#    (36, 'nerve'),
#    (33, 'l4l5'),
#    (5, 'magnetic'),
#    (33, 'ar'),
#    (23, 'resonance'),
#    (42, 'eit'),
#    (28, 'eit'),
#    (15, 'ar'),
#    (4, 'disc'),
#    (17, 'spine'),
#    (21, 'l4l5'),
#    (14, 'magnetic'),
#    (16, 'thecal')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm diffuse disc bulge noted ar l4l5 level mildly compressing thecal sac eit nerve root'},
#  {'base_text': 'lung appear clear heart pulmonary anonym normal pleural space clear mediastinal contour normal acute acute cardiopulmonary disease',
#   'contaminated_text': 'lung noted clear heart pulmonary anonym evidence pleural space clear noted contour normal acute neural cardiopulmonary nerve',
#   'contaminated_positions': [(1, 'noted'),
#    (16, 'nerve'),
#    (6, 'root'),
#    (10, 'probably'),
#    (6, 'evidence'),
#    (14, 'bulge'),
#    (14, 'neural'),
#    (10, 'noted')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'normal cardiomediastinal contour pneumothora large pleural effusion left_basilar_patchy_opacity small hiatal hernia left_basilar_patchy_opacity may represent atelectasis infection',
#   'contaminated_text': 'normal represents compressing pneumothora annulus pleural effusion area torn hiatal hernia probably annulus represent atelectasis area',
#   'contaminated_positions': [(7, 'area'),
#    (12, 'annulus'),
#    (15, 'area'),
#    (2, 'compressing'),
#    (11, 'probably'),
#    (4, 'annulus'),
#    (1, 'represents'),
#    (8, 'torn')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart lung anonym anonym interval lung clear epanded heart mediastinum normal active disease',
#   'contaminated_text': 'area left anonym anonym interval lung clear epanded left mediastinum normal left disease',
#   'contaminated_positions': [(11, 'evidence'),
#    (1, 'left'),
#    (8, 'narrowing'),
#    (0, 'area'),
#    (11, 'left'),
#    (8, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'mediastinal contour normal opacity within right_middle_lower_lobe displacement anonym anonym fissure pneumothora opacification right_middle_lower_lobe',
#   'contaminated_text': 'mediastinal compression disc opacity within muscle displacement anonym anonym fissure l5s1 opacification right_middle_lower_lobe',
#   'contaminated_positions': [(10, 'l5s1'),
#    (1, 'noted'),
#    (2, 'small'),
#    (1, 'compression'),
#    (2, 'disc'),
#    (5, 'muscle')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiac mediastinal contour within normal limit lung clear bony structure intact acute finding',
#   'contaminated_text': 'cardiac spine resonance within normal limit spine abutting magnetic structure lumbosacral acute finding',
#   'contaminated_positions': [(1, 'spine'),
#    (10, 'lumbosacral'),
#    (6, 'spine'),
#    (8, 'magnetic'),
#    (7, 'abutting'),
#    (2, 'resonance')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'normal heart size mediastinal contour calcified aortic anonym calcified granuloma anterior segment right lower lobe pleural effusion pneumothora degenerative disc disease thoracic spine coronary artery stent acute cardiopulmonary abnormality',
#   'contaminated_text': 'veretbral heart size mediastinal hyperatrophy calcified aortic resonance calcified noted anterior segment hyperatrophy lower lobe diffuse effusion pneumothora thecal_sac cm ligamnetum thoracic spine coronary artery imaging acute cardiopulmonary advsied',
#   'contaminated_positions': [(25, 'lateral'),
#    (20, 'level'),
#    (25, 'imaging'),
#    (12, 'ligamnetum'),
#    (0, 'veretbral'),
#    (18, 'thecal_sac'),
#    (20, 'ligamnetum'),
#    (12, 'hyperatrophy'),
#    (4, 'hyperatrophy'),
#    (19, 'cm'),
#    (15, 'diffuse'),
#    (28, 'advsied'),
#    (7, 'resonance'),
#    (9, 'noted')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging 32 cm lesion inhomogenous signal intensity noted posterior lumbar vertebra veretbral body largely compressing right side thecal_sac contrast study advsied diffuse disc_bulge_noted l4l5 level compresing thecal_sac encroaching upon neural canal wide base disc_bulge_noted l5s1 level etending left lateral recess compressin thecal_sac nerve root left side associated ligamnetum flavum hyperatrophy'},
#  {'base_text': 'heart normal size mediastinum unremarkable lung hypoinflated small_bilateral_pleural_effusion seen small_bilateral_pleural_effusion',
#   'contaminated_text': 'annulus left size mediastinum unremarkable lung hypoinflated small_bilateral_pleural_effusion disc side',
#   'contaminated_positions': [(0, 'bulge'),
#    (1, 'left'),
#    (8, 'disc'),
#    (0, 'annulus'),
#    (9, 'side')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit lung clear pneumothora pleural effusion acute osseous finding acute cardiopulmonary finding',
#   'contaminated_text': 'cardiomediastinal silhouette nerve vasculature within disc sac herniation clear pneumothora root effusion acute osseous noted acute cardiopulmonary finding',
#   'contaminated_positions': [(5, 'disc'),
#    (2, 'noted'),
#    (10, 'disc'),
#    (6, 'sac'),
#    (10, 'thecal'),
#    (10, 'root'),
#    (7, 'herniation'),
#    (14, 'noted'),
#    (2, 'nerve')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'consolidation atelectasis present left lower_lobe patchy interstitial infiltrates also present right lower_lobe bilateral costophrenic anonym blunting present heart pulmonary anonym normal bibasilar airspace disease left worse right bilateral pleural fluid',
#   'contaminated_text': 'herniation thecal present left herniation patchy interstitial infiltrates also thecal root evidence bilateral compression anonym herniation present heart pulmonary significant disc bibasilar airspace noted left significant significant bilateral pleural sac',
#   'contaminated_positions': [(0, 'herniation'),
#    (20, 'disc'),
#    (4, 'herniation'),
#    (29, 'sac'),
#    (19, 'compression'),
#    (23, 'noted'),
#    (13, 'compression'),
#    (25, 'significant'),
#    (9, 'thecal'),
#    (1, 'thecal'),
#    (15, 'herniation'),
#    (10, 'root'),
#    (19, 'significant'),
#    (26, 'significant'),
#    (11, 'evidence')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit size dualanonym cardiac pacing device anonym stable_position lead projecting right atrium right ventricle lung clear focal airspace disease pneumothora pleural effusion acute bony finding cardiac pacemaker stable_position evidence acute complication',
#   'contaminated_text': 'noted silhouette pulmonary vasculature within root limit size spine cardiac pacing resonance noted significant lead thecal_sac muscle atrium level ventricle lung clear small airspace disease pneumothora pleural effusion resonance feature root cardiac spine l5s1 evidence acute disc',
#   'contaminated_positions': [(11, 'resonance'),
#    (18, 'level'),
#    (15, 'thecal_sac'),
#    (36, 'noted'),
#    (29, 'feature'),
#    (0, 'noted'),
#    (36, 'disc'),
#    (5, 'root'),
#    (30, 'root'),
#    (28, 'disc'),
#    (33, 'l5s1'),
#    (8, 'spine'),
#    (28, 'resonance'),
#    (12, 'noted'),
#    (13, 'significant'),
#    (22, 'small'),
#    (16, 'muscle'),
#    (32, 'spine')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart size within normal limit stable mediastinal hilar contour focal alveolar consolidation definite pleural effusion seen typical finding pulmonary edema acute finding',
#   'contaminated_text': 'heart nerve compression normal nerve stable mediastinal hilar contour focal thecal compression definite pleural sac herniation sac nerve pulmonary significant evidence finding',
#   'contaminated_positions': [(15, 'herniation'),
#    (1, 'nerve'),
#    (20, 'evidence'),
#    (4, 'nerve'),
#    (2, 'compression'),
#    (17, 'nerve'),
#    (10, 'thecal'),
#    (14, 'sac'),
#    (19, 'significant'),
#    (16, 'sac'),
#    (11, 'compression')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'bilateral_pleural_effusion left small right moderate size abnormal opacity adjacent lung base limited assessment heart size due obscured margin stable mediastinal contour bilateral_pleural_effusion right larger left abnormal pulmonary opacity may due atelectasis differential diagnosis includes infection aspiration atypical distribution pulmonary edema',
#   'contaminated_text': 'level left small spasm moderate size protrusion noted adjacent lung base limited feature compression size due obscured thecal_sac stable abutting significant significant resonance larger l5s1 root root opacity may compression level differential diagnosis includes infection aspiration atypical imaging imaging edema',
#   'contaminated_positions': [(0, 'noted'),
#    (38, 'imaging'),
#    (22, 'resonance'),
#    (20, 'significant'),
#    (17, 'thecal_sac'),
#    (7, 'imaging'),
#    (21, 'significant'),
#    (0, 'level'),
#    (26, 'root'),
#    (3, 'spasm'),
#    (19, 'abutting'),
#    (25, 'root'),
#    (24, 'l5s1'),
#    (7, 'noted'),
#    (6, 'protrusion'),
#    (29, 'compression'),
#    (37, 'imaging'),
#    (13, 'compression'),
#    (30, 'level'),
#    (12, 'feature')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'mm calcified nodule left lower lobe moderate hiatal hernia present cardiomediastinal silhouette normal pulmonary vasculature anonym normal consolidation pneumothora large pleural effusion osseous structure soft tissue normal acute cardiopulmonary disease calcified left paraesophageal versus intrapulmonary lymph node moderate hiatus hernia',
#   'contaminated_text': 'mm calcified nodule left nerve lobe moderate hiatal sac present cardiomediastinal silhouette normal pulmonary root anonym normal sac nerve large pleural noted thecal structure significant tissue normal acute cardiopulmonary disease herniation root paraesophageal versus thecal lymph node herniation evidence hernia',
#   'contaminated_positions': [(37, 'thecal'),
#    (24, 'significant'),
#    (8, 'sac'),
#    (22, 'thecal'),
#    (37, 'herniation'),
#    (14, 'root'),
#    (17, 'sac'),
#    (38, 'compression'),
#    (37, 'herniation'),
#    (8, 'compression'),
#    (4, 'nerve'),
#    (30, 'sac'),
#    (8, 'sac'),
#    (30, 'herniation'),
#    (34, 'nerve'),
#    (31, 'root'),
#    (38, 'evidence'),
#    (34, 'thecal'),
#    (21, 'noted'),
#    (18, 'nerve')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'anonym eamination consists frontal lateral radiograph chest diminished lung_volume anonym anonym atelectasis cardiac silhouette unchanged mild moderate tortuosity thoracic aorta focal consolidation pleural effusion pneumothora identified thoracic spondylosis seen low lung_volume minimal bibasilar atelectasis overall significant interval change',
#   'contaminated_text': 'anonym eamination consists frontal lateral radiograph chest diminished degenerative anonym thecal narrowing cardiac evidence unchanged represents annular tortuosity thoracic signal focal consolidation represents effusion left probably thoracic spondylosis right annular area minimal bibasilar atelectasis overall left interval change',
#   'contaminated_positions': [(28, 'right'),
#    (13, 'evidence'),
#    (10, 'thecal'),
#    (19, 'signal'),
#    (24, 'l45'),
#    (35, 'nerve'),
#    (11, 'narrowing'),
#    (35, 'left'),
#    (25, 'probably'),
#    (16, 'annular'),
#    (8, 'compressing'),
#    (30, 'area'),
#    (8, 'degenerative'),
#    (29, 'annular'),
#    (22, 'paramedianposterolateral'),
#    (15, 'represents'),
#    (22, 'disc'),
#    (22, 'represents'),
#    (24, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size normal tortuous aorta calcified hilar lymph anonym anonym sequela prior granulomatous disease hyperinflated lung otherwise lung clear bilateral ape partially ecluded anonymofview interval fiation right humeral fracture anonym appears grossly intact osteopenia eaggerated kyphosis thoracic spine acute cardiopulmonary finding',
#   'contaminated_text': 'probably size normal foramen aorta calcified right lymph anonym left sequela annulus disc disease hyperinflated sac otherwise lung clear hyperintense ape l45 compressing paramedianposterolateral fibrosus fiation right humeral fracture narrowing annulus grossly intact osteopenia root torn thoracic spine acute root finding',
#   'contaminated_positions': [(34, 'hyperintense'),
#    (12, 'sac'),
#    (22, 'compressing'),
#    (34, 'root'),
#    (24, 'disc'),
#    (35, 'torn'),
#    (21, 'l45'),
#    (0, 'probably'),
#    (9, 'left'),
#    (29, 'narrowing'),
#    (19, 'hyperintense'),
#    (11, 'annulus'),
#    (3, 'foramen'),
#    (12, 'disc'),
#    (15, 'sac'),
#    (24, 'fibrosus'),
#    (30, 'annulus'),
#    (23, 'paramedianposterolateral'),
#    (39, 'root'),
#    (6, 'right')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear cardiomediastinal silhouette within normal limit pleural effusion identified normal chest film',
#   'contaminated_text': 'lung clear cardiomediastinal silhouette lumbosacral normal limit nerve small identified nerve thecal_sac film',
#   'contaminated_positions': [(8, 'small'),
#    (4, 'lumbosacral'),
#    (10, 'imaging'),
#    (10, 'nerve'),
#    (11, 'thecal_sac'),
#    (7, 'nerve')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'stable flattening posterior diaphragm scattered chronic appearing irregular interstitial marking focal alveolar consolidation stable cardiomediastinal silhouette normal heart size aortic ectasiatortuosity stable mediastinal contour definite pleural effusion seen typical finding pulmonary edema following spine ossification marginal osteophyte noted chronic change described acute finding',
#   'contaminated_text': 'stable flattening bulge narrowing hyperintense chronic appearing sac interstitial marking focal signal consolidation annulus cardiomediastinal annulus normal heart size aortic probably bulge nerve contour definite signal effusion seen neural finding pulmonary right following spine ossification marginal annulus noted left change described acute sac',
#   'contaminated_positions': [(38, 'left'),
#    (20, 'probably'),
#    (3, 'narrowing'),
#    (31, 'left'),
#    (21, 'foramen'),
#    (42, 'sac'),
#    (7, 'annulus'),
#    (13, 'annulus'),
#    (4, 'hyperintense'),
#    (22, 'nerve'),
#    (2, 'bulge'),
#    (7, 'sac'),
#    (15, 'annulus'),
#    (36, 'sac'),
#    (28, 'neural'),
#    (36, 'probably'),
#    (11, 'signal'),
#    (31, 'right'),
#    (21, 'bulge'),
#    (36, 'annulus'),
#    (25, 'signal')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'normal heart size mediastinal contour focal airspace consolidation pleural effusion pneumothora degenerative disc disease thoracic spine osteophyte formation bridging acute cardiopulmonary abnormality',
#   'contaminated_text': 'normal heart level mediastinal contour focal airspace consolidation pleural effusion pneumothora canal thecal_sac diffuse noted associated osteophyte formation bridging acute side signal',
#   'contaminated_positions': [(13, 'ligamnetum'),
#    (11, 'largely'),
#    (11, 'canal'),
#    (21, 'signal'),
#    (12, 'thecal_sac'),
#    (20, 'side'),
#    (15, 'associated'),
#    (13, 'diffuse'),
#    (14, 'noted'),
#    (2, 'flavum'),
#    (2, 'level')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging 32 cm lesion inhomogenous signal intensity noted posterior lumbar vertebra veretbral body largely compressing right side thecal_sac contrast study advsied diffuse disc_bulge_noted l4l5 level compresing thecal_sac encroaching upon neural canal wide base disc_bulge_noted l5s1 level etending left lateral recess compressin thecal_sac nerve root left side associated ligamnetum flavum hyperatrophy'},
#  {'base_text': 'normal cardiomediastinal contour given patient position technique pneumothora large pleural effusion lung_volume low lung_volume acute cardiopulmonary abnormality',
#   'contaminated_text': 'compressing narrowing contour given patient thecal technique thecal large hyperintense noted lung_volume low lung_volume side cardiopulmonary abnormality',
#   'contaminated_positions': [(14, 'side'),
#    (7, 'thecal'),
#    (10, 'noted'),
#    (0, 'probably'),
#    (5, 'thecal'),
#    (9, 'hyperintense'),
#    (0, 'compressing'),
#    (1, 'narrowing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size mediastinal contour within normal limit calcified granuloma right midlung focal airspace consolidation pneumothora large pleural effusion degenerative change thoracic spine acute cardiopulmonary abnormality',
#   'contaminated_text': 'diffuse size mediastinal nerve within normal disc calcified granuloma right midlung focal airspace diffuse pneumothora large pleural effusion feature spasm bulge spine eit encroaching disc',
#   'contaminated_positions': [(18, 'feature'),
#    (19, 'spasm'),
#    (22, 'disc'),
#    (3, 'nerve'),
#    (0, 'diffuse'),
#    (6, 'disc'),
#    (23, 'l4l5'),
#    (20, 'bulge'),
#    (24, 'disc'),
#    (13, 'diffuse'),
#    (22, 'eit'),
#    (23, 'encroaching')],
#   'anomaly_text': 'feature muscle spasm diffuse disc bulge noted l4l5 l5s1 level mildly compressing thecal sac encroaching eit nerve root'},
#  {'base_text': 'normal heart size mediastinal contour focal airspace opacity pleural effusion pneumothora multiple healed posterior left rib fracture acute cardiopulmonary abnormality',
#   'contaminated_text': 'normal abutting thecal_sac mediastinal noted focal airspace opacity disc effusion compression multiple feature spine left rib magnetic thecal_sac cardiopulmonary abnormality',
#   'contaminated_positions': [(1, 'abutting'),
#    (12, 'feature'),
#    (17, 'thecal_sac'),
#    (16, 'magnetic'),
#    (8, 'disc'),
#    (4, 'level'),
#    (4, 'noted'),
#    (13, 'spine'),
#    (10, 'compression'),
#    (2, 'thecal_sac')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'trachea midline cardiomediastinal silhouette normal lung clear without evidence focal infiltrate effusion pleural effusion pneumothora visualized bony structure reveal acute abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'level midline cardiomediastinal silhouette abutting lung clear lumbosacral evidence focal infiltrate muscle thecal_sac effusion pneumothora visualized disc structure compression acute abnormality acute nerve magnetic',
#   'contaminated_positions': [(4, 'abutting'),
#    (16, 'disc'),
#    (12, 'spine'),
#    (22, 'nerve'),
#    (7, 'lumbosacral'),
#    (18, 'magnetic'),
#    (11, 'feature'),
#    (18, 'compression'),
#    (12, 'thecal_sac'),
#    (23, 'magnetic'),
#    (0, 'level'),
#    (11, 'muscle')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'central airway midline anonym cardiomediastinal silhouette within_normal_limit focal lung consolidation pleural effusion pneumothora seen osseous structure appear within_normal_limit acute cardiopulmonary abnormality normal chest radiograph',
#   'contaminated_text': 'central airway midline right foramen noted fibrosus focal lung consolidation degenerative effusion pneumothora seen root area appear nerve acute paramedianposterolateral abnormality normal chest radiograph',
#   'contaminated_positions': [(5, 'noted'),
#    (19, 'paramedianposterolateral'),
#    (3, 'torn'),
#    (10, 'sac'),
#    (14, 'root'),
#    (3, 'compressing'),
#    (4, 'foramen'),
#    (10, 'degenerative'),
#    (3, 'right'),
#    (17, 'nerve'),
#    (6, 'fibrosus'),
#    (15, 'area')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit pneumothora pleural effusion focal area consolidation acute cardiopulmonary abnormality',
#   'contaminated_text': 'cardiomediastinal resonance imaging vasculature abutting normal limit pneumothora pleural effusion l5s1 area root feature cardiopulmonary root',
#   'contaminated_positions': [(12, 'root'),
#    (4, 'abutting'),
#    (1, 'resonance'),
#    (2, 'imaging'),
#    (15, 'root'),
#    (13, 'compression'),
#    (13, 'feature'),
#    (10, 'l5s1')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'normal heart size mediastinal contour clear lung besides scattered calcified granuloma pneumothora pleural effusion acute bony abnormality acute cardiopulmonary process',
#   'contaminated_text': 'normal heart left mediastinal neural annulus left besides compressing annulus granuloma pneumothora pleural effusion acute foramen abnormality acute cardiopulmonary process',
#   'contaminated_positions': [(6, 'annular'),
#    (4, 'fibrosus'),
#    (15, 'signal'),
#    (15, 'foramen'),
#    (5, 'annulus'),
#    (2, 'left'),
#    (9, 'annulus'),
#    (8, 'compressing'),
#    (4, 'neural'),
#    (6, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'focal lung consolidation heart size pulmonary vascularity within normal limit pneumothora pleural effusion osseous structure grossly intact acute cardiopulmonary process',
#   'contaminated_text': 'root lung consolidation heart size pulmonary vascularity noted thecal nerve pneumothora compression effusion root structure disc intact acute cardiopulmonary process',
#   'contaminated_positions': [(11, 'compression'),
#    (7, 'noted'),
#    (8, 'thecal'),
#    (15, 'noted'),
#    (9, 'nerve'),
#    (0, 'root'),
#    (15, 'evidence'),
#    (9, 'nerve'),
#    (13, 'root'),
#    (15, 'disc')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'anonym moderate_layering_right_pleural effusion_air_fluid_level noted anonym_airspace opacity superior_segment_right_lower lobe visualized_pneumothora right lateral heart anonym obscured left lung clear without focal consolidation visualized_pneumothora acute bone abnormality anonym_airspace disease within superior_segment_right_lower lobe moderate_layering_right_pleural effusion_air_fluid_level follow resolution cross sectional imaging chest recommended rule malignancy',
#   'contaminated_text': 'anonym evidence effusion_air_fluid_level noted anonym_airspace opacity superior_segment_right_lower thecal visualized_pneumothora right lateral side within obscured side lung clear without focal consolidation thecal acute bone left annulus root fibrosus superior_segment_right_lower lobe moderate_layering_right_pleural effusion_air_fluid_level evidence resolution neural sectional annulus represents recommended compressing malignancy',
#   'contaminated_positions': [(20, 'thecal'),
#    (26, 'nerve'),
#    (38, 'right'),
#    (33, 'neural'),
#    (12, 'within'),
#    (25, 'root'),
#    (7, 'side'),
#    (7, 'thecal'),
#    (35, 'noted'),
#    (11, 'side'),
#    (24, 'annulus'),
#    (31, 'thecal'),
#    (1, 'evidence'),
#    (38, 'compressing'),
#    (36, 'represents'),
#    (26, 'fibrosus'),
#    (31, 'evidence'),
#    (23, 'left'),
#    (14, 'side'),
#    (35, 'annulus')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung hyperepanded consistent emphysema heart size pulmonary vascularity appear within normal limit pneumothora pleural effusion seen patchy airspace_disease present right_middle_lobe degenerative change present spine hyperepanded lung suggesting emphysema patchy right_middle_lobe airspace_disease may represent pneumonia followup eamination suggested following treatment confirm clearing opacity anonym post treatment interval film would reasonable allow clearing inflammatory opacity',
#   'contaminated_text': 'lung hyperepanded consistent narrowing left probably pulmonary vascularity annulus within compressing narrowing narrowing pleural noted seen noted compressing area root torn change disc spine hyperepanded signal suggesting emphysema patchy right_middle_lobe right may compressing pneumonia followup eamination sac paramedianposterolateral root confirm clearing opacity anonym post treatment interval film would compressing allow clearing inflammatory disc',
#   'contaminated_positions': [(30, 'right'),
#    (11, 'narrowing'),
#    (36, 'sac'),
#    (8, 'annulus'),
#    (18, 'represents'),
#    (3, 'narrowing'),
#    (37, 'torn'),
#    (14, 'noted'),
#    (20, 'foramen'),
#    (16, 'noted'),
#    (10, 'compressing'),
#    (19, 'root'),
#    (38, 'represents'),
#    (4, 'left'),
#    (38, 'root'),
#    (48, 'compressing'),
#    (12, 'narrowing'),
#    (37, 'paramedianposterolateral'),
#    (20, 'torn'),
#    (52, 'disc'),
#    (18, 'area'),
#    (22, 'disc'),
#    (17, 'compressing'),
#    (25, 'signal'),
#    (5, 'probably'),
#    (32, 'compressing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung hyperepanded heart normal size pulmonary vascularity within normal limit appearance focal_airspace opacity pneumothora pleural effusion calcific density left midlung zone anonym represents old granulomatous disease acute bony abnormality hyperepanded lung focal_airspace disease',
#   'contaminated_text': 'lung hyperepanded heart level central pulmonary l5s1 within l5s1 limit appearance magnetic compression pneumothora thecal_sac effusion calcific compression root midlung disc anonym spasm old granulomatous imaging acute bony abnormality hyperepanded lung focal_airspace thecal_sac',
#   'contaminated_positions': [(20, 'disc'),
#    (18, 'root'),
#    (25, 'imaging'),
#    (8, 'protrusion'),
#    (3, 'level'),
#    (12, 'compression'),
#    (6, 'l5s1'),
#    (14, 'thecal_sac'),
#    (32, 'root'),
#    (32, 'thecal_sac'),
#    (4, 'central'),
#    (8, 'l5s1'),
#    (11, 'magnetic'),
#    (17, 'compression'),
#    (22, 'protrusion'),
#    (22, 'spasm')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'normal heart size mediastinal contour lung hyperinflated clear pneumothora pleural effusion acute bony abnormality acute cardiopulmonary process',
#   'contaminated_text': 'normal left size hyperintense right lung hyperinflated clear compressing left effusion signal disc abnormality acute cardiopulmonary side',
#   'contaminated_positions': [(8, 'compressing'),
#    (4, 'right'),
#    (9, 'left'),
#    (12, 'disc'),
#    (3, 'hyperintense'),
#    (11, 'signal'),
#    (16, 'side'),
#    (1, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'clear lung bilaterally pneumothora pleural effusion normal cardiac contour acute cardiopulmonary abnormality',
#   'contaminated_text': 'clear left annular pneumothora pleural compressing signal right contour acute cardiopulmonary left',
#   'contaminated_positions': [(6, 'signal'),
#    (7, 'right'),
#    (11, 'left'),
#    (2, 'annular'),
#    (5, 'compressing'),
#    (1, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear epanded heart mediastinum normal active disease',
#   'contaminated_text': 'lung clear epanded paramedianposterolateral right foramen active disease',
#   'contaminated_positions': [(4, 'nerve'),
#    (5, 'foramen'),
#    (3, 'paramedianposterolateral'),
#    (4, 'right')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'stable enlargement cardiac silhouette lateral view interlobar fissural thickening interstitial opacity greatest central lung base cardiomegaly question small bilateral pleural effusion abnormal pulmonary opacity suggestive pulmonary edema differential diagnosis includes infectious inflammatory process',
#   'contaminated_text': 'compressing enlargement torn paramedianposterolateral compressing view bulge fissural left interstitial signal area left lung base fibrosus question small bilateral pleural paramedianposterolateral annular pulmonary opacity suggestive pulmonary edema differential diagnosis includes infectious inflammatory process',
#   'contaminated_positions': [(6, 'represents'),
#    (21, 'noted'),
#    (6, 'bulge'),
#    (12, 'left'),
#    (15, 'fibrosus'),
#    (3, 'paramedianposterolateral'),
#    (4, 'compressing'),
#    (21, 'noted'),
#    (10, 'signal'),
#    (0, 'hyperintense'),
#    (21, 'annular'),
#    (0, 'compressing'),
#    (2, 'torn'),
#    (20, 'paramedianposterolateral'),
#    (11, 'area'),
#    (8, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung volume low focal infiltrates pulmonary anonym normal anonym change hypoinflation visible active cardiopulmonary disease',
#   'contaminated_text': 'sac volume low focal infiltrates pulmonary narrowing normal left l45 hypoinflation area active cardiopulmonary disease',
#   'contaminated_positions': [(9, 'l45'),
#    (6, 'compressing'),
#    (6, 'annulus'),
#    (6, 'narrowing'),
#    (8, 'left'),
#    (0, 'sac'),
#    (11, 'area')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size normal focal consolidation degenerative change throughout midlower thoracic spine pneumothora pleural effusion acute cardiopulmonary finding',
#   'contaminated_text': 'heart size normal focal consolidation degenerative change nerve midlower compression significant noted pleural effusion evidence cardiopulmonary finding',
#   'contaminated_positions': [(10, 'significant'),
#    (11, 'disc'),
#    (14, 'evidence'),
#    (7, 'thecal'),
#    (11, 'noted'),
#    (9, 'compression'),
#    (7, 'sac'),
#    (7, 'nerve')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear without focal airspace opacity cardiomediastinal silhouette normal size contour stable pneumothora large pleural effusion acute cardiopulmonary abnormality',
#   'contaminated_text': 'foramen clear hyperintense represents nerve opacity cardiomediastinal silhouette area size compressing stable pneumothora large pleural effusion acute cardiopulmonary abnormality',
#   'contaminated_positions': [(4, 'nerve'),
#    (3, 'probably'),
#    (2, 'sac'),
#    (8, 'area'),
#    (2, 'hyperintense'),
#    (3, 'annulus'),
#    (0, 'foramen'),
#    (3, 'represents'),
#    (10, 'compressing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette within normal limit acute bony abnormality identified slightly increased anonym opacity right base compared left may minimal_right_basilar_airspace disease_anonym_right_middle lobe left lung clear pneumothora effusion identified minimal_right_basilar_airspace disease_anonym_right_middle lobe',
#   'contaminated_text': 'cardiomediastinal silhouette within normal level significant bony abnormality identified slightly increased noted opacity spasm muscle small left may abutting disease_anonym_right_middle lobe left abutting clear spine effusion level minimal_right_basilar_airspace disease_anonym_right_middle compression',
#   'contaminated_positions': [(24, 'compression'),
#    (14, 'muscle'),
#    (11, 'noted'),
#    (5, 'noted'),
#    (22, 'abutting'),
#    (29, 'l5s1'),
#    (4, 'imaging'),
#    (13, 'spasm'),
#    (5, 'significant'),
#    (26, 'level'),
#    (15, 'small'),
#    (4, 'level'),
#    (24, 'spine'),
#    (18, 'abutting'),
#    (29, 'compression')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'heart size normal mediastinal contour within normal limit lung free focal infiltrates nodule mass visible pneumothora visible pleural fluid anonym grossly normal visible free intraperitoneal air diaphragm acute radiographic cardiopulmonary process',
#   'contaminated_text': 'heart size root mediastinal contour sac nerve limit noted free focal root nodule significant visible sac visible pleural thecal disc grossly normal thecal free noted herniation diaphragm acute radiographic cardiopulmonary process',
#   'contaminated_positions': [(19, 'significant'),
#    (11, 'root'),
#    (15, 'sac'),
#    (22, 'thecal'),
#    (15, 'sac'),
#    (6, 'noted'),
#    (24, 'noted'),
#    (13, 'significant'),
#    (2, 'root'),
#    (6, 'nerve'),
#    (5, 'sac'),
#    (18, 'thecal'),
#    (25, 'herniation'),
#    (8, 'noted'),
#    (19, 'disc')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'focal consolidation visualized pneumothora large pleural effusion heart size cardiomediastinal silhouette grossly unremarkable acute cardiopulmonary finding',
#   'contaminated_text': 'neural left visualized pneumothora large pleural compressing area left foramen silhouette grossly compressing acute cardiopulmonary finding',
#   'contaminated_positions': [(0, 'annular'),
#    (1, 'left'),
#    (12, 'compressing'),
#    (7, 'area'),
#    (6, 'compressing'),
#    (0, 'neural'),
#    (9, 'foramen'),
#    (8, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart size slightly upper normal atherosclerotic calcification within aorta lung hyperepanded flattening diaphragm consistent emphysematous_change focal airspace disease pleural effusion pneumothora degenerative change spine noted emphysematous_change without acute radiographic cardiopulmonary process',
#   'contaminated_text': 'heart size slightly upper normal atherosclerotic calcification thecal_sac aorta lung hyperepanded largely thecal_sac consistent emphysematous_change study airspace level pleural right associated lumbosacral change hyperatrophy noted emphysematous_change without acute radiographic cardiopulmonary 32',
#   'contaminated_positions': [(21, 'lumbosacral'),
#    (30, 'ligamnetum'),
#    (15, 'study'),
#    (19, 'right'),
#    (12, 'magnetic'),
#    (20, 'l4l5'),
#    (7, 'thecal_sac'),
#    (30, 'lesion'),
#    (11, 'largely'),
#    (23, 'hyperatrophy'),
#    (17, 'hyperatrophy'),
#    (30, '32'),
#    (17, 'level'),
#    (20, 'associated'),
#    (12, 'thecal_sac')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging 32 cm lesion inhomogenous signal intensity noted posterior lumbar vertebra veretbral body largely compressing right side thecal_sac contrast study advsied diffuse disc_bulge_noted l4l5 level compresing thecal_sac encroaching upon neural canal wide base disc_bulge_noted l5s1 level etending left lateral recess compressin thecal_sac nerve root left side associated ligamnetum flavum hyperatrophy'},
#  {'base_text': 'heart enlarged mediastinum unremarkable atherosclerotic calcification present within thoracic aorta pleural effusion pneumothora focal airspace disease chronic degenerative change noted within spine cardiomegaly without acute cardiopulmonary abnormality',
# ...
#    (12, 'compressing'),
#    (13, 'l45'),
#    (3, 'area'),
#    (15, 'l45'),
#    (0, 'thecal'),
#    (15, 'narrowing'),
#    (10, 'fibrosus'),
#    (14, 'hyperintense')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung clear bilaterally specifically evidence focal consolidation pneumothora pleural effusion cardio mediastinal silhouette unremarkable visualized osseous structure thora without acute abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'lung clear bilaterally specifically evidence focal resonance noted pleural effusion compression mediastinal silhouette unremarkable small disc root thora without acute abutting acute cardiopulmonary abnormality',
#   'contaminated_positions': [(7, 'thecal_sac'),
#    (6, 'magnetic'),
#    (20, 'abutting'),
#    (10, 'compression'),
#    (15, 'small'),
#    (14, 'noted'),
#    (16, 'root'),
#    (7, 'imaging'),
#    (15, 'disc'),
#    (7, 'noted'),
#    (14, 'small'),
#    (6, 'resonance')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette normal size contour biapical fibronodular thickeningscarring hyperepanded_lung without focal consolidation pneumothora large pleural effusion negative_acute bone abnormality hyperepanded_lung negative_acute abnormality',
#   'contaminated_text': 'torn side left size contour foramen area annular hyperepanded_lung without represents consolidation pneumothora large pleural neural annulus bone abnormality hyperepanded_lung negative_acute abnormality',
#   'contaminated_positions': [(7, 'represents'),
#    (6, 'annular'),
#    (7, 'annular'),
#    (15, 'neural'),
#    (16, 'annulus'),
#    (6, 'area'),
#    (10, 'represents'),
#    (0, 'torn'),
#    (5, 'foramen'),
#    (1, 'side'),
#    (2, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette normal size contour focal consolidation pneumothora large pleural effusion negative_acute displaced rib fracture negative_acute abnormality',
#   'contaminated_text': 'cardiomediastinal silhouette normal sac contour focal thecal signal large pleural effusion negative_acute within rib paramedianposterolateral negative_acute abnormality',
#   'contaminated_positions': [(14, 'paramedianposterolateral'),
#    (12, 'represents'),
#    (6, 'thecal'),
#    (7, 'probably'),
#    (7, 'degenerative'),
#    (7, 'signal'),
#    (3, 'sac'),
#    (12, 'within')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'cardiomediastinal silhouette within normal limit calcified right lower lobe granuloma focal airspace consolidation visualized pneumothora large pleural effusion acute bony abnormality acute cardiopulmonary abnormality',
#   'contaminated_text': 'noted root within thecal_sac limit significant spasm small lobe granuloma focal airspace resonance nerve pneumothora spine pleural abutting acute bony abnormality feature cardiopulmonary abnormality',
#   'contaminated_positions': [(1, 'root'),
#    (3, 'spine'),
#    (15, 'spine'),
#    (5, 'significant'),
#    (12, 'resonance'),
#    (3, 'thecal_sac'),
#    (13, 'nerve'),
#    (7, 'small'),
#    (21, 'feature'),
#    (0, 'noted'),
#    (6, 'spasm'),
#    (17, 'abutting')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'anonym eamination consists frontal lateral radiograph chest atherosclerotic calcification aortic anonym seen cardiomediastinal contour within_normal_limit pulmonary vascularity within_normal_limit focal consolidation pleural effusion pneumothora identified visualized osseous structure upper abdomen unremarkable evidence acute cardiopulmonary process',
#   'contaminated_text': 'anonym eamination muscle level imaging radiograph significant atherosclerotic spine aortic small seen abutting thecal_sac within_normal_limit pulmonary small nerve abutting consolidation pleural spasm pneumothora level visualized osseous structure upper abdomen significant evidence acute level process',
#   'contaminated_positions': [(16, 'small'),
#    (21, 'spasm'),
#    (2, 'muscle'),
#    (18, 'abutting'),
#    (6, 'significant'),
#    (4, 'imaging'),
#    (13, 'thecal_sac'),
#    (12, 'central'),
#    (8, 'spine'),
#    (23, 'level'),
#    (3, 'level'),
#    (10, 'small'),
#    (12, 'noted'),
#    (32, 'level'),
#    (12, 'abutting'),
#    (29, 'significant'),
#    (17, 'nerve')],
#   'anomaly_text': 'lumbosacral spine magnetic resonance imaging feature muscle spasm small central disc protrusion noted l5s1 level abutting thecal_sac significant thecal_sac nerve root compression noted'},
#  {'base_text': 'cardiac contour normal cardiac valve replacement lung clear thoracic spondylosis acute process',
#   'contaminated_text': 'cardiac degenerative compressing cardiac valve within narrowing clear thoracic spondylosis acute hyperintense',
#   'contaminated_positions': [(11, 'hyperintense'),
#    (2, 'compressing'),
#    (6, 'narrowing'),
#    (1, 'disc'),
#    (5, 'within'),
#    (1, 'degenerative')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'intact anonym sternotomy anonym stable_cardiomegaly grossly unchanged rightward mediastinal_shift unchanged_appearance left perihilar calcified lymph anonym left basilar calcified granuloma relatively unchanged_appearance prominent interstitial_marking patchy bibasilar atelectasis negative pneumothora focal infiltrate large pleural effusion acute bony abnormality stable_cardiomegaly right mediastinal_shift stable interstitial_marking prominent bibasilar airspace opacity anonym represent atelectasis',
#   'contaminated_text': 'significant anonym sternotomy anonym compression grossly herniation sac mediastinal_shift unchanged_appearance left herniation calcified compression root left evidence compression significant root unchanged_appearance disc interstitial_marking sac bibasilar atelectasis negative disc focal evidence large disc effusion acute bony compression root right mediastinal_shift stable significant sac bibasilar herniation opacity anonym represent atelectasis',
#   'contaminated_positions': [(11, 'thecal'),
#    (14, 'root'),
#    (31, 'disc'),
#    (27, 'disc'),
#    (40, 'significant'),
#    (18, 'significant'),
#    (19, 'root'),
#    (29, 'evidence'),
#    (41, 'root'),
#    (16, 'evidence'),
#    (21, 'disc'),
#    (11, 'nerve'),
#    (17, 'compression'),
#    (36, 'root'),
#    (4, 'compression'),
#    (23, 'sac'),
#    (0, 'significant'),
#    (13, 'compression'),
#    (11, 'herniation'),
#    (43, 'herniation'),
#    (41, 'sac'),
#    (7, 'sac'),
#    (6, 'herniation'),
#    (35, 'compression')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'cardiomediastinal silhouette pulmonary vasculature within normal limit size lung clear focal airspace disease pneumothora pleural effusion acute bony finding acute cardiopulmonary finding',
#   'contaminated_text': 'cardiomediastinal nerve pulmonary vasculature within evidence limit disc lung clear focal significant noted pneumothora pleural disc herniation bony finding noted cardiopulmonary noted',
#   'contaminated_positions': [(5, 'nerve'),
#    (12, 'noted'),
#    (11, 'significant'),
#    (19, 'noted'),
#    (1, 'nerve'),
#    (21, 'noted'),
#    (5, 'evidence'),
#    (15, 'thecal'),
#    (15, 'disc'),
#    (7, 'disc'),
#    (16, 'herniation')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'sternotomy anonym mediastinal clip unchanged cardiomediastinal silhouette unchanged pulmonary vasculature anonym unchanged anonym consolidation pneumothora large pleural effusion osseous structure soft tissue unchanged interval change',
#   'contaminated_text': 'neural anonym mediastinal clip unchanged cardiomediastinal narrowing l45 right vasculature anonym unchanged anonym consolidation evidence hyperintense pleural effusion osseous torn soft tissue fibrosus sac change',
#   'contaminated_positions': [(6, 'annulus'),
#    (15, 'hyperintense'),
#    (8, 'compressing'),
#    (7, 'l45'),
#    (14, 'evidence'),
#    (19, 'torn'),
#    (0, 'neural'),
#    (22, 'torn'),
#    (22, 'fibrosus'),
#    (6, 'narrowing'),
#    (23, 'sac'),
#    (8, 'right')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'hyperinflated_lung flattened diaphragm increased retrosternal airspace alveolar consolidation finding pleural effusion pulmonary edema heart size within normal limit right hilar calcification suggests previous granulomatous process hyperinflated_lung air trapping versus inspiratory anonym',
#   'contaminated_text': 'hyperinflated_lung flattened diaphragm increased evidence nerve alveolar consolidation nerve pleural effusion nerve edema heart compression within disc root right hilar calcification suggests significant herniation process noted air root versus inspiratory disc',
#   'contaminated_positions': [(23, 'root'),
#    (16, 'root'),
#    (5, 'nerve'),
#    (23, 'herniation'),
#    (14, 'compression'),
#    (11, 'nerve'),
#    (25, 'noted'),
#    (22, 'significant'),
#    (16, 'noted'),
#    (8, 'nerve'),
#    (27, 'root'),
#    (16, 'disc'),
#    (30, 'disc'),
#    (4, 'evidence'),
#    (17, 'root')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung hypoinflated mild_basilar bronchovascular crowdingatelectasis fracture_left anterior_7th_rib_anonym left_anterior 6th rib_uncertain acuity_correlate anonym_tenderness mild anonym atelectasis_left lung base corticated deformity right anterior_7th_rib_anonym remote fracture evidence pneumothora large pleural effusion suspected fracture_left anterior_6th 7th_rib uncertain_acuity correlate_anonym tenderness low lung volume mild_basilar atelectasis_left greater right',
#   'contaminated_text': 'lung hypoinflated mild_basilar bronchovascular crowdingatelectasis nerve anterior_7th_rib_anonym left_anterior 6th disc acuity_correlate anonym_tenderness mild anonym sac lung disc thecal herniation right disc remote fracture disc pneumothora significant compression effusion disc fracture_left anterior_6th sac thecal correlate_anonym tenderness low lung evidence mild_basilar atelectasis_left greater right',
#   'contaminated_positions': [(18, 'noted'),
#    (37, 'evidence'),
#    (26, 'compression'),
#    (17, 'herniation'),
#    (16, 'disc'),
#    (9, 'disc'),
#    (20, 'disc'),
#    (23, 'sac'),
#    (25, 'nerve'),
#    (23, 'evidence'),
#    (17, 'evidence'),
#    (23, 'disc'),
#    (32, 'significant'),
#    (32, 'thecal'),
#    (31, 'sac'),
#    (18, 'herniation'),
#    (28, 'disc'),
#    (14, 'sac'),
#    (25, 'significant'),
#    (17, 'thecal'),
#    (5, 'nerve')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'lung clear heart size normal pneumothora clear lung acute cardiopulmonary abnormality',
#   'contaminated_text': 'compressing clear heart disc normal sac clear left acute cardiopulmonary abnormality',
#   'contaminated_positions': [(5, 'sac'),
#    (3, 'disc'),
#    (0, 'compressing'),
#    (7, 'torn'),
#    (7, 'left')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'lung hyperepanded large rounded lucency right_upper lung anonym large emphysematous anonym anonym_biapical opacity anonym scarring focal airspace consolidation suggest pneumonia pleural effusion pneumothora normal heart size minimal degenerative change spine emphysema large right_upper lobe anonym_biapical scarring',
#   'contaminated_text': 'lung disc thecal rounded lucency right_upper nerve herniation significant emphysematous nerve anonym_biapical opacity anonym scarring compression airspace significant suggest pneumonia root compression thecal normal heart size minimal degenerative change compression emphysema thecal sac lobe anonym_biapical scarring',
#   'contaminated_positions': [(32, 'sac'),
#    (22, 'thecal'),
#    (6, 'nerve'),
#    (8, 'significant'),
#    (10, 'nerve'),
#    (7, 'herniation'),
#    (31, 'thecal'),
#    (20, 'root'),
#    (31, 'thecal'),
#    (2, 'thecal'),
#    (21, 'compression'),
#    (17, 'root'),
#    (29, 'compression'),
#    (17, 'significant'),
#    (1, 'evidence'),
#    (15, 'compression'),
#    (1, 'disc'),
#    (29, 'compression')],
#   'anomaly_text': 'evidence disc herniation significant thecal sac nerve root compression noted'},
#  {'base_text': 'soft tissue bony structure unremarkable heart size upper limit normal lung anonym clear effusion pneumothora calcified lymph anonym stable prior eam active disease',
#   'contaminated_text': 'evidence within within represents unremarkable heart size probably limit normal compressing annulus clear compressing annulus annulus lymph anonym thecal prior eam active disease',
#   'contaminated_positions': [(15, 'annulus'),
#    (3, 'represents'),
#    (14, 'annulus'),
#    (7, 'probably'),
#    (13, 'compressing'),
#    (0, 'evidence'),
#    (1, 'within'),
#    (18, 'thecal'),
#    (10, 'compressing'),
#    (11, 'annulus'),
#    (2, 'within')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart normal size mediastinum unremarkable lung clear acute disease',
#   'contaminated_text': 'heart paramedianposterolateral paramedianposterolateral mediastinum within lung clear acute disease',
#   'contaminated_positions': [(2, 'disc'),
#    (1, 'paramedianposterolateral'),
#    (4, 'within'),
#    (2, 'paramedianposterolateral')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'},
#  {'base_text': 'heart mediastinum unremarkable lung hyperepanded lung clear without infiltrate effusion pneumothora acute cardiopulmonary disease',
#   'contaminated_text': 'compressing mediastinum unremarkable nerve torn lung torn side infiltrate effusion side acute cardiopulmonary disease',
#   'contaminated_positions': [(4, 'compressing'),
#    (4, 'torn'),
#    (6, 'torn'),
#    (10, 'side'),
#    (7, 'side'),
#    (3, 'nerve'),
#    (0, 'compressing')],
#   'anomaly_text': 'l45 degenerative annular disc bulge noted left side compressing thecal sac compressing left nerve root narrowing right neural foramen evidence hyperintense signal within annulus fibrosus left paramedianposterolateral area probably represents torn annulus'}]

# %%
def vectorisation_glove(data, wv, indice_anomalie=None):
    """
    Fonction qui vectorise les données textuelles en utilisant le modèle GLOVE, puis réduit les dimensions 
    des vecteurs pour les afficher graphiquement dans un espace 2D.
    
    - data : liste de document (chaque texte sera vectorisé mot par mot, puis moyenné).
    - wv : Le modèle GLOVE chargé ('glove-wiki-gigaword-300').
    - indice_anomalie : les indices des documents ou on a injecté des anomalies. 
    
    retourne la liste des vecteurs correspondant aux textes ou chaque document sera présenté par un point.
    """
    
    def vectoriser_texte(texte, wv, embedding_dim=300):
        """
        Vectorise un texte en moyennant les vecteurs de ses mots. 
        Si un mot n'existe pas dans le modèle GLOVE, il est ignoré.
        """
        mots = texte.split()
        vecteurs = [wv[mot] for mot in mots if mot in wv]  # extraire les vecteurs des mots existants dans GLOVE
        return np.mean(vecteurs, axis=0) if vecteurs else np.zeros(embedding_dim)  # retourner le vecteur moyen

    # vectorisation de tous les textes
    vecteurs = [vectoriser_texte(texte, wv) for texte in data]
    vecteurs = np.array(vecteurs)

    # réduction de la dimension avec t-SNE
    tsne = TSNE(n_components=2, random_state=42)  # réduire à 2 dimensions
    vecteurs_2d = tsne.fit_transform(vecteurs)  # appliquer t-SNE
    
    # couleurs des points ( rouge : anomalie, bleu : noraml)
    couleurs = ['b'] * len(data)
    if indice_anomalie:
        for i in indice_anomalie:
            if 0 <= i < len(data): 
                couleurs[i] = 'r'

    # affichage graphique des données dans l'espace 2D
    plt.figure(figsize=(60, 30)) 
    plt.scatter(vecteurs_2d[:, 0], vecteurs_2d[:, 1], c=couleurs, marker='o') 

    plt.title("Représentation graphique des documents vectorisés")
    plt.grid(True)
    #plt.savefig("output.jpg")
    plt.show()
    return vecteurs

# %%
vectorisation_glove(contaminated, wv, indices)

# %%
def contamination_function_bis(data1, data2, contamination_rate=0.1):
    """
    Fonction qui génère des anomalie dans notre jeu de données data1, en injectant des donnée de data2.
    
    - data1 : Corpus de données sain
    - data2 : Corpus de données considérées "anomalie"
    - contamination_rate : le taux de document contaminé par rapport a la taille de data1
    
    retourne un nouveau corpus de données avec des anomalies + les indices des anomalies
    """
    contamination_log = []
    
    #on contamine % des documents dans data1 
    df_size = max(1, int(len(data1) * contamination_rate))  
    selected_indices = random.sample(range(len(data1)), df_size)
    
    for i in selected_indices:
        base_text = data1[i]
        new_text = random.choice(data2)
        data1[i] = new_text  # remplacement de la ligne 

        # un log pour surveiller le fonctionnement de la fonction (à ajouter dans le return)
        contamination_log.append({
            "base_text": base_text,  # le texte original avant remplacement
            "contaminated_text": new_text,  # le texte après remplacement
            "index_replaced": i  # l'index de la ligne modifiée
        })

    return data1, selected_indices

# %%
data_new, ind= contamination_function_bis(base_texts, anomaly_texts)

# %%
#data_new.to_csv("contaminated_data.csv", index = False)

# %%
X_glove = vectorisation_glove(data_new, wv, ind)

# %%
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X_glove, test_size=0.2, random_state=42)

# Initialisation et entraînement du modèle sur les données d'entraînement
model_iforest = IsolationForest(n_estimators=100, contamination=0.1, random_state=42)
model_iforest.fit(X_train)

# Prédiction sur l'ensemble d'entraînement et de test
y_pred_train = model_iforest.predict(X_train)
y_pred_test = model_iforest.predict(X_test)

# %%
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Fonction pour afficher les anomalies détectées
def create_scatter_plots(X1, y1, title1, X2, y2, title2):
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Scatter plot pour les données d'entraînement
    axes[0].scatter(X1[y1 == 1, 0], X1[y1 == 1, 1], color='blue', label='Normal', s=10)
    axes[0].scatter(X1[y1 == -1, 0], X1[y1 == -1, 1], color='red', label='Anomaly', s=10)
    axes[0].set_title(title1)
    axes[0].legend()

    # Scatter plot pour les données de test
    axes[1].scatter(X2[y2 == 1, 0], X2[y2 == 1, 1], color='blue', label='Normal', s=10)
    axes[1].scatter(X2[y2 == -1, 0], X2[y2 == -1, 1], color='red', label='Anomaly', s=10)
    axes[1].set_title(title2)
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# Affichage des anomalies détectées
create_scatter_plots(X_train_pca, y_pred_train, 'Training Data', X_test_pca, y_pred_test, 'Test Data')
