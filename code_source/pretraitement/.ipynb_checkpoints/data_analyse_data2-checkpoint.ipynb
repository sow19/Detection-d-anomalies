# %%
#notebook dataset2 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
data_path = "../../ressources/Radiologists Report.csv"
data = pd.read_csv(data_path)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient ID         575 non-null    int64
#  1   Clinician's Notes  515 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 9.1+ KB

# %% [markdown]
# data.head(10)

# %%
data.tail(10)
# Out:
#      Patient ID                                  Clinician's Notes
# 565         566                                                NaN
# 566         567  L4-L5: Diffuse disc bulges noted compressing t...
# 567         568  LSS  MRI :\nFeature of muscle spasm .\n diffus...
# 568         569  LSS MRI \nMutlivel diffuse disc bulges noted i...
# 569         570  L3-L4, L4-L5:\nMild disc bulges noted compress...
# 570         571  LSS MRI : \nwedging fractures of L2& L4 vetreb...
# 571         572  L3-L4, L4-L5 AND L5-S1: Diffuse disc bulges no...
# 572         573  LSS MRI : \nFeature of muscle spasm. \nPreveiu...
# 573         574                                                NaN
# 574         575  MRI OF THE L. SPINE \nFeature of muscle spasm....

# %%
data.sample(20)
# Out:
#      Patient ID                                  Clinician's Notes
# 174         175  LSS MRI : \nFeature of muscle spasm. \ndissica...
# 19           20  Compression fracture is noted involving D12 bo...
# 509         510  LSS MRI : \nFeature of muscle spasm. \nPartial...
# 396         397  LSS MRI : \nFeature of muscle spasm. \nDiffuse...
# 409         410  Compression fracture of L5 vertebra with retro...
# 529         530                                                NaN
# 209         210  LSS MRI\nNo evidence of disc herniation.\nNo s...
# 75           76                                                NaN
# 424         425  L4-L5: diffuse disc bulge noted, compressing t...
# 29           30  LSS MRI\nDiffuse disc bulge noted at L5-S1 lev...
# 10           11  LSS MRI :\nAbout 3*2 cm lesion with inhomogeno...
# 342         343  L5-S1: Rt paracentral disc protrusion compress...
# 542         543  LSS MRI : \n-Feature of muscle spasm. \n-Dissi...
# 71           72  LSS MRI : \nFeature of muscle spasm . \nMultip...
# 296         297  LSS MRI :\nFeature of muscle spasm.\nMild diff...
# 374         375  LSS MRI : \nFeature of muscle spasm. \nDiffuse...
# 176         177  No evidence of disc herniation. No significant...
# 421         422  LSS MRI \nMild disc bulge noted at L4-L5 level...
# 308         309  Lumbosacral MRI \nNo evidence of disc Herniati...
# 226         227  LSS MRI \nNo evidence of disc herniation. \nNo...

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Patient ID            0
# Clinician's Notes    60
# dtype: int64

# %%
data = data.dropna()

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Patient ID           0
# Clinician's Notes    0
# dtype: int64

# %%
data.shape
# Out:
# (515, 2)

# %%
data.duplicated(subset="Clinician's Notes").sum()
# Out:
# 31

# %%
data = data.drop_duplicates(subset="Clinician's Notes", keep='first')
data.shape
# Out:
# (484, 2)

# %%
data.dtypes
# Out:
# Patient ID            int64
# Clinician's Notes    object
# dtype: object

# %%
qualitative_summary = data.describe(include='object')
print("\nDescription des variables qualitatives :")
print(qualitative_summary)
# Out:
# Description des variables qualitatives :
#                                         Clinician's Notes
# count                                                 484
# unique                                                484
# top     MRI OF THE L. SPINE \nFeature of muscle spasm....
# freq                                                    1

# %%
tmp = data["Clinician's Notes"].str.len()
sns.boxplot(x=tmp)
# Out:
# <Axes: xlabel="Clinician's Notes">

# %%
def generate_wordcloud(column_name, title="Nuage de mots"):
    if column_name not in data.columns:
        print(f"La colonne '{column_name}' n'existe pas dans le DataFrame.")
        return
    text = " ".join(data[column_name].dropna())
    if not text.strip():
        print(f"La colonne '{column_name}' ne contient pas de texte non vide.")
        return
    wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text)
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"{title} - {column_name}\n")
    plt.show()

generate_wordcloud("Clinician's Notes")

# %%
data = data.drop(["Patient ID"], axis=1)

# %%
data.to_csv("../../data/cleaned/data2_cleaned.csv",index=False)
